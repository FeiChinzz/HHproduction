# %%
import time
t1 = time.time()

import math
import os
import numpy as np
import pandas as pd
import h5py
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm

import tensorflow as tf
import tensorflow.keras as keras
from tensorflow.keras import layers, models
from tensorflow.keras.optimizers import Adam , SGD , Adagrad
from tensorflow.keras.callbacks import ModelCheckpoint, LearningRateScheduler, EarlyStopping, CSVLogger, ReduceLROnPlateau
from tensorflow.keras.utils import to_categorical, plot_model
from tensorflow.keras import regularizers , initializers
from sklearn.metrics import confusion_matrix
import tensorflow.keras.backend as K
from sklearn import metrics
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split

gpus = tf.config.experimental.list_physical_devices("GPU")
tf.config.set_visible_devices(gpus[1], "GPU")

### set seed ###
keras.utils.set_random_seed(2330)
tf.config.experimental.enable_op_determinism()
# Out:
# 2026-09-21 02:55:30.497287: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
##### load data #####

HLdata_path = "/root/data/mucollider/two_boosted/3TeV/data_HLfeature.h5"
HLdata_file = h5py.File(HLdata_path, 'r')
print(HLdata_file.keys())

LLdata_path = "/root/data/mucollider/two_boosted/3TeV/data_LLfeature.h5"
LLdata_file = h5py.File(LLdata_path, 'r')
print(LLdata_file.keys())
# Out:
# <KeysViewHDF5 ['BTag_leading', 'BTag_subleading', 'H_0', 'H_1', 'LB_1', 'M_JJ', 'S_0', 'S_1', 'X_HH', 'dEta_JJ', 'm_J_leading', 'm_J_subleading', 'missET', 'pT_JJ', 'pt_J_leading', 'pt_J_subleading', 'target_everytype', 'target_sigbg']>
# <KeysViewHDF5 ['particle_info']>

# %%
##### include data #####

HLfeatures = ['BTag_leading', 'BTag_subleading', 'M_JJ', 'X_HH', 'dEta_JJ', 'm_J_leading', 'm_J_subleading', 'missET', 'pT_JJ', 'pt_J_leading', 'pt_J_subleading']
LLfeatures = ['particle_info']

##### select BTag work point at WP70 (BitNumber 1) #####

BTag_leading = ((HLdata_file['BTag_leading'][:])&2)
BTag_subleading = ((HLdata_file['BTag_subleading'][:])&2)

##### include other high level features data #####

HLdata = []
for feature in HLfeatures:
    if feature=='BTag_leading': HLdata.append(BTag_leading)
    elif feature=='BTag_subleading': HLdata.append(BTag_subleading)
    else: HLdata.append(HLdata_file[feature][:])
HLdata = np.array(HLdata).T
print('shape of high level data:', HLdata.shape)

LLdata = LLdata_file['particle_info'][:]
print('shape of low level data:', LLdata.shape)

target = HLdata_file['target_sigbg'][:]
print('shape of target:', target.shape)

#### Do training data and validation data split #####

HL_train, HL_val, LL_train, LL_val, y_train, y_val = train_test_split(HLdata, LLdata, target, test_size=0.2, random_state=2330, shuffle=True)
print("\nAfter training validation data split:")
print("HL training data: ", HL_train.shape, "HL validation data: ", HL_val.shape)
print("LL training data: ", LL_train.shape, "LL validation data: ", LL_val.shape)
print("training target: ", y_train.shape, "validation target: ", y_val.shape)
# Out:
# shape of high level data: (866059, 11)
# shape of low level data: (866059, 160)
# shape of target: (866059,)
#
# After training validation data split:
# HL training data:  (692847, 11) HL validation data:  (173212, 11)
# LL training data:  (692847, 160) LL validation data:  (173212, 160)
# training target:  (692847,) validation target:  (173212,)

# %%
##### construct model #####

### high level features part ###

HL_input = layers.Input(shape=(11,), name='HL_Input')

x_hl = layers.Dense(128)(HL_input)
x_hl = layers.BatchNormalization()(x_hl)
x_hl = layers.Activation('relu')(x_hl)
x_hl = layers.Dropout(0.1)(x_hl)

x_hl = layers.Dense(128)(x_hl)
x_hl = layers.BatchNormalization()(x_hl)
x_hl = layers.Activation('relu')(x_hl)
x_hl = layers.Dropout(0.1)(x_hl)

### low level features part ###

LL_input = layers.Input(shape=(160,), name='LL_Input')

x_ll = layers.Dense(512)(LL_input)
x_ll = layers.BatchNormalization()(x_ll)
x_ll = layers.Activation('relu')(x_ll)
x_ll = layers.Dropout(0.1)(x_ll)

x_ll = layers.Dense(128)(x_ll)
x_ll = layers.BatchNormalization()(x_ll)
x_ll = layers.Activation('relu')(x_ll)
x_ll = layers.Dropout(0.1)(x_ll)

### combine two parts of model and the following node ###

combined = layers.Concatenate()([x_hl, x_ll])

x = layers.Dense(256, activation='relu')(combined)
x = layers.Dense(16, activation='relu')(x)
output = layers.Dense(1, activation='sigmoid', name='Output')(x)

model = models.Model(inputs=[HL_input, LL_input], outputs=output)

### optimizer ###

opt = keras.optimizers.Adam(learning_rate=1e-5)

### compile ###

model.compile(loss='binary_crossentropy', optimizer=opt, metrics=["accuracy","mse"])

### summary ###

model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  HL_Input (InputLayer)       [(None, 11)]                 0         []
#
#  LL_Input (InputLayer)       [(None, 160)]                0         []
#
#  dense (Dense)               (None, 128)                  1536      ['HL_Input[0][0]']
#
#  dense_2 (Dense)             (None, 512)                  82432     ['LL_Input[0][0]']
#
#  batch_normalization (Batch  (None, 128)                  512       ['dense[0][0]']
#  Normalization)
#
#  batch_normalization_2 (Bat  (None, 512)                  2048      ['dense_2[0][0]']
#  chNormalization)
#
#  activation (Activation)     (None, 128)                  0         ['batch_normalization[0][0]']
#
#  activation_2 (Activation)   (None, 512)                  0         ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  dropout (Dropout)           (None, 128)                  0         ['activation[0][0]']
#
#  dropout_2 (Dropout)         (None, 512)                  0         ['activation_2[0][0]']
#
#  dense_1 (Dense)             (None, 128)                  16512     ['dropout[0][0]']
#
#  dense_3 (Dense)             (None, 128)                  65664     ['dropout_2[0][0]']
#
#  batch_normalization_1 (Bat  (None, 128)                  512       ['dense_1[0][0]']
#  chNormalization)
#
#  batch_normalization_3 (Bat  (None, 128)                  512       ['dense_3[0][0]']
#  chNormalization)
#
#  activation_1 (Activation)   (None, 128)                  0         ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  activation_3 (Activation)   (None, 128)                  0         ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  dropout_1 (Dropout)         (None, 128)                  0         ['activation_1[0][0]']
#
#  dropout_3 (Dropout)         (None, 128)                  0         ['activation_3[0][0]']
#
#  concatenate (Concatenate)   (None, 256)                  0         ['dropout_1[0][0]',
#                                                                      'dropout_3[0][0]']
#
#  dense_4 (Dense)             (None, 256)                  65792     ['concatenate[0][0]']
#
#  dense_5 (Dense)             (None, 16)                   4112      ['dense_4[0][0]']
#
#  Output (Dense)              (None, 1)                    17        ['dense_5[0][0]']
#
# ==================================================================================================
# Total params: 239649 (936.13 KB)
# Trainable params: 237857 (929.13 KB)
# Non-trainable params: 1792 (7.00 KB)
# __________________________________________________________________________________________________
# 2026-09-21 02:55:33.625281: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 46696 MB memory:  -> device: 1, name: NVIDIA RTX A6000, pci bus id: 0000:25:00.0, compute capability: 8.6

# %%
##### training model #####

tr_model = model.fit(x=[HL_train, LL_train], y=y_train, validation_data=([HL_val, LL_val], y_val), epochs=128, batch_size=256, verbose=1)
# Out:
# Epoch 1/128
# 2026-09-21 02:55:37.426539: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:606] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2026-09-21 02:55:38.146339: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7fd37033d7f0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2026-09-21 02:55:38.146384: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA RTX A6000, Compute Capability 8.6
# 2026-09-21 02:55:38.151519: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:255] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2026-09-21 02:55:38.287771: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:432] Loaded cuDNN version 8600
# 2026-09-21 02:55:38.416574: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 2707/2707 [==============================] - 29s 9ms/step - loss: 0.3898 - accuracy: 0.8163 - mse: 0.1267 - val_loss: 0.2829 - val_accuracy: 0.8775 - val_mse: 0.0877
# Epoch 2/128
# 2707/2707 [==============================] - 23s 8ms/step - loss: 0.2930 - accuracy: 0.8701 - mse: 0.0919 - val_loss: 0.2490 - val_accuracy: 0.8896 - val_mse: 0.0776
# Epoch 3/128
# 2707/2707 [==============================] - 23s 9ms/step - loss: 0.2688 - accuracy: 0.8809 - mse: 0.0840 - val_loss: 0.2358 - val_accuracy: 0.8939 - val_mse: 0.0735
# Epoch 4/128
# 2707/2707 [==============================] - 23s 9ms/step - loss: 0.2547 - accuracy: 0.8867 - mse: 0.0795 - val_loss: 0.2277 - val_accuracy: 0.8968 - val_mse: 0.0711
# Epoch 5/128
# 2707/2707 [==============================] - 23s 8ms/step - loss: 0.2456 - accuracy: 0.8903 - mse: 0.0766 - val_loss: 0.2215 - val_accuracy: 0.9004 - val_mse: 0.0691
# Epoch 6/128
# 2707/2707 [==============================] - 23s 8ms/step - loss: 0.2388 - accuracy: 0.8932 - mse: 0.0746 - val_loss: 0.2164 - val_accuracy: 0.9018 - val_mse: 0.0676
# Epoch 7/128
# 2707/2707 [==============================] - 23s 9ms/step - loss: 0.2329 - accuracy: 0.8956 - mse: 0.0727 - val_loss: 0.2118 - val_accuracy: 0.9041 - val_mse: 0.0661
# Epoch 8/128
# 2707/2707 [==============================] - 23s 8ms/step - loss: 0.2278 - accuracy: 0.8983 - mse: 0.0711 - val_loss: 0.2070 - val_accuracy: 0.9064 - val_mse: 0.0646
# Epoch 9/128
# 2707/2707 [==============================] - 23s 9ms/step - loss: 0.2228 - accuracy: 0.9001 - mse: 0.0695 - val_loss: 0.2021 - val_accuracy: 0.9084 - val_mse: 0.0631
# Epoch 10/128
# 2707/2707 [==============================] - 23s 9ms/step - loss: 0.2176 - accuracy: 0.9027 - mse: 0.0678 - val_loss: 0.1967 - val_accuracy: 0.9117 - val_mse: 0.0614
# Epoch 11/128
# 2707/2707 [==============================] - 23s 9ms/step - loss: 0.2125 - accuracy: 0.9051 - mse: 0.0661 - val_loss: 0.1908 - val_accuracy: 0.9151 - val_mse: 0.0594
# Epoch 12/128
# 2707/2707 [==============================] - 23s 8ms/step - loss: 0.2067 - accuracy: 0.9081 - mse: 0.0643 - val_loss: 0.1859 - val_accuracy: 0.9178 - val_mse: 0.0577
# Epoch 13/128
# 2707/2707 [==============================] - 23s 9ms/step - loss: 0.2018 - accuracy: 0.9107 - mse: 0.0627 - val_loss: 0.1807 - val_accuracy: 0.9205 - val_mse: 0.0560
# Epoch 14/128
# 2707/2707 [==============================] - 23s 9ms/step - loss: 0.1974 - accuracy: 0.9124 - mse: 0.0613 - val_loss: 0.1765 - val_accuracy: 0.9215 - val_mse: 0.0548
# Epoch 15/128
# 2707/2707 [==============================] - 23s 8ms/step - loss: 0.1934 - accuracy: 0.9142 - mse: 0.0601 - val_loss: 0.1728 - val_accuracy: 0.9239 - val_mse: 0.0536
# Epoch 16/128
# 2707/2707 [==============================] - 23s 9ms/step - loss: 0.1901 - accuracy: 0.9155 - mse: 0.0591 - val_loss: 0.1697 - val_accuracy: 0.9255 - val_mse: 0.0526
# Epoch 17/128
# 2707/2707 [==============================] - 22s 8ms/step - loss: 0.1873 - accuracy: 0.9172 - mse: 0.0582 - val_loss: 0.1670 - val_accuracy: 0.9266 - val_mse: 0.0518
# Epoch 18/128
# 2707/2707 [==============================] - 22s 8ms/step - loss: 0.1843 - accuracy: 0.9186 - mse: 0.0572 - val_loss: 0.1642 - val_accuracy: 0.9280 - val_mse: 0.0508
# Epoch 19/128
# 2707/2707 [==============================] - 23s 8ms/step - loss: 0.1817 - accuracy: 0.9195 - mse: 0.0564 - val_loss: 0.1620 - val_accuracy: 0.9289 - val_mse: 0.0501
# Epoch 20/128
# 2707/2707 [==============================] - 22s 8ms/step - loss: 0.1793 - accuracy: 0.9210 - mse: 0.0556 - val_loss: 0.1600 - val_accuracy: 0.9302 - val_mse: 0.0495
# Epoch 21/128
# 2707/2707 [==============================] - 22s 8ms/step - loss: 0.1771 - accuracy: 0.9221 - mse: 0.0549 - val_loss: 0.1580 - val_accuracy: 0.9312 - val_mse: 0.0488
# Epoch 22/128
# 2707/2707 [==============================] - 23s 8ms/step - loss: 0.1752 - accuracy: 0.9226 - mse: 0.0543 - val_loss: 0.1561 - val_accuracy: 0.9323 - val_mse: 0.0481
# Epoch 23/128
# 2707/2707 [==============================] - 22s 8ms/step - loss: 0.1732 - accuracy: 0.9236 - mse: 0.0537 - val_loss: 0.1546 - val_accuracy: 0.9330 - val_mse: 0.0477
# Epoch 24/128
# 2707/2707 [==============================] - 22s 8ms/step - loss: 0.1710 - accuracy: 0.9251 - mse: 0.0529 - val_loss: 0.1528 - val_accuracy: 0.9338 - val_mse: 0.0471
# Epoch 25/128
# 2707/2707 [==============================] - 22s 8ms/step - loss: 0.1693 - accuracy: 0.9257 - mse: 0.0524 - val_loss: 0.1510 - val_accuracy: 0.9349 - val_mse: 0.0465
# Epoch 26/128
# 2707/2707 [==============================] - 22s 8ms/step - loss: 0.1675 - accuracy: 0.9265 - mse: 0.0518 - val_loss: 0.1496 - val_accuracy: 0.9356 - val_mse: 0.0460
# Epoch 27/128
# 2707/2707 [==============================] - 22s 8ms/step - loss: 0.1659 - accuracy: 0.9275 - mse: 0.0513 - val_loss: 0.1486 - val_accuracy: 0.9360 - val_mse: 0.0457
# Epoch 28/128
# 2707/2707 [==============================] - 23s 8ms/step - loss: 0.1643 - accuracy: 0.9285 - mse: 0.0507 - val_loss: 0.1474 - val_accuracy: 0.9366 - val_mse: 0.0453
# Epoch 29/128
# 2707/2707 [==============================] - 22s 8ms/step - loss: 0.1625 - accuracy: 0.9296 - mse: 0.0501 - val_loss: 0.1458 - val_accuracy: 0.9374 - val_mse: 0.0447
# Epoch 30/128
# 2707/2707 [==============================] - 22s 8ms/step - loss: 0.1614 - accuracy: 0.9299 - mse: 0.0498 - val_loss: 0.1447 - val_accuracy: 0.9382 - val_mse: 0.0444
# Epoch 31/128
# 2707/2707 [==============================] - 22s 8ms/step - loss: 0.1601 - accuracy: 0.9306 - mse: 0.0493 - val_loss: 0.1440 - val_accuracy: 0.9387 - val_mse: 0.0441
# Epoch 32/128
# 2707/2707 [==============================] - 22s 8ms/step - loss: 0.1588 - accuracy: 0.9313 - mse: 0.0489 - val_loss: 0.1429 - val_accuracy: 0.9393 - val_mse: 0.0438
# Epoch 33/128
# 2707/2707 [==============================] - 22s 8ms/step - loss: 0.1580 - accuracy: 0.9320 - mse: 0.0486 - val_loss: 0.1425 - val_accuracy: 0.9393 - val_mse: 0.0437
# Epoch 34/128
# 2707/2707 [==============================] - 22s 8ms/step - loss: 0.1570 - accuracy: 0.9323 - mse: 0.0483 - val_loss: 0.1416 - val_accuracy: 0.9399 - val_mse: 0.0434
# Epoch 35/128
# 2707/2707 [==============================] - 22s 8ms/step - loss: 0.1557 - accuracy: 0.9331 - mse: 0.0479 - val_loss: 0.1403 - val_accuracy: 0.9407 - val_mse: 0.0429
# Epoch 36/128
# 2707/2707 [==============================] - 22s 8ms/step - loss: 0.1547 - accuracy: 0.9332 - mse: 0.0476 - val_loss: 0.1400 - val_accuracy: 0.9408 - val_mse: 0.0429
# Epoch 37/128
# 2707/2707 [==============================] - 23s 8ms/step - loss: 0.1538 - accuracy: 0.9340 - mse: 0.0472 - val_loss: 0.1392 - val_accuracy: 0.9412 - val_mse: 0.0426
# Epoch 38/128
# 2707/2707 [==============================] - 23s 8ms/step - loss: 0.1533 - accuracy: 0.9344 - mse: 0.0470 - val_loss: 0.1386 - val_accuracy: 0.9414 - val_mse: 0.0424
# Epoch 39/128
# 2707/2707 [==============================] - 22s 8ms/step - loss: 0.1525 - accuracy: 0.9350 - mse: 0.0467 - val_loss: 0.1382 - val_accuracy: 0.9421 - val_mse: 0.0422
# Epoch 40/128
# 2707/2707 [==============================] - 22s 8ms/step - loss: 0.1512 - accuracy: 0.9352 - mse: 0.0463 - val_loss: 0.1376 - val_accuracy: 0.9420 - val_mse: 0.0420
# Epoch 41/128
# 2707/2707 [==============================] - 23s 9ms/step - loss: 0.1505 - accuracy: 0.9357 - mse: 0.0461 - val_loss: 0.1369 - val_accuracy: 0.9426 - val_mse: 0.0417
# Epoch 42/128
# 2707/2707 [==============================] - 23s 9ms/step - loss: 0.1502 - accuracy: 0.9359 - mse: 0.0460 - val_loss: 0.1365 - val_accuracy: 0.9426 - val_mse: 0.0416
# Epoch 43/128
# 2707/2707 [==============================] - 23s 8ms/step - loss: 0.1495 - accuracy: 0.9363 - mse: 0.0458 - val_loss: 0.1365 - val_accuracy: 0.9425 - val_mse: 0.0417
# Epoch 44/128
# 2707/2707 [==============================] - 23s 8ms/step - loss: 0.1488 - accuracy: 0.9367 - mse: 0.0456 - val_loss: 0.1359 - val_accuracy: 0.9427 - val_mse: 0.0415
# Epoch 45/128
# 2707/2707 [==============================] - 23s 8ms/step - loss: 0.1480 - accuracy: 0.9369 - mse: 0.0453 - val_loss: 0.1353 - val_accuracy: 0.9434 - val_mse: 0.0412
# Epoch 46/128
# 2707/2707 [==============================] - 23s 8ms/step - loss: 0.1475 - accuracy: 0.9373 - mse: 0.0451 - val_loss: 0.1350 - val_accuracy: 0.9433 - val_mse: 0.0412
# Epoch 47/128
# 2707/2707 [==============================] - 23s 8ms/step - loss: 0.1471 - accuracy: 0.9376 - mse: 0.0450 - val_loss: 0.1345 - val_accuracy: 0.9437 - val_mse: 0.0409
# Epoch 48/128
# 2707/2707 [==============================] - 23s 8ms/step - loss: 0.1466 - accuracy: 0.9380 - mse: 0.0448 - val_loss: 0.1343 - val_accuracy: 0.9437 - val_mse: 0.0409
# Epoch 49/128
# 2707/2707 [==============================] - 24s 9ms/step - loss: 0.1465 - accuracy: 0.9379 - mse: 0.0447 - val_loss: 0.1339 - val_accuracy: 0.9440 - val_mse: 0.0408
# Epoch 50/128
# 2707/2707 [==============================] - 23s 9ms/step - loss: 0.1458 - accuracy: 0.9382 - mse: 0.0446 - val_loss: 0.1342 - val_accuracy: 0.9436 - val_mse: 0.0409
# Epoch 51/128
# 2707/2707 [==============================] - 22s 8ms/step - loss: 0.1451 - accuracy: 0.9386 - mse: 0.0443 - val_loss: 0.1332 - val_accuracy: 0.9443 - val_mse: 0.0405
# Epoch 52/128
# 2707/2707 [==============================] - 23s 8ms/step - loss: 0.1450 - accuracy: 0.9388 - mse: 0.0443 - val_loss: 0.1332 - val_accuracy: 0.9443 - val_mse: 0.0405
# Epoch 53/128
# 2707/2707 [==============================] - 23s 8ms/step - loss: 0.1444 - accuracy: 0.9389 - mse: 0.0441 - val_loss: 0.1335 - val_accuracy: 0.9445 - val_mse: 0.0405
# Epoch 54/128
# 2707/2707 [==============================] - 23s 8ms/step - loss: 0.1441 - accuracy: 0.9393 - mse: 0.0440 - val_loss: 0.1336 - val_accuracy: 0.9440 - val_mse: 0.0407
# Epoch 55/128
# 2707/2707 [==============================] - 23s 8ms/step - loss: 0.1440 - accuracy: 0.9391 - mse: 0.0440 - val_loss: 0.1325 - val_accuracy: 0.9447 - val_mse: 0.0403
# Epoch 56/128
# 2707/2707 [==============================] - 22s 8ms/step - loss: 0.1437 - accuracy: 0.9393 - mse: 0.0438 - val_loss: 0.1325 - val_accuracy: 0.9446 - val_mse: 0.0403
# Epoch 57/128
# 2707/2707 [==============================] - 22s 8ms/step - loss: 0.1433 - accuracy: 0.9395 - mse: 0.0437 - val_loss: 0.1324 - val_accuracy: 0.9446 - val_mse: 0.0403
# Epoch 58/128
# 2707/2707 [==============================] - 23s 8ms/step - loss: 0.1431 - accuracy: 0.9395 - mse: 0.0437 - val_loss: 0.1323 - val_accuracy: 0.9448 - val_mse: 0.0402
# Epoch 59/128
# 2707/2707 [==============================] - 23s 8ms/step - loss: 0.1427 - accuracy: 0.9396 - mse: 0.0436 - val_loss: 0.1318 - val_accuracy: 0.9452 - val_mse: 0.0401
# Epoch 60/128
# 2707/2707 [==============================] - 23s 8ms/step - loss: 0.1422 - accuracy: 0.9403 - mse: 0.0433 - val_loss: 0.1319 - val_accuracy: 0.9450 - val_mse: 0.0401
# Epoch 61/128
# 2707/2707 [==============================] - 22s 8ms/step - loss: 0.1422 - accuracy: 0.9398 - mse: 0.0434 - val_loss: 0.1320 - val_accuracy: 0.9451 - val_mse: 0.0401
# Epoch 62/128
# 2707/2707 [==============================] - 22s 8ms/step - loss: 0.1421 - accuracy: 0.9400 - mse: 0.0433 - val_loss: 0.1314 - val_accuracy: 0.9451 - val_mse: 0.0400
# Epoch 63/128
# 2707/2707 [==============================] - 23s 8ms/step - loss: 0.1416 - accuracy: 0.9402 - mse: 0.0432 - val_loss: 0.1319 - val_accuracy: 0.9447 - val_mse: 0.0401
# Epoch 64/128
# 2707/2707 [==============================] - 22s 8ms/step - loss: 0.1409 - accuracy: 0.9407 - mse: 0.0429 - val_loss: 0.1313 - val_accuracy: 0.9452 - val_mse: 0.0399
# Epoch 65/128
# 2707/2707 [==============================] - 23s 8ms/step - loss: 0.1412 - accuracy: 0.9403 - mse: 0.0431 - val_loss: 0.1311 - val_accuracy: 0.9455 - val_mse: 0.0398
# Epoch 66/128
# 2707/2707 [==============================] - 23s 8ms/step - loss: 0.1407 - accuracy: 0.9405 - mse: 0.0429 - val_loss: 0.1310 - val_accuracy: 0.9454 - val_mse: 0.0398
# Epoch 67/128
# 2707/2707 [==============================] - 22s 8ms/step - loss: 0.1406 - accuracy: 0.9406 - mse: 0.0429 - val_loss: 0.1311 - val_accuracy: 0.9455 - val_mse: 0.0398
# Epoch 68/128
# 2707/2707 [==============================] - 23s 9ms/step - loss: 0.1401 - accuracy: 0.9407 - mse: 0.0427 - val_loss: 0.1306 - val_accuracy: 0.9454 - val_mse: 0.0397
# Epoch 69/128
# 2707/2707 [==============================] - 23s 9ms/step - loss: 0.1398 - accuracy: 0.9415 - mse: 0.0426 - val_loss: 0.1309 - val_accuracy: 0.9454 - val_mse: 0.0398
# Epoch 70/128
# 2707/2707 [==============================] - 23s 8ms/step - loss: 0.1398 - accuracy: 0.9412 - mse: 0.0426 - val_loss: 0.1301 - val_accuracy: 0.9456 - val_mse: 0.0395
# Epoch 71/128
# 2707/2707 [==============================] - 22s 8ms/step - loss: 0.1393 - accuracy: 0.9414 - mse: 0.0424 - val_loss: 0.1303 - val_accuracy: 0.9458 - val_mse: 0.0396
# Epoch 72/128
# 2707/2707 [==============================] - 23s 8ms/step - loss: 0.1392 - accuracy: 0.9415 - mse: 0.0424 - val_loss: 0.1301 - val_accuracy: 0.9455 - val_mse: 0.0395
# Epoch 73/128
# 2707/2707 [==============================] - 22s 8ms/step - loss: 0.1390 - accuracy: 0.9414 - mse: 0.0423 - val_loss: 0.1301 - val_accuracy: 0.9456 - val_mse: 0.0395
# Epoch 74/128
# 2707/2707 [==============================] - 23s 9ms/step - loss: 0.1388 - accuracy: 0.9415 - mse: 0.0423 - val_loss: 0.1303 - val_accuracy: 0.9458 - val_mse: 0.0396
# Epoch 75/128
# 2707/2707 [==============================] - 24s 9ms/step - loss: 0.1388 - accuracy: 0.9414 - mse: 0.0423 - val_loss: 0.1298 - val_accuracy: 0.9460 - val_mse: 0.0394
# Epoch 76/128
# 2707/2707 [==============================] - 24s 9ms/step - loss: 0.1383 - accuracy: 0.9416 - mse: 0.0421 - val_loss: 0.1300 - val_accuracy: 0.9460 - val_mse: 0.0395
# Epoch 77/128
# 2707/2707 [==============================] - 24s 9ms/step - loss: 0.1380 - accuracy: 0.9419 - mse: 0.0420 - val_loss: 0.1298 - val_accuracy: 0.9457 - val_mse: 0.0394
# Epoch 78/128
# 2707/2707 [==============================] - 24s 9ms/step - loss: 0.1378 - accuracy: 0.9417 - mse: 0.0420 - val_loss: 0.1298 - val_accuracy: 0.9457 - val_mse: 0.0394
# Epoch 79/128
# 2707/2707 [==============================] - 24s 9ms/step - loss: 0.1376 - accuracy: 0.9421 - mse: 0.0419 - val_loss: 0.1295 - val_accuracy: 0.9459 - val_mse: 0.0393
# Epoch 80/128
# 2707/2707 [==============================] - 24s 9ms/step - loss: 0.1377 - accuracy: 0.9421 - mse: 0.0419 - val_loss: 0.1296 - val_accuracy: 0.9459 - val_mse: 0.0394
# Epoch 81/128
# 2707/2707 [==============================] - 23s 9ms/step - loss: 0.1374 - accuracy: 0.9422 - mse: 0.0418 - val_loss: 0.1290 - val_accuracy: 0.9462 - val_mse: 0.0392
# Epoch 82/128
# 2707/2707 [==============================] - 24s 9ms/step - loss: 0.1375 - accuracy: 0.9419 - mse: 0.0419 - val_loss: 0.1297 - val_accuracy: 0.9462 - val_mse: 0.0394
# Epoch 83/128
# 2707/2707 [==============================] - 23s 9ms/step - loss: 0.1371 - accuracy: 0.9421 - mse: 0.0418 - val_loss: 0.1294 - val_accuracy: 0.9460 - val_mse: 0.0393
# Epoch 84/128
# 2707/2707 [==============================] - 24s 9ms/step - loss: 0.1368 - accuracy: 0.9422 - mse: 0.0417 - val_loss: 0.1293 - val_accuracy: 0.9460 - val_mse: 0.0393
# Epoch 85/128
# 2707/2707 [==============================] - 23s 9ms/step - loss: 0.1370 - accuracy: 0.9422 - mse: 0.0417 - val_loss: 0.1291 - val_accuracy: 0.9460 - val_mse: 0.0392
# Epoch 86/128
# 2707/2707 [==============================] - 24s 9ms/step - loss: 0.1365 - accuracy: 0.9425 - mse: 0.0415 - val_loss: 0.1290 - val_accuracy: 0.9462 - val_mse: 0.0392
# Epoch 87/128
# 2707/2707 [==============================] - 23s 9ms/step - loss: 0.1364 - accuracy: 0.9427 - mse: 0.0415 - val_loss: 0.1289 - val_accuracy: 0.9462 - val_mse: 0.0392
# Epoch 88/128
# 2707/2707 [==============================] - 24s 9ms/step - loss: 0.1364 - accuracy: 0.9427 - mse: 0.0415 - val_loss: 0.1298 - val_accuracy: 0.9459 - val_mse: 0.0395
# Epoch 89/128
# 2707/2707 [==============================] - 23s 9ms/step - loss: 0.1360 - accuracy: 0.9425 - mse: 0.0414 - val_loss: 0.1290 - val_accuracy: 0.9464 - val_mse: 0.0392
# Epoch 90/128
# 2707/2707 [==============================] - 24s 9ms/step - loss: 0.1362 - accuracy: 0.9428 - mse: 0.0414 - val_loss: 0.1293 - val_accuracy: 0.9460 - val_mse: 0.0393
# Epoch 91/128
# 2707/2707 [==============================] - 24s 9ms/step - loss: 0.1356 - accuracy: 0.9431 - mse: 0.0413 - val_loss: 0.1289 - val_accuracy: 0.9461 - val_mse: 0.0391
# Epoch 92/128
# 2707/2707 [==============================] - 24s 9ms/step - loss: 0.1351 - accuracy: 0.9430 - mse: 0.0412 - val_loss: 0.1288 - val_accuracy: 0.9461 - val_mse: 0.0391
# Epoch 93/128
# 2707/2707 [==============================] - 24s 9ms/step - loss: 0.1350 - accuracy: 0.9431 - mse: 0.0411 - val_loss: 0.1284 - val_accuracy: 0.9465 - val_mse: 0.0390
# Epoch 94/128
# 2707/2707 [==============================] - 24s 9ms/step - loss: 0.1355 - accuracy: 0.9432 - mse: 0.0412 - val_loss: 0.1284 - val_accuracy: 0.9465 - val_mse: 0.0390
# Epoch 95/128
# 2707/2707 [==============================] - 24s 9ms/step - loss: 0.1353 - accuracy: 0.9431 - mse: 0.0412 - val_loss: 0.1283 - val_accuracy: 0.9466 - val_mse: 0.0390
# Epoch 96/128
# 2707/2707 [==============================] - 24s 9ms/step - loss: 0.1349 - accuracy: 0.9433 - mse: 0.0410 - val_loss: 0.1284 - val_accuracy: 0.9463 - val_mse: 0.0390
# Epoch 97/128
# 2707/2707 [==============================] - 24s 9ms/step - loss: 0.1347 - accuracy: 0.9435 - mse: 0.0410 - val_loss: 0.1289 - val_accuracy: 0.9461 - val_mse: 0.0391
# Epoch 98/128
# 2707/2707 [==============================] - 23s 9ms/step - loss: 0.1346 - accuracy: 0.9433 - mse: 0.0410 - val_loss: 0.1283 - val_accuracy: 0.9465 - val_mse: 0.0390
# Epoch 99/128
# 2707/2707 [==============================] - 24s 9ms/step - loss: 0.1343 - accuracy: 0.9435 - mse: 0.0409 - val_loss: 0.1286 - val_accuracy: 0.9468 - val_mse: 0.0390
# Epoch 100/128
# 2707/2707 [==============================] - 23s 9ms/step - loss: 0.1343 - accuracy: 0.9435 - mse: 0.0409 - val_loss: 0.1280 - val_accuracy: 0.9466 - val_mse: 0.0389
# Epoch 101/128
# 2707/2707 [==============================] - 23s 9ms/step - loss: 0.1341 - accuracy: 0.9435 - mse: 0.0408 - val_loss: 0.1281 - val_accuracy: 0.9467 - val_mse: 0.0389
# Epoch 102/128
# 2707/2707 [==============================] - 24s 9ms/step - loss: 0.1340 - accuracy: 0.9438 - mse: 0.0408 - val_loss: 0.1284 - val_accuracy: 0.9465 - val_mse: 0.0389
# Epoch 103/128
# 2707/2707 [==============================] - 24s 9ms/step - loss: 0.1336 - accuracy: 0.9437 - mse: 0.0407 - val_loss: 0.1280 - val_accuracy: 0.9467 - val_mse: 0.0389
# Epoch 104/128
# 2707/2707 [==============================] - 23s 9ms/step - loss: 0.1336 - accuracy: 0.9438 - mse: 0.0407 - val_loss: 0.1278 - val_accuracy: 0.9467 - val_mse: 0.0388
# Epoch 105/128
# 2707/2707 [==============================] - 23s 9ms/step - loss: 0.1337 - accuracy: 0.9437 - mse: 0.0407 - val_loss: 0.1282 - val_accuracy: 0.9466 - val_mse: 0.0389
# Epoch 106/128
# 2707/2707 [==============================] - 23s 9ms/step - loss: 0.1331 - accuracy: 0.9441 - mse: 0.0405 - val_loss: 0.1280 - val_accuracy: 0.9468 - val_mse: 0.0389
# Epoch 107/128
# 2707/2707 [==============================] - 24s 9ms/step - loss: 0.1332 - accuracy: 0.9439 - mse: 0.0405 - val_loss: 0.1279 - val_accuracy: 0.9467 - val_mse: 0.0388
# Epoch 108/128
# 2707/2707 [==============================] - 24s 9ms/step - loss: 0.1327 - accuracy: 0.9441 - mse: 0.0404 - val_loss: 0.1280 - val_accuracy: 0.9468 - val_mse: 0.0388
# Epoch 109/128
# 2707/2707 [==============================] - 23s 8ms/step - loss: 0.1324 - accuracy: 0.9446 - mse: 0.0402 - val_loss: 0.1276 - val_accuracy: 0.9470 - val_mse: 0.0387
# Epoch 110/128
# 2707/2707 [==============================] - 24s 9ms/step - loss: 0.1331 - accuracy: 0.9442 - mse: 0.0404 - val_loss: 0.1276 - val_accuracy: 0.9469 - val_mse: 0.0387
# Epoch 111/128
# 2707/2707 [==============================] - 24s 9ms/step - loss: 0.1325 - accuracy: 0.9441 - mse: 0.0403 - val_loss: 0.1278 - val_accuracy: 0.9469 - val_mse: 0.0388
# Epoch 112/128
# 2707/2707 [==============================] - 23s 9ms/step - loss: 0.1322 - accuracy: 0.9447 - mse: 0.0402 - val_loss: 0.1281 - val_accuracy: 0.9468 - val_mse: 0.0389
# Epoch 113/128
# 2707/2707 [==============================] - 23s 9ms/step - loss: 0.1322 - accuracy: 0.9447 - mse: 0.0402 - val_loss: 0.1276 - val_accuracy: 0.9470 - val_mse: 0.0387
# Epoch 114/128
# 2707/2707 [==============================] - 24s 9ms/step - loss: 0.1324 - accuracy: 0.9445 - mse: 0.0403 - val_loss: 0.1278 - val_accuracy: 0.9470 - val_mse: 0.0388
# Epoch 115/128
# 2707/2707 [==============================] - 24s 9ms/step - loss: 0.1323 - accuracy: 0.9444 - mse: 0.0402 - val_loss: 0.1276 - val_accuracy: 0.9468 - val_mse: 0.0387
# Epoch 116/128
# 2707/2707 [==============================] - 23s 8ms/step - loss: 0.1321 - accuracy: 0.9442 - mse: 0.0402 - val_loss: 0.1277 - val_accuracy: 0.9469 - val_mse: 0.0387
# Epoch 117/128
# 2707/2707 [==============================] - 24s 9ms/step - loss: 0.1315 - accuracy: 0.9447 - mse: 0.0401 - val_loss: 0.1273 - val_accuracy: 0.9471 - val_mse: 0.0386
# Epoch 118/128
# 2707/2707 [==============================] - 24s 9ms/step - loss: 0.1318 - accuracy: 0.9444 - mse: 0.0402 - val_loss: 0.1276 - val_accuracy: 0.9471 - val_mse: 0.0387
# Epoch 119/128
# 2707/2707 [==============================] - 24s 9ms/step - loss: 0.1315 - accuracy: 0.9449 - mse: 0.0400 - val_loss: 0.1279 - val_accuracy: 0.9470 - val_mse: 0.0388
# Epoch 120/128
# 2707/2707 [==============================] - 24s 9ms/step - loss: 0.1314 - accuracy: 0.9448 - mse: 0.0400 - val_loss: 0.1277 - val_accuracy: 0.9470 - val_mse: 0.0387
# Epoch 121/128
# 2707/2707 [==============================] - 24s 9ms/step - loss: 0.1310 - accuracy: 0.9451 - mse: 0.0398 - val_loss: 0.1273 - val_accuracy: 0.9471 - val_mse: 0.0386
# Epoch 122/128
# 2707/2707 [==============================] - 24s 9ms/step - loss: 0.1307 - accuracy: 0.9450 - mse: 0.0398 - val_loss: 0.1274 - val_accuracy: 0.9470 - val_mse: 0.0387
# Epoch 123/128
# 2707/2707 [==============================] - 24s 9ms/step - loss: 0.1310 - accuracy: 0.9447 - mse: 0.0399 - val_loss: 0.1270 - val_accuracy: 0.9474 - val_mse: 0.0385
# Epoch 124/128
# 2707/2707 [==============================] - 24s 9ms/step - loss: 0.1307 - accuracy: 0.9451 - mse: 0.0398 - val_loss: 0.1276 - val_accuracy: 0.9469 - val_mse: 0.0387
# Epoch 125/128
# 2707/2707 [==============================] - 24s 9ms/step - loss: 0.1308 - accuracy: 0.9450 - mse: 0.0398 - val_loss: 0.1272 - val_accuracy: 0.9474 - val_mse: 0.0386
# Epoch 126/128
# 2707/2707 [==============================] - 24s 9ms/step - loss: 0.1308 - accuracy: 0.9451 - mse: 0.0398 - val_loss: 0.1275 - val_accuracy: 0.9470 - val_mse: 0.0387
# Epoch 127/128
# 2707/2707 [==============================] - 24s 9ms/step - loss: 0.1305 - accuracy: 0.9453 - mse: 0.0397 - val_loss: 0.1272 - val_accuracy: 0.9472 - val_mse: 0.0386
# Epoch 128/128
# 2707/2707 [==============================] - 23s 9ms/step - loss: 0.1303 - accuracy: 0.9454 - mse: 0.0396 - val_loss: 0.1270 - val_accuracy: 0.9474 - val_mse: 0.0386

# %%
### plot learning curve

fig, ax = plt.subplots(1,1, figsize=(8,8))
plt.plot(tr_model.history["loss"], label='training data',c='blue',linewidth = 2)
plt.plot(tr_model.history["val_loss"], label='validation data',c='red',linewidth = 2)
plt.title("DNN with TDA variable", fontsize=25)
ax.set_ylabel('loss', fontsize=25,horizontalalignment='right',y=1)
ax.set_xlabel('epoch', fontsize=25,horizontalalignment='right',x=1)
# plt.yscale("log")
plt.legend(loc='best', prop={'size':20}, edgecolor = "w",fancybox=False, framealpha=0)
plt.show()

fig, ax = plt.subplots(1,1, figsize=(8,8))
plt.plot(tr_model.history["accuracy"], label='training data',c='blue',linewidth = 2)
plt.plot(tr_model.history["val_accuracy"], label='validation data',c='red',linewidth = 2)
plt.title("DNN with TDA variable", fontsize=25)
ax.set_ylabel('accuracy', fontsize=25,horizontalalignment='right',y=1)
ax.set_xlabel('epoch', fontsize=25,horizontalalignment='right',x=1)
# plt.yscale("log")
plt.legend(loc='best', prop={'size':20}, edgecolor = "w",fancybox=False, framealpha=0)
plt.show()

# %%
print("Time:{:^8.4f}(s)".format(time.time()-t1))
# Out:
# Time:2976.7716(s)

# %%
### save the model ###

model.save("/root/data/mucollider/two_boosted/3TeV/model_mucollider_woTDA.h5")
# Out:
# /root/miniconda3/envs/tf/lib/python3.10/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
### model test ###

HLtest = []
LLtest = []
targettest = []
prediction = []

processes = ["hhvv", "hhmumu", "jjBG_ptcut", "ttBG_ptcut", "bbBG_ptcut", "wwBG", "wwvvBG", "zzBG", "zzvvBG", "hzvvBG"]
event_num = [147518, 143791, 35834, 35591, 39064, 50582, 99709, 60870, 120594, 132700]
Xsection = [4.0360050e-02, +3.3945676e-03, 1.345150e+01, 4.423600e+00, 2.325600e+00, 1.506969e+02, 1.224052e+01, 9.618000e+00, 6.473005e+00, 7.4722023e-01]     ### unit: fb
simulation_num = 500000
Luminosity = 1000   ### unit: fb^-1

count = 0
for process in processes:
    HLtest.append(HLdata[count:count+event_num[processes.index(process)]])
    LLtest.append(LLdata[count:count+event_num[processes.index(process)]])
    targettest.append(target[count:count+event_num[processes.index(process)]])
    prediction.append(model.predict([HLtest[-1], LLtest[-1]]))
    count += event_num[processes.index(process)]
# Out:
# 4610/4610 [==============================] - 8s 2ms/step
# 4494/4494 [==============================] - 8s 2ms/step
# 1120/1120 [==============================] - 2s 2ms/step
# 1113/1113 [==============================] - 2s 2ms/step
# 1221/1221 [==============================] - 3s 2ms/step
# 1581/1581 [==============================] - 3s 2ms/step
# 3116/3116 [==============================] - 6s 2ms/step
# 1903/1903 [==============================] - 4s 2ms/step
# 3769/3769 [==============================] - 7s 2ms/step
# 4141/4141 [==============================] - 8s 2ms/step

# %%
##### plot the prediction histogram #####

plt.figure(1, figsize=(9,7))
bins = np.linspace(0,1,21)
for process in processes:
    plt.hist(prediction[processes.index(process)], bins=bins, label=process, histtype=('stepfilled' if (process=='hhvv' or process=='hhmumu') else 'step'), density=True, alpha=(0.5 if (process=='hhvv' or process=='hhmumu') else 1))
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
plt.xlabel(r"prediction score", fontsize=18)
plt.ylabel(r"Normalized $\frac{dN}{dx}$", fontsize=18)
# plt.yscale("log")
plt.title("Model", fontsize=18)
plt.legend(loc='best')
plt.show()

plt.figure(1, figsize=(9,7))
bins = np.linspace(0,1,21)
for process in processes:
    plt.hist(prediction[processes.index(process)], bins=bins, label=process, histtype=('stepfilled' if (process=='hhvv' or process=='hhmumu') else 'step'), density=True, alpha=(0.5 if (process=='hhvv' or process=='hhmumu') else 1))
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
plt.xlabel(r"prediction score", fontsize=18)
plt.ylabel(r"Normalized $\frac{dN}{dx}$", fontsize=18)
plt.yscale("log")
plt.title("Model", fontsize=18)
plt.legend(loc='best')
plt.show()

# %%
### Do the score cut ###

score_cuts = [0.5, 0.7, 0.8, 0.9, 0.95, 0.99, 0.999]

for score_cut in score_cuts:
    print("In score cut", score_cut)

    num_afterML = []
    for process in processes: num_afterML.append(sum(prediction[processes.index(process)]>=score_cut)[0])
    print("Number before ML: ", event_num)
    print("Number after  ML: ", num_afterML)
    
    ### calculate significance ###
    
    s, b = 0, 0
    for process in processes[0:2]:
        s += Luminosity * Xsection[processes.index(process)] * (num_afterML[processes.index(process)]/simulation_num)
    for process in processes[2:]:
        b += Luminosity * Xsection[processes.index(process)] * (num_afterML[processes.index(process)]/simulation_num)
        
    def significance(s,b):
        return np.sqrt(2*((s+b)*np.log(1+s/b)-s))
    
    z = significance(s,b)
    print("signal events:", s)
    print("background events:", b)
    print("significance:", z)
    print("\n")
# Out:
# In score cut 0.5
# Number before ML:  [147518, 143791, 35834, 35591, 39064, 50582, 99709, 60870, 120594, 132700]
# Number after  ML:  [131858, 133722, 171, 1374, 366, 0, 7, 1, 499, 15305]
# signal events: 11.5514476830144
# background events: 47.9818785103
# significance: 1.6066461057922967
#
#
# In score cut 0.7
# Number before ML:  [147518, 143791, 35834, 35591, 39064, 50582, 99709, 60870, 120594, 132700]
# Number after  ML:  [122438, 126473, 97, 809, 187, 0, 1, 0, 111, 7053]
# signal events: 10.741849899949601
# background events: 22.63852691438
# significance: 2.107250260537637
#
#
# In score cut 0.8
# Number before ML:  [147518, 143791, 35834, 35591, 39064, 50582, 99709, 60870, 120594, 132700]
# Number after  ML:  [116044, 120109, 63, 574, 133, 0, 0, 0, 38, 3811]
# signal events: 10.182519524136799
# background events: 13.579052373060001
# significance: 2.495220056805084
#
#
# In score cut 0.9
# Number before ML:  [147518, 143791, 35834, 35591, 39064, 50582, 99709, 60870, 120594, 132700]
# Number after  ML:  [107107, 110326, 39, 347, 86, 0, 0, 0, 9, 1410]
# signal events: 9.3947058807752
# background events: 6.742873738600001
# significance: 3.0620211397793256
#
#
# In score cut 0.95
# Number before ML:  [147518, 143791, 35834, 35591, 39064, 50582, 99709, 60870, 120594, 132700]
# Number after  ML:  [100171, 103575, 24, 233, 53, 0, 0, 0, 3, 693]
# signal events: 8.78899781544
# background events: 4.028068468780001
# significance: 3.477538238433701
#
#
# In score cut 0.99
# Number before ML:  [147518, 143791, 35834, 35591, 39064, 50582, 99709, 60870, 120594, 132700]
# Number after  ML:  [83407, 89837, 4, 72, 19, 0, 0, 0, 0, 157]
# signal events: 7.3425369196623995
# background events: 1.0676103522200002
# significance: 4.475744155883543
#
#
# In score cut 0.999
# Number before ML:  [147518, 143791, 35834, 35591, 39064, 50582, 99709, 60870, 120594, 132700]
# Number after  ML:  [41079, 52826, 0, 7, 2, 0, 0, 0, 0, 6]
# signal events: 3.6745438439752
# background events: 0.08019944276
# significance: 4.640510731354945

# %%
scores = np.linspace(0.3, 1, 100)
z_line = []

def significance(s,b):
    return np.sqrt(2*((s+b)*np.log(1+s/b)-s))

for score in scores:
    num_afterML = []
    for process in processes: num_afterML.append(sum(prediction[processes.index(process)]>=score)[0])
    s, b = 0, 0
    for process in processes[0:2]:
        s += Luminosity * Xsection[processes.index(process)] * (num_afterML[processes.index(process)]/simulation_num)
    for process in processes[2:]:
        b += Luminosity * Xsection[processes.index(process)] * (num_afterML[processes.index(process)]/simulation_num)
    
    z_line.append(significance(s,b))

plt.figure(1, figsize=(9,7))
plt.plot(scores, z_line, label='significance vs. score cut')
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
plt.xlabel(r"prediction score", fontsize=18)
plt.ylabel(r"significance", fontsize=18)
plt.legend(loc='best')
plt.show()
# Out:
# /tmp/ipykernel_1254/3436209754.py:5: RuntimeWarning: invalid value encountered in scalar divide
#   return np.sqrt(2*((s+b)*np.log(1+s/b)-s))

# %%
### check which part of model is more important ###

weights, biases = model.get_layer('dense_4').get_weights()
hl_influence = np.mean(np.abs(weights[:128, :]))
ll_influence = np.mean(np.abs(weights[128:, :]))
print("high level influence: ", hl_influence)
print("low  level influence: ", ll_influence)

weights, _ = model.get_layer('dense_4').get_weights()

hl_weights = np.abs(weights[:128, :]).flatten()
ll_weights = np.abs(weights[128:, :]).flatten()

bins = np.linspace(0,max(hl_weights), 50)
plt.hist(hl_weights, bins=bins, alpha=0.5, label='HL Weights', color='blue')
plt.hist(ll_weights, bins=bins, alpha=0.5, label='LL Weights', color='green')
plt.title('Weight Magnitude Distribution at Fusion Layer')
plt.xlabel('weight')
plt.ylabel('count')
plt.legend()
plt.show()
# Out:
# high level influence:  0.05773111
# low  level influence:  0.053648673

# %%
print("Time:{:^8.4f}(s)".format(time.time()-t1))
# Out:
# Time:3155.1664(s)
