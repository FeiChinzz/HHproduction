# %%
########## import some useful package ##########

import time
t1 = time.time()

import uproot
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm

import ripser
import persim

# %%
########## read the data ##########

processes = [f"run_{i:02d}_decayed_1" for i in range(1,12)]
kappa_3 = [0.2, 0.4, 0.6, 0.8, 0.9, 1, 1.1, 1.2, 1.4, 1.6, 1.8]
# Xsection_NoDecay = [1.23322e-01, 1.016366e-01, 8.33476424e-02, 6.81961e-02, 6.2211286e-02, 5.648398e-02, 5.187586e-02, 4.801255e-02, 4.246736e-02, 4.038406e-02, 4.1308219e-02]     ### hhvv unit: fb
Xsection_NoDecay = [1.068573e-2, 8.89267e-3, 7.29573e-3, 5.892737e-3, 5.2836183e-3, 4.68848e-3, 4.1895e-3, 3.7137245e-3, 2.9218193e-3, 2.3228e-3, 1.9414667e-3]     ### hhmumu unit: fb
BR_hbb = 0.5824
Xsection = []
for i in range(11):
    Xsection.append(Xsection_NoDecay[i]*BR_hbb*BR_hbb)
    
Luminosity = 1000   ### unit: fb^-1
simulation_num = 100000

features = ["VLCjetR10N2", "VLCjetR10N2.PT", "VLCjetR10N2.Mass", "VLCjetR10N2.Constituents", "EFlowTrack.fUniqueID", "EFlowTrack.PT", "EFlowTrack.Eta", "EFlowTrack.Phi", "EFlowTrack.PID", "EFlowPhoton.fUniqueID", "EFlowPhoton.ET", "EFlowPhoton.Eta", "EFlowPhoton.Phi", "EFlowNeutralHadron.fUniqueID", "EFlowNeutralHadron.ET", "EFlowNeutralHadron.Eta", "EFlowNeutralHadron.Phi"]

##### set data path #####

event_path = []
for type in processes:
    event_path.append("/data/mucollider/two_boosted/scan_kappa3_hhmumu/Events/" + type + "/delphes_events.root")

##### get the data file #####

data_file =[]
for path in event_path:
    data_file.append(uproot.open(path))
    
##### read data with features #####
events = []     ### total events
for process in processes:
    tmp_events = []
    for feature in features:
        tmp_events.append(data_file[processes.index(process)]["Delphes;1"][feature].array())
    tmp_events = np.expand_dims(tmp_events, axis=-1)
    tmp_events = tmp_events.transpose((1,0,2))
    tmp_events = np.squeeze(tmp_events,axis=(2,))
    events.append(tmp_events)
    print(process, "Time:{:^8.4f}(s)".format(time.time()-t1))
del tmp_events
# Out:
# /usr/local/lib/python3.8/dist-packages/awkward/array/base.py:394: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return cls.numpy.array(value, copy=False)
# run_01_decayed_1 Time:11.8163 (s)
# run_02_decayed_1 Time:22.2832 (s)
# run_03_decayed_1 Time:33.1206 (s)
# run_04_decayed_1 Time:43.6242 (s)
# run_05_decayed_1 Time:54.2904 (s)
# run_06_decayed_1 Time:65.0127 (s)
# run_07_decayed_1 Time:74.2866 (s)
# run_08_decayed_1 Time:85.7652 (s)
# run_09_decayed_1 Time:97.7914 (s)
# run_10_decayed_1 Time:107.2663(s)
# run_11_decayed_1 Time:116.4964(s)

# %%
########## define useful function ##########

##### calculate significance #####

def significance(s,b):
    return np.sqrt(2*((s+b)*np.log(1+s/b)-s))

##### count event number #####

def count(events):
    events_num = []
    for i, process in enumerate(processes):
        events_num.append(len(events[processes.index(process)]))
        print("There are", events_num[i], process, "events. Corresponding cross section:", Xsection[processes.index(process)]*events_num[i]/simulation_num, "(fb)")
        
##### select if Fat Jet >= 2 #####
        
def Fat_Jet_selection(events):
    where1 = np.where(events[:,features.index("VLCjetR10N2")]>=2)
    return events[where1]

##### select if M_jet_leading > XX GeV #####

def mass_leading_selection(events, low_mass_cut, high_mass_cut):
    where1 = []
    for i in range(len(events)):
        switch=1
        if events[i][features.index("VLCjetR10N2.Mass")][0]<low_mass_cut:
            switch=0
        if events[i][features.index("VLCjetR10N2.Mass")][0]>high_mass_cut:
            switch=0
        if switch==1:
            where1.append(i)
    return events[where1]

##### select if M_jet_subleading > XX GeV #####

def mass_subleading_selection(events, low_mass_cut, high_mass_cut):
    where1 = []
    for i in range(len(events)):
        switch=1
        if events[i][features.index("VLCjetR10N2.Mass")][1]<low_mass_cut:
            switch=0
        if events[i][features.index("VLCjetR10N2.Mass")][1]>high_mass_cut:
            switch=0
        if switch==1:
            where1.append(i)
    return events[where1]

##### select if pT_J_leading > XX GeV #####

def pT_leading_selection(events, low_pT_cut, high_pT_cut):
    where1 = []
    for i in range(len(events)):
        switch = 1
        if events[i][features.index("VLCjetR10N2.PT")][0]<low_pT_cut:
            switch=0
        if events[i][features.index("VLCjetR10N2.PT")][0]>high_pT_cut:
            switch=0
        if switch==1:
            where1.append(i)
    return events[where1]

##### select if pT_J_subleading > XX GeV #####

def pT_subleading_selection(events, low_pT_cut, high_pT_cut):
    where1 = []
    for i in range(len(events)):
        switch = 1
        if events[i][features.index("VLCjetR10N2.PT")][1]<low_pT_cut:
            switch=0
        if events[i][features.index("VLCjetR10N2.PT")][1]>high_pT_cut:
            switch=0
        if switch==1:
            where1.append(i)
    return events[where1]

# %%
def get_particle_info(event):
    ##### set jet constituents ID #####

    leadingJ_constituents = event[features.index("VLCjetR10N2.Constituents")][0][:-1]
    subleadingJ_constituents= event[features.index("VLCjetR10N2.Constituents")][1][:-1]

    ##### construct infromation for all EFlow particles in this events and sort by PT #####

    all_ID = np.concatenate((event[features.index("EFlowTrack.fUniqueID")], event[features.index("EFlowPhoton.fUniqueID")], event[features.index("EFlowNeutralHadron.fUniqueID")]))
    all_PT = np.concatenate((event[features.index("EFlowTrack.PT")], event[features.index("EFlowPhoton.ET")], event[features.index("EFlowNeutralHadron.ET")]))
    all_Eta = np.concatenate((event[features.index("EFlowTrack.Eta")], event[features.index("EFlowPhoton.Eta")], event[features.index("EFlowNeutralHadron.Eta")]))
    all_Phi = np.concatenate((event[features.index("EFlowTrack.Phi")], event[features.index("EFlowPhoton.Phi")], event[features.index("EFlowNeutralHadron.Phi")]))
    all_PID = np.concatenate((event[features.index("EFlowTrack.PID")], np.full(len(event[features.index("EFlowPhoton.fUniqueID")]), 22), np.full(len(event[features.index("EFlowNeutralHadron.fUniqueID")]), 4)))

    #####                          categorize PID                      #####
    ##### 1:electron 2:muon 3:photon 4:neutral hadron 5:charged hadron #####

    condlist = [abs(all_PID)==11, abs(all_PID)==13, abs(all_PID)==22, abs(all_PID)==4]
    choicelist = [1, 2, 3, 4]
    all_PID = np.select(condlist, choicelist, 5)

    sort_order = np.argsort(all_PT)[::-1]   ### from large PT to low PT

    all_ID = all_ID[sort_order]
    all_PT = all_PT[sort_order]
    all_Eta = all_Eta[sort_order]
    all_Phi = all_Phi[sort_order]
    all_PID = all_PID[sort_order]

    ##### find Jet particle in EFlow particle #####
    if len(leadingJ_constituents)>20: where_leading = np.where(np.isin(all_ID, leadingJ_constituents))[0][0:20]
    else: where_leading = np.where(np.isin(all_ID, leadingJ_constituents))[0]

    if len(subleadingJ_constituents)>20: where_subleading = np.where(np.isin(all_ID, subleadingJ_constituents))[0][0:20]
    else: where_subleading = np.where(np.isin(all_ID, subleadingJ_constituents))[0]

    leadingJ_PT, subleadingJ_PT = all_PT[where_leading], all_PT[where_subleading]
    leadingJ_Eta, subleadingJ_Eta = all_Eta[where_leading], all_Eta[where_subleading]
    leadingJ_Phi, subleadingJ_Phi = all_Phi[where_leading], all_Phi[where_subleading]
    leadingJ_PID, subleadingJ_PID = all_PID[where_leading], all_PID[where_subleading]

    leadingJ_info, subleadingJ_info = np.stack((leadingJ_PT, leadingJ_Eta, leadingJ_Phi, leadingJ_PID), axis=1).ravel(), np.stack((subleadingJ_PT, subleadingJ_Eta, subleadingJ_Phi, subleadingJ_PID), axis=1).ravel()

    ##### do zero padding #####

    particle_info = np.zeros(2*20*4)
    particle_info[0:len(leadingJ_info)] = leadingJ_info
    particle_info[80:80+len(subleadingJ_info)] = subleadingJ_info
    
    return particle_info

# %%
########## preselection ##########

print("Before any selection:")
count(events)

##### 2 fat jet selection #####

for process in processes:
    events[processes.index(process)] = Fat_Jet_selection(events[processes.index(process)])
print("\nAfter 2 fat jet selection:")
count(events)

##### leading jet pT selection #####

leading_low_pT_cut = 200   ### GeV
leading_high_pT_cut = 800   ### GeV
for process in processes:
    events[processes.index(process)] = pT_leading_selection(events[processes.index(process)], leading_low_pT_cut, leading_high_pT_cut)
print("\nAfter leading jet pT selection:")
count(events)

##### subleading jet pT selection #####

subleading_low_pT_cut = 200   ### GeV
subleading_high_pT_cut = 600   ### GeV
for process in processes:
    events[processes.index(process)] = pT_subleading_selection(events[processes.index(process)], subleading_low_pT_cut, subleading_high_pT_cut)
print("\nAfter subleading jet pT selection:")
count(events)

##### leading jet mass selection #####

leading_low_mass_cut = 65
leading_high_mass_cut = 150
for process in processes:
    events[processes.index(process)] = mass_leading_selection(events[processes.index(process)], leading_low_mass_cut, leading_high_mass_cut)
print("\nAfter leading jet mass selection:")
count(events)

##### subleading jet mass selection #####

subleading_low_mass_cut = 65
subleading_high_mass_cut = 150
for process in processes:
    events[processes.index(process)] = mass_subleading_selection(events[processes.index(process)], subleading_low_mass_cut, subleading_high_mass_cut)
print("\nAfter subleading jet mass selection:")
count(events)
# Out:
# Before any selection:
# There are 100000 run_01_decayed_1 events. Corresponding cross section: 0.0036244901941248 (fb)
# There are 100000 run_02_decayed_1 events. Corresponding cross section: 0.0030163026030592005 (fb)
# There are 100000 run_03_decayed_1 events. Corresponding cross section: 0.0024746369077248004 (fb)
# There are 100000 run_04_decayed_1 events. Corresponding cross section: 0.00199875604877312 (fb)
# There are 100000 run_05_decayed_1 events. Corresponding cross section: 0.001792149223108608 (fb)
# There are 100000 run_06_decayed_1 events. Corresponding cross section: 0.0015902844059648004 (fb)
# There are 100000 run_07_decayed_1 events. Corresponding cross section: 0.00142103549952 (fb)
# There are 100000 run_08_decayed_1 events. Corresponding cross section: 0.0012596573218611202 (fb)
# There are 100000 run_09_decayed_1 events. Corresponding cross section: 0.000991051187130368 (fb)
# There are 100000 run_10_decayed_1 events. Corresponding cross section: 0.000787869974528 (fb)
# There are 100000 run_11_decayed_1 events. Corresponding cross section: 0.0006585256240209921 (fb)
#
# After 2 fat jet selection:
# There are 100000 run_01_decayed_1 events. Corresponding cross section: 0.0036244901941248 (fb)
# There are 100000 run_02_decayed_1 events. Corresponding cross section: 0.0030163026030592005 (fb)
# There are 100000 run_03_decayed_1 events. Corresponding cross section: 0.0024746369077248004 (fb)
# There are 100000 run_04_decayed_1 events. Corresponding cross section: 0.00199875604877312 (fb)
# There are 100000 run_05_decayed_1 events. Corresponding cross section: 0.001792149223108608 (fb)
# There are 100000 run_06_decayed_1 events. Corresponding cross section: 0.0015902844059648004 (fb)
# There are 100000 run_07_decayed_1 events. Corresponding cross section: 0.00142103549952 (fb)
# There are 100000 run_08_decayed_1 events. Corresponding cross section: 0.0012596573218611202 (fb)
# There are 100000 run_09_decayed_1 events. Corresponding cross section: 0.000991051187130368 (fb)
# There are 100000 run_10_decayed_1 events. Corresponding cross section: 0.000787869974528 (fb)
# There are 100000 run_11_decayed_1 events. Corresponding cross section: 0.0006585256240209921 (fb)
#
# After leading jet pT selection:
# There are 90834 run_01_decayed_1 events. Corresponding cross section: 0.0032922694229313206 (fb)
# There are 90751 run_02_decayed_1 events. Corresponding cross section: 0.002737324775302255 (fb)
# There are 90715 run_03_decayed_1 events. Corresponding cross section: 0.0022448668708425525 (fb)
# There are 90360 run_04_decayed_1 events. Corresponding cross section: 0.0018060759656713912 (fb)
# There are 90003 run_05_decayed_1 events. Corresponding cross section: 0.0016129880652744405 (fb)
# There are 89992 run_06_decayed_1 events. Corresponding cross section: 0.0014311287426158432 (fb)
# There are 89905 run_07_decayed_1 events. Corresponding cross section: 0.001277581965843456 (fb)
# There are 89649 run_08_decayed_1 events. Corresponding cross section: 0.0011292701924752757 (fb)
# There are 89111 run_09_decayed_1 events. Corresponding cross section: 0.0008831356233637422 (fb)
# There are 88845 run_10_decayed_1 events. Corresponding cross section: 0.0006999830788694017 (fb)
# There are 88519 run_11_decayed_1 events. Corresponding cross section: 0.0005829202971271419 (fb)
#
# After subleading jet pT selection:
# There are 58862 run_01_decayed_1 events. Corresponding cross section: 0.0021334474180657397 (fb)
# There are 58416 run_02_decayed_1 events. Corresponding cross section: 0.0017620033286030626 (fb)
# There are 58150 run_03_decayed_1 events. Corresponding cross section: 0.0014390013618419716 (fb)
# There are 57435 run_04_decayed_1 events. Corresponding cross section: 0.0011479855366128414 (fb)
# There are 56805 run_05_decayed_1 events. Corresponding cross section: 0.0010180303661868448 (fb)
# There are 56508 run_06_decayed_1 events. Corresponding cross section: 0.0008986379121225895 (fb)
# There are 56319 run_07_decayed_1 events. Corresponding cross section: 0.0008003129829746689 (fb)
# There are 55723 run_08_decayed_1 events. Corresponding cross section: 0.0007019188494606721 (fb)
# There are 54425 run_09_decayed_1 events. Corresponding cross section: 0.0005393796085957028 (fb)
# There are 53279 run_10_decayed_1 events. Corresponding cross section: 0.0004197692437287731 (fb)
# There are 51969 run_11_decayed_1 events. Corresponding cross section: 0.0003422291815474694 (fb)
#
# After leading jet mass selection:
# There are 45426 run_01_decayed_1 events. Corresponding cross section: 0.0016464609155831316 (fb)
# There are 44855 run_02_decayed_1 events. Corresponding cross section: 0.0013529625326022042 (fb)
# There are 44685 run_03_decayed_1 events. Corresponding cross section: 0.001105791502216827 (fb)
# There are 44190 run_04_decayed_1 events. Corresponding cross section: 0.0008832502979528418 (fb)
# There are 43613 run_05_decayed_1 events. Corresponding cross section: 0.0007816100406743573 (fb)
# There are 43287 run_06_decayed_1 events. Corresponding cross section: 0.0006883864108099832 (fb)
# There are 42899 run_07_decayed_1 events. Corresponding cross section: 0.0006096100189390849 (fb)
# There are 42631 run_08_decayed_1 events. Corresponding cross section: 0.0005370045128826141 (fb)
# There are 41278 run_09_decayed_1 events. Corresponding cross section: 0.0004090861090236733 (fb)
# There are 40312 run_10_decayed_1 events. Corresponding cross section: 0.0003176061441317274 (fb)
# There are 38946 run_11_decayed_1 events. Corresponding cross section: 0.0002564693895312156 (fb)
#
# After subleading jet mass selection:
# There are 30469 run_01_decayed_1 events. Corresponding cross section: 0.0011043459172478854 (fb)
# There are 30020 run_02_decayed_1 events. Corresponding cross section: 0.0009054940414383719 (fb)
# There are 29858 run_03_decayed_1 events. Corresponding cross section: 0.0007388770879084708 (fb)
# There are 29497 run_04_decayed_1 events. Corresponding cross section: 0.0005895730717066072 (fb)
# There are 29190 run_05_decayed_1 events. Corresponding cross section: 0.0005231283582254027 (fb)
# There are 28845 run_06_decayed_1 events. Corresponding cross section: 0.0004587175369005467 (fb)
# There are 28653 run_07_decayed_1 events. Corresponding cross section: 0.0004071693016774657 (fb)
# There are 28343 run_08_decayed_1 events. Corresponding cross section: 0.0003570246747350973 (fb)
# There are 27442 run_09_decayed_1 events. Corresponding cross section: 0.0002719642667723156 (fb)
# There are 26613 run_10_decayed_1 events. Corresponding cross section: 0.00020967583632113665 (fb)
# There are 25744 run_11_decayed_1 events. Corresponding cross section: 0.0001695308366479642 (fb)

# %%
##### generate particle information #####

particle_info = []

for process in processes:
    for event in events[processes.index(process)]:
        particle_info.append(get_particle_info(event))
    print("Time:{:^8.4f}(s)".format(time.time()-t1))
# Out:
# Time:146.7611(s)
# Time:153.5300(s)
# Time:160.2834(s)
# Time:167.1247(s)
# Time:173.8480(s)
# Time:180.4203(s)
# Time:187.0228(s)
# Time:193.5786(s)
# Time:199.8888(s)
# Time:206.0409(s)
# Time:212.0785(s)

# %%
particle_info[0]
# Out:
# array([ 3.35938721e+01,  8.90382230e-01,  6.33179724e-01,  3.00000000e+00,
#         2.40298595e+01,  1.49251533e+00,  3.63026202e-01,  3.00000000e+00,
#         2.32268448e+01,  1.53145528e+00,  4.23133790e-01,  5.00000000e+00,
#         1.85105877e+01,  1.51622987e+00,  3.87259811e-01,  5.00000000e+00,
#         1.75916004e+01,  8.59031260e-01,  6.53634489e-01,  5.00000000e+00,
#         1.66498451e+01,  1.49748564e+00,  3.98592830e-01,  5.00000000e+00,
#         1.58792229e+01,  1.49730492e+00,  3.42358291e-01,  5.00000000e+00,
#         1.56987934e+01,  8.85413885e-01,  6.07769489e-01,  5.00000000e+00,
#         1.56088037e+01,  8.61806512e-01,  6.82710052e-01,  5.00000000e+00,
#         1.54106293e+01,  1.49305689e+00,  4.03954059e-01,  3.00000000e+00,
#         1.18672237e+01,  1.52690721e+00,  3.81076962e-01,  3.00000000e+00,
#         1.14417467e+01,  1.51457870e+00,  3.87956530e-01,  3.00000000e+00,
#         1.14327955e+01,  9.01304305e-01,  6.41843319e-01,  5.00000000e+00,
#         1.14049740e+01,  9.31791663e-01,  6.66844904e-01,  5.00000000e+00,
#         1.08251953e+01,  1.47318685e+00,  4.04865950e-01,  3.00000000e+00,
#         1.04103384e+01,  8.98699522e-01,  6.47325337e-01,  5.00000000e+00,
#         8.95067883e+00,  1.56463659e+00,  5.01672029e-01,  4.00000000e+00,
#         8.64008713e+00,  1.49179852e+00,  4.16170627e-01,  3.00000000e+00,
#         6.44007206e+00,  1.28379309e+00,  5.01014054e-01,  3.00000000e+00,
#         5.99821329e+00,  8.76000345e-01,  6.41932070e-01,  3.00000000e+00,
#         1.04867401e+02, -3.19069862e-01, -2.72100210e+00,  2.00000000e+00,
#         7.23913956e+01, -2.95076758e-01, -2.71191192e+00,  5.00000000e+00,
#         2.81512566e+01, -2.93887258e-01, -2.72194004e+00,  5.00000000e+00,
#         2.16760254e+01, -1.43677533e-01,  2.71792650e+00,  4.00000000e+00,
#         2.16022453e+01, -3.04480046e-01, -2.71902871e+00,  5.00000000e+00,
#         1.68159409e+01,  2.47058589e-02,  2.81322241e+00,  4.00000000e+00,
#         1.48088446e+01, -1.56639680e-01,  2.71828294e+00,  5.00000000e+00,
#         7.93947506e+00, -3.22218746e-01, -2.65450788e+00,  5.00000000e+00,
#         7.44766760e+00, -3.79145026e-01, -2.80676150e+00,  5.00000000e+00,
#         7.34031487e+00, -1.48195907e-01,  2.68409109e+00,  3.00000000e+00,
#         5.09196711e+00, -3.02254736e-01, -2.72476935e+00,  3.00000000e+00,
#         4.01079607e+00, -1.84462070e-01,  2.33218288e+00,  5.00000000e+00,
#         3.58033252e+00, -2.37086475e-01, -2.69790530e+00,  5.00000000e+00,
#         2.41902900e+00, -1.55286238e-01,  2.72715807e+00,  3.00000000e+00,
#         2.41593075e+00, -2.67522514e-01, -2.70373774e+00,  3.00000000e+00,
#         2.15748572e+00, -1.61181297e-03,  2.80518484e+00,  3.00000000e+00,
#         2.08230829e+00, -2.25613043e-01, -2.96082449e+00,  4.00000000e+00,
#         1.36394668e+00, -8.84906054e-02,  2.67442489e+00,  3.00000000e+00,
#         1.28981411e+00, -2.74401098e-01, -2.69249558e+00,  3.00000000e+00,
#         1.28819478e+00,  3.51045907e-01,  2.83366966e+00,  5.00000000e+00])

# %%
##### output test data #####

d = {'particle_info': particle_info}
df = pd.DataFrame(data=d)
df
# Out:
#                                             particle_info
# 0       [33.5938720703125, 0.8903822302818298, 0.63317...
# 1       [43.87957763671875, -1.171006202697754, -2.409...
# 2       [35.96276092529297, -0.9760716557502747, -1.63...
# 3       [116.82451629638672, 0.26441124081611633, 0.08...
# 4       [63.6117057800293, 0.3210308849811554, 0.62128...
# ...                                                   ...
# 314669  [113.9906234741211, 0.09585023671388626, -1.26...
# 314670  [35.57377243041992, 1.4595005512237549, -1.663...
# 314671  [44.547550201416016, 1.6834325790405273, 0.058...
# 314672  [32.41587448120117, 0.32940903306007385, 0.514...
# 314673  [71.48008728027344, 0.7510918378829956, 2.9417...
#
# [314674 rows x 1 columns]

# %%
import h5py
h5f = h5py.File('/data/mucollider/two_boosted/scan_kappa3_hhmumu_LL.h5', 'w')
for key, value in d.items():
    h5f.create_dataset(key, data=value)
    print(f"已寫入 Dataset: {key}")
h5f.close()
# Out:
# 已寫入 Dataset: particle_info
