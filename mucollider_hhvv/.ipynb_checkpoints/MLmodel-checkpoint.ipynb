# %%
import time
t1 = time.time()

import math
import os
import numpy as np
import pandas as pd
import h5py
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm

import tensorflow as tf
import tensorflow.keras as keras
from tensorflow.keras import layers, models
from tensorflow.keras.optimizers import Adam , SGD , Adagrad
from tensorflow.keras.callbacks import ModelCheckpoint, LearningRateScheduler, EarlyStopping, CSVLogger, ReduceLROnPlateau
from tensorflow.keras.utils import to_categorical, plot_model
from tensorflow.keras import regularizers , initializers
from sklearn.metrics import confusion_matrix
import tensorflow.keras.backend as K
from sklearn import metrics
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split

gpus = tf.config.experimental.list_physical_devices("GPU")
tf.config.set_visible_devices(gpus[1], "GPU")

### set seed ###
keras.utils.set_random_seed(2330)
tf.config.experimental.enable_op_determinism()
# Out:
# 2026-01-27 04:44:45.995423: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
##### load data #####

HLdata_path = "/root/data/mucollider/two_boosted/data_HLfeature.h5"
HLdata_file = h5py.File(HLdata_path, 'r')
print(HLdata_file.keys())

LLdata_path = "/root/data/mucollider/two_boosted/data_LLfeature.h5"
LLdata_file = h5py.File(LLdata_path, 'r')
print(LLdata_file.keys())
# Out:
# <KeysViewHDF5 ['BTag_leading', 'BTag_subleading', 'H_0', 'H_1', 'LB_1', 'M_JJ', 'S_0', 'S_1', 'X_HH', 'dEta_JJ', 'm_J_leading', 'm_J_subleading', 'missET', 'pT_JJ', 'pt_J_leading', 'pt_J_subleading', 'target_everytype', 'target_sigbg']>
# <KeysViewHDF5 ['particle_info']>

# %%
##### include data #####

HLfeatures = ['BTag_leading', 'BTag_subleading', 'H_0', 'H_1', 'LB_1', 'M_JJ', 'S_0', 'S_1', 'X_HH', 'dEta_JJ', 'm_J_leading', 'm_J_subleading', 'missET', 'pT_JJ', 'pt_J_leading', 'pt_J_subleading']
LLfeatures = ['particle_info']

##### select BTag work point at WP70 (BitNumber 1) #####

BTag_leading = ((HLdata_file['BTag_leading'][:])&2)
BTag_subleading = ((HLdata_file['BTag_subleading'][:])&2)

##### include other high level features data #####

HLdata = []
for feature in HLfeatures:
    if feature=='BTag_leading': HLdata.append(BTag_leading)
    elif feature=='BTag_subleading': HLdata.append(BTag_subleading)
    else: HLdata.append(HLdata_file[feature][:])
HLdata = np.array(HLdata).T
print('shape of high level data:', HLdata.shape)

LLdata = LLdata_file['particle_info'][:]
print('shape of low level data:', LLdata.shape)

target = HLdata_file['target_sigbg'][:]
print('shape of target:', target.shape)

#### Do training data and validation data split #####

HL_train, HL_val, LL_train, LL_val, y_train, y_val = train_test_split(HLdata, LLdata, target, test_size=0.2, random_state=2330, shuffle=True)
print("\nAfter training validation data split:")
print("HL training data: ", HL_train.shape, "HL validation data: ", HL_val.shape)
print("LL training data: ", LL_train.shape, "LL validation data: ", LL_val.shape)
print("training target: ", y_train.shape, "validation target: ", y_val.shape)
# Out:
# shape of high level data: (733359, 16)
# shape of low level data: (733359, 160)
# shape of target: (733359,)
#
# After training validation data split:
# HL training data:  (586687, 16) HL validation data:  (146672, 16)
# LL training data:  (586687, 160) LL validation data:  (146672, 160)
# training target:  (586687,) validation target:  (146672,)

# %%
##### construct model #####

### high level features part ###

HL_input = layers.Input(shape=(16,), name='HL_Input')

x_hl = layers.Dense(128)(HL_input)
x_hl = layers.BatchNormalization()(x_hl)
x_hl = layers.Activation('relu')(x_hl)
x_hl = layers.Dropout(0.1)(x_hl)

x_hl = layers.Dense(128)(x_hl)
x_hl = layers.BatchNormalization()(x_hl)
x_hl = layers.Activation('relu')(x_hl)
x_hl = layers.Dropout(0.1)(x_hl)

### low level features part ###

LL_input = layers.Input(shape=(160,), name='LL_Input')

x_ll = layers.Dense(512)(LL_input)
x_ll = layers.BatchNormalization()(x_ll)
x_ll = layers.Activation('relu')(x_ll)
x_ll = layers.Dropout(0.1)(x_ll)

x_ll = layers.Dense(128)(x_ll)
x_ll = layers.BatchNormalization()(x_ll)
x_ll = layers.Activation('relu')(x_ll)
x_ll = layers.Dropout(0.1)(x_ll)

### combine two parts of model and the following node ###

combined = layers.Concatenate()([x_hl, x_ll])

x = layers.Dense(256, activation='relu')(combined)
x = layers.Dense(16, activation='relu')(x)
output = layers.Dense(1, activation='sigmoid', name='Output')(x)

model = models.Model(inputs=[HL_input, LL_input], outputs=output)

### optimizer ###

opt = keras.optimizers.Adam(learning_rate=1e-5)

### compile ###

model.compile(loss='binary_crossentropy', optimizer=opt, metrics=["accuracy","mse"])

### summary ###

model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  HL_Input (InputLayer)       [(None, 16)]                 0         []
#
#  LL_Input (InputLayer)       [(None, 160)]                0         []
#
#  dense (Dense)               (None, 128)                  2176      ['HL_Input[0][0]']
#
#  dense_2 (Dense)             (None, 512)                  82432     ['LL_Input[0][0]']
#
#  batch_normalization (Batch  (None, 128)                  512       ['dense[0][0]']
#  Normalization)
#
#  batch_normalization_2 (Bat  (None, 512)                  2048      ['dense_2[0][0]']
#  chNormalization)
#
#  activation (Activation)     (None, 128)                  0         ['batch_normalization[0][0]']
#
#  activation_2 (Activation)   (None, 512)                  0         ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  dropout (Dropout)           (None, 128)                  0         ['activation[0][0]']
#
#  dropout_2 (Dropout)         (None, 512)                  0         ['activation_2[0][0]']
#
#  dense_1 (Dense)             (None, 128)                  16512     ['dropout[0][0]']
#
#  dense_3 (Dense)             (None, 128)                  65664     ['dropout_2[0][0]']
#
#  batch_normalization_1 (Bat  (None, 128)                  512       ['dense_1[0][0]']
#  chNormalization)
#
#  batch_normalization_3 (Bat  (None, 128)                  512       ['dense_3[0][0]']
#  chNormalization)
#
#  activation_1 (Activation)   (None, 128)                  0         ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  activation_3 (Activation)   (None, 128)                  0         ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  dropout_1 (Dropout)         (None, 128)                  0         ['activation_1[0][0]']
#
#  dropout_3 (Dropout)         (None, 128)                  0         ['activation_3[0][0]']
#
#  concatenate (Concatenate)   (None, 256)                  0         ['dropout_1[0][0]',
#                                                                      'dropout_3[0][0]']
#
#  dense_4 (Dense)             (None, 256)                  65792     ['concatenate[0][0]']
#
#  dense_5 (Dense)             (None, 16)                   4112      ['dense_4[0][0]']
#
#  Output (Dense)              (None, 1)                    17        ['dense_5[0][0]']
#
# ==================================================================================================
# Total params: 240289 (938.63 KB)
# Trainable params: 238497 (931.63 KB)
# Non-trainable params: 1792 (7.00 KB)
# __________________________________________________________________________________________________
# 2026-01-27 04:44:49.949504: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 46696 MB memory:  -> device: 1, name: NVIDIA RTX A6000, pci bus id: 0000:25:00.0, compute capability: 8.6

# %%
##### training model #####

tr_model = model.fit(x=[HL_train, LL_train], y=y_train, validation_data=([HL_val, LL_val], y_val), epochs=128, batch_size=256, verbose=1)
# Out:
# Epoch 1/128
# 2026-01-27 04:44:55.026520: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:606] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2026-01-27 04:44:55.033370: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x55df4f40e4c0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2026-01-27 04:44:55.033413: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA RTX A6000, Compute Capability 8.6
# 2026-01-27 04:44:55.041627: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:255] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2026-01-27 04:44:55.392867: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:432] Loaded cuDNN version 8600
# 2026-01-27 04:44:55.509130: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 2292/2292 [==============================] - 25s 8ms/step - loss: 0.3235 - accuracy: 0.8539 - mse: 0.1025 - val_loss: 0.1745 - val_accuracy: 0.9368 - val_mse: 0.0495
# Epoch 2/128
# 2292/2292 [==============================] - 20s 9ms/step - loss: 0.1765 - accuracy: 0.9325 - mse: 0.0510 - val_loss: 0.1262 - val_accuracy: 0.9556 - val_mse: 0.0348
# Epoch 3/128
# 2292/2292 [==============================] - 20s 9ms/step - loss: 0.1494 - accuracy: 0.9444 - mse: 0.0423 - val_loss: 0.1141 - val_accuracy: 0.9600 - val_mse: 0.0313
# Epoch 4/128
# 2292/2292 [==============================] - 20s 9ms/step - loss: 0.1346 - accuracy: 0.9508 - mse: 0.0378 - val_loss: 0.1056 - val_accuracy: 0.9630 - val_mse: 0.0288
# Epoch 5/128
# 2292/2292 [==============================] - 20s 9ms/step - loss: 0.1235 - accuracy: 0.9550 - mse: 0.0345 - val_loss: 0.0987 - val_accuracy: 0.9655 - val_mse: 0.0269
# Epoch 6/128
# 2292/2292 [==============================] - 20s 9ms/step - loss: 0.1150 - accuracy: 0.9584 - mse: 0.0319 - val_loss: 0.0908 - val_accuracy: 0.9687 - val_mse: 0.0246
# Epoch 7/128
# 2292/2292 [==============================] - 20s 9ms/step - loss: 0.1057 - accuracy: 0.9623 - mse: 0.0292 - val_loss: 0.0827 - val_accuracy: 0.9715 - val_mse: 0.0223
# Epoch 8/128
# 2292/2292 [==============================] - 19s 8ms/step - loss: 0.0971 - accuracy: 0.9658 - mse: 0.0266 - val_loss: 0.0752 - val_accuracy: 0.9743 - val_mse: 0.0202
# Epoch 9/128
# 2292/2292 [==============================] - 20s 9ms/step - loss: 0.0897 - accuracy: 0.9688 - mse: 0.0244 - val_loss: 0.0686 - val_accuracy: 0.9767 - val_mse: 0.0183
# Epoch 10/128
# 2292/2292 [==============================] - 19s 8ms/step - loss: 0.0833 - accuracy: 0.9714 - mse: 0.0225 - val_loss: 0.0632 - val_accuracy: 0.9784 - val_mse: 0.0169
# Epoch 11/128
# 2292/2292 [==============================] - 19s 8ms/step - loss: 0.0774 - accuracy: 0.9733 - mse: 0.0208 - val_loss: 0.0584 - val_accuracy: 0.9800 - val_mse: 0.0156
# Epoch 12/128
# 2292/2292 [==============================] - 19s 8ms/step - loss: 0.0734 - accuracy: 0.9748 - mse: 0.0198 - val_loss: 0.0550 - val_accuracy: 0.9811 - val_mse: 0.0147
# Epoch 13/128
# 2292/2292 [==============================] - 19s 8ms/step - loss: 0.0692 - accuracy: 0.9761 - mse: 0.0187 - val_loss: 0.0525 - val_accuracy: 0.9819 - val_mse: 0.0141
# Epoch 14/128
# 2292/2292 [==============================] - 19s 8ms/step - loss: 0.0654 - accuracy: 0.9776 - mse: 0.0176 - val_loss: 0.0496 - val_accuracy: 0.9829 - val_mse: 0.0133
# Epoch 15/128
# 2292/2292 [==============================] - 19s 8ms/step - loss: 0.0634 - accuracy: 0.9782 - mse: 0.0170 - val_loss: 0.0470 - val_accuracy: 0.9837 - val_mse: 0.0126
# Epoch 16/128
# 2292/2292 [==============================] - 20s 9ms/step - loss: 0.0610 - accuracy: 0.9790 - mse: 0.0164 - val_loss: 0.0454 - val_accuracy: 0.9844 - val_mse: 0.0122
# Epoch 17/128
# 2292/2292 [==============================] - 20s 9ms/step - loss: 0.0588 - accuracy: 0.9798 - mse: 0.0158 - val_loss: 0.0436 - val_accuracy: 0.9850 - val_mse: 0.0117
# Epoch 18/128
# 2292/2292 [==============================] - 19s 8ms/step - loss: 0.0568 - accuracy: 0.9803 - mse: 0.0153 - val_loss: 0.0429 - val_accuracy: 0.9850 - val_mse: 0.0116
# Epoch 19/128
# 2292/2292 [==============================] - 19s 8ms/step - loss: 0.0557 - accuracy: 0.9808 - mse: 0.0150 - val_loss: 0.0414 - val_accuracy: 0.9857 - val_mse: 0.0112
# Epoch 20/128
# 2292/2292 [==============================] - 19s 8ms/step - loss: 0.0538 - accuracy: 0.9812 - mse: 0.0146 - val_loss: 0.0405 - val_accuracy: 0.9860 - val_mse: 0.0110
# Epoch 21/128
# 2292/2292 [==============================] - 20s 9ms/step - loss: 0.0530 - accuracy: 0.9816 - mse: 0.0143 - val_loss: 0.0396 - val_accuracy: 0.9863 - val_mse: 0.0107
# Epoch 22/128
# 2292/2292 [==============================] - 21s 9ms/step - loss: 0.0518 - accuracy: 0.9819 - mse: 0.0140 - val_loss: 0.0392 - val_accuracy: 0.9863 - val_mse: 0.0107
# Epoch 23/128
# 2292/2292 [==============================] - 21s 9ms/step - loss: 0.0507 - accuracy: 0.9823 - mse: 0.0138 - val_loss: 0.0380 - val_accuracy: 0.9868 - val_mse: 0.0103
# Epoch 24/128
# 2292/2292 [==============================] - 20s 9ms/step - loss: 0.0499 - accuracy: 0.9826 - mse: 0.0135 - val_loss: 0.0384 - val_accuracy: 0.9866 - val_mse: 0.0105
# Epoch 25/128
# 2292/2292 [==============================] - 20s 9ms/step - loss: 0.0489 - accuracy: 0.9829 - mse: 0.0133 - val_loss: 0.0380 - val_accuracy: 0.9867 - val_mse: 0.0104
# Epoch 26/128
# 2292/2292 [==============================] - 21s 9ms/step - loss: 0.0482 - accuracy: 0.9832 - mse: 0.0131 - val_loss: 0.0372 - val_accuracy: 0.9870 - val_mse: 0.0102
# Epoch 27/128
# 2292/2292 [==============================] - 20s 9ms/step - loss: 0.0477 - accuracy: 0.9833 - mse: 0.0129 - val_loss: 0.0365 - val_accuracy: 0.9872 - val_mse: 0.0100
# Epoch 28/128
# 2292/2292 [==============================] - 20s 9ms/step - loss: 0.0472 - accuracy: 0.9833 - mse: 0.0128 - val_loss: 0.0364 - val_accuracy: 0.9872 - val_mse: 0.0099
# Epoch 29/128
# 2292/2292 [==============================] - 20s 9ms/step - loss: 0.0464 - accuracy: 0.9837 - mse: 0.0126 - val_loss: 0.0361 - val_accuracy: 0.9873 - val_mse: 0.0099
# Epoch 30/128
# 2292/2292 [==============================] - 20s 9ms/step - loss: 0.0461 - accuracy: 0.9840 - mse: 0.0125 - val_loss: 0.0355 - val_accuracy: 0.9876 - val_mse: 0.0097
# Epoch 31/128
# 2292/2292 [==============================] - 21s 9ms/step - loss: 0.0453 - accuracy: 0.9841 - mse: 0.0123 - val_loss: 0.0352 - val_accuracy: 0.9876 - val_mse: 0.0096
# Epoch 32/128
# 2292/2292 [==============================] - 20s 9ms/step - loss: 0.0451 - accuracy: 0.9841 - mse: 0.0123 - val_loss: 0.0355 - val_accuracy: 0.9875 - val_mse: 0.0097
# Epoch 33/128
# 2292/2292 [==============================] - 21s 9ms/step - loss: 0.0446 - accuracy: 0.9843 - mse: 0.0121 - val_loss: 0.0347 - val_accuracy: 0.9878 - val_mse: 0.0095
# Epoch 34/128
# 2292/2292 [==============================] - 20s 9ms/step - loss: 0.0437 - accuracy: 0.9845 - mse: 0.0119 - val_loss: 0.0346 - val_accuracy: 0.9878 - val_mse: 0.0095
# Epoch 35/128
# 2292/2292 [==============================] - 20s 9ms/step - loss: 0.0434 - accuracy: 0.9846 - mse: 0.0118 - val_loss: 0.0344 - val_accuracy: 0.9878 - val_mse: 0.0094
# Epoch 36/128
# 2292/2292 [==============================] - 21s 9ms/step - loss: 0.0432 - accuracy: 0.9847 - mse: 0.0118 - val_loss: 0.0346 - val_accuracy: 0.9878 - val_mse: 0.0095
# Epoch 37/128
# 2292/2292 [==============================] - 20s 9ms/step - loss: 0.0430 - accuracy: 0.9848 - mse: 0.0117 - val_loss: 0.0339 - val_accuracy: 0.9880 - val_mse: 0.0092
# Epoch 38/128
# 2292/2292 [==============================] - 19s 8ms/step - loss: 0.0426 - accuracy: 0.9850 - mse: 0.0115 - val_loss: 0.0339 - val_accuracy: 0.9881 - val_mse: 0.0093
# Epoch 39/128
# 2292/2292 [==============================] - 19s 8ms/step - loss: 0.0426 - accuracy: 0.9849 - mse: 0.0116 - val_loss: 0.0338 - val_accuracy: 0.9880 - val_mse: 0.0092
# Epoch 40/128
# 2292/2292 [==============================] - 19s 8ms/step - loss: 0.0422 - accuracy: 0.9850 - mse: 0.0115 - val_loss: 0.0341 - val_accuracy: 0.9878 - val_mse: 0.0093
# Epoch 41/128
# 2292/2292 [==============================] - 19s 8ms/step - loss: 0.0419 - accuracy: 0.9852 - mse: 0.0114 - val_loss: 0.0337 - val_accuracy: 0.9881 - val_mse: 0.0092
# Epoch 42/128
# 2292/2292 [==============================] - 19s 8ms/step - loss: 0.0415 - accuracy: 0.9853 - mse: 0.0113 - val_loss: 0.0336 - val_accuracy: 0.9881 - val_mse: 0.0092
# Epoch 43/128
# 2292/2292 [==============================] - 19s 8ms/step - loss: 0.0414 - accuracy: 0.9852 - mse: 0.0113 - val_loss: 0.0332 - val_accuracy: 0.9883 - val_mse: 0.0091
# Epoch 44/128
# 2292/2292 [==============================] - 19s 8ms/step - loss: 0.0410 - accuracy: 0.9856 - mse: 0.0111 - val_loss: 0.0339 - val_accuracy: 0.9881 - val_mse: 0.0093
# Epoch 45/128
# 2292/2292 [==============================] - 19s 8ms/step - loss: 0.0410 - accuracy: 0.9855 - mse: 0.0112 - val_loss: 0.0333 - val_accuracy: 0.9882 - val_mse: 0.0091
# Epoch 46/128
# 2292/2292 [==============================] - 19s 8ms/step - loss: 0.0406 - accuracy: 0.9856 - mse: 0.0111 - val_loss: 0.0330 - val_accuracy: 0.9883 - val_mse: 0.0090
# Epoch 47/128
# 2292/2292 [==============================] - 20s 9ms/step - loss: 0.0402 - accuracy: 0.9857 - mse: 0.0110 - val_loss: 0.0328 - val_accuracy: 0.9882 - val_mse: 0.0090
# Epoch 48/128
# 2292/2292 [==============================] - 20s 9ms/step - loss: 0.0398 - accuracy: 0.9860 - mse: 0.0109 - val_loss: 0.0330 - val_accuracy: 0.9882 - val_mse: 0.0090
# Epoch 49/128
# 2292/2292 [==============================] - 19s 8ms/step - loss: 0.0399 - accuracy: 0.9860 - mse: 0.0108 - val_loss: 0.0327 - val_accuracy: 0.9883 - val_mse: 0.0090
# Epoch 50/128
# 2292/2292 [==============================] - 20s 9ms/step - loss: 0.0401 - accuracy: 0.9859 - mse: 0.0109 - val_loss: 0.0327 - val_accuracy: 0.9884 - val_mse: 0.0089
# Epoch 51/128
# 2292/2292 [==============================] - 20s 9ms/step - loss: 0.0398 - accuracy: 0.9860 - mse: 0.0108 - val_loss: 0.0330 - val_accuracy: 0.9882 - val_mse: 0.0090
# Epoch 52/128
# 2292/2292 [==============================] - 20s 9ms/step - loss: 0.0393 - accuracy: 0.9860 - mse: 0.0107 - val_loss: 0.0329 - val_accuracy: 0.9882 - val_mse: 0.0090
# Epoch 53/128
# 2292/2292 [==============================] - 20s 9ms/step - loss: 0.0390 - accuracy: 0.9862 - mse: 0.0106 - val_loss: 0.0328 - val_accuracy: 0.9883 - val_mse: 0.0090
# Epoch 54/128
# 2292/2292 [==============================] - 20s 9ms/step - loss: 0.0390 - accuracy: 0.9861 - mse: 0.0107 - val_loss: 0.0325 - val_accuracy: 0.9884 - val_mse: 0.0089
# Epoch 55/128
# 2292/2292 [==============================] - 19s 8ms/step - loss: 0.0389 - accuracy: 0.9862 - mse: 0.0106 - val_loss: 0.0320 - val_accuracy: 0.9886 - val_mse: 0.0087
# Epoch 56/128
# 2292/2292 [==============================] - 19s 8ms/step - loss: 0.0385 - accuracy: 0.9864 - mse: 0.0105 - val_loss: 0.0320 - val_accuracy: 0.9885 - val_mse: 0.0088
# Epoch 57/128
# 2292/2292 [==============================] - 21s 9ms/step - loss: 0.0389 - accuracy: 0.9863 - mse: 0.0106 - val_loss: 0.0325 - val_accuracy: 0.9884 - val_mse: 0.0089
# Epoch 58/128
# 2292/2292 [==============================] - 20s 9ms/step - loss: 0.0381 - accuracy: 0.9866 - mse: 0.0104 - val_loss: 0.0320 - val_accuracy: 0.9886 - val_mse: 0.0088
# Epoch 59/128
# 2292/2292 [==============================] - 20s 9ms/step - loss: 0.0382 - accuracy: 0.9866 - mse: 0.0104 - val_loss: 0.0321 - val_accuracy: 0.9885 - val_mse: 0.0088
# Epoch 60/128
# 2292/2292 [==============================] - 20s 9ms/step - loss: 0.0380 - accuracy: 0.9867 - mse: 0.0103 - val_loss: 0.0323 - val_accuracy: 0.9885 - val_mse: 0.0089
# Epoch 61/128
# 2292/2292 [==============================] - 21s 9ms/step - loss: 0.0374 - accuracy: 0.9867 - mse: 0.0102 - val_loss: 0.0320 - val_accuracy: 0.9886 - val_mse: 0.0088
# Epoch 62/128
# 2292/2292 [==============================] - 22s 9ms/step - loss: 0.0375 - accuracy: 0.9867 - mse: 0.0102 - val_loss: 0.0319 - val_accuracy: 0.9886 - val_mse: 0.0087
# Epoch 63/128
# 2292/2292 [==============================] - 22s 9ms/step - loss: 0.0375 - accuracy: 0.9867 - mse: 0.0102 - val_loss: 0.0323 - val_accuracy: 0.9884 - val_mse: 0.0089
# Epoch 64/128
# 2292/2292 [==============================] - 20s 9ms/step - loss: 0.0374 - accuracy: 0.9867 - mse: 0.0102 - val_loss: 0.0322 - val_accuracy: 0.9886 - val_mse: 0.0088
# Epoch 65/128
# 2292/2292 [==============================] - 20s 9ms/step - loss: 0.0372 - accuracy: 0.9869 - mse: 0.0101 - val_loss: 0.0323 - val_accuracy: 0.9885 - val_mse: 0.0089
# Epoch 66/128
# 2292/2292 [==============================] - 21s 9ms/step - loss: 0.0372 - accuracy: 0.9870 - mse: 0.0101 - val_loss: 0.0316 - val_accuracy: 0.9887 - val_mse: 0.0087
# Epoch 67/128
# 2292/2292 [==============================] - 21s 9ms/step - loss: 0.0370 - accuracy: 0.9869 - mse: 0.0101 - val_loss: 0.0316 - val_accuracy: 0.9888 - val_mse: 0.0086
# Epoch 68/128
# 2292/2292 [==============================] - 22s 9ms/step - loss: 0.0368 - accuracy: 0.9869 - mse: 0.0100 - val_loss: 0.0316 - val_accuracy: 0.9888 - val_mse: 0.0087
# Epoch 69/128
# 2292/2292 [==============================] - 21s 9ms/step - loss: 0.0363 - accuracy: 0.9872 - mse: 0.0099 - val_loss: 0.0318 - val_accuracy: 0.9886 - val_mse: 0.0087
# Epoch 70/128
# 2292/2292 [==============================] - 22s 9ms/step - loss: 0.0365 - accuracy: 0.9872 - mse: 0.0099 - val_loss: 0.0315 - val_accuracy: 0.9888 - val_mse: 0.0086
# Epoch 71/128
# 2292/2292 [==============================] - 22s 9ms/step - loss: 0.0363 - accuracy: 0.9872 - mse: 0.0099 - val_loss: 0.0318 - val_accuracy: 0.9887 - val_mse: 0.0087
# Epoch 72/128
# 2292/2292 [==============================] - 21s 9ms/step - loss: 0.0362 - accuracy: 0.9871 - mse: 0.0099 - val_loss: 0.0313 - val_accuracy: 0.9889 - val_mse: 0.0086
# Epoch 73/128
# 2292/2292 [==============================] - 21s 9ms/step - loss: 0.0363 - accuracy: 0.9871 - mse: 0.0099 - val_loss: 0.0318 - val_accuracy: 0.9887 - val_mse: 0.0087
# Epoch 74/128
# 2292/2292 [==============================] - 21s 9ms/step - loss: 0.0364 - accuracy: 0.9872 - mse: 0.0099 - val_loss: 0.0322 - val_accuracy: 0.9886 - val_mse: 0.0088
# Epoch 75/128
# 2292/2292 [==============================] - 21s 9ms/step - loss: 0.0359 - accuracy: 0.9873 - mse: 0.0098 - val_loss: 0.0312 - val_accuracy: 0.9889 - val_mse: 0.0085
# Epoch 76/128
# 2292/2292 [==============================] - 21s 9ms/step - loss: 0.0358 - accuracy: 0.9874 - mse: 0.0097 - val_loss: 0.0312 - val_accuracy: 0.9890 - val_mse: 0.0085
# Epoch 77/128
# 2292/2292 [==============================] - 21s 9ms/step - loss: 0.0357 - accuracy: 0.9874 - mse: 0.0097 - val_loss: 0.0314 - val_accuracy: 0.9889 - val_mse: 0.0086
# Epoch 78/128
# 2292/2292 [==============================] - 21s 9ms/step - loss: 0.0357 - accuracy: 0.9875 - mse: 0.0097 - val_loss: 0.0314 - val_accuracy: 0.9889 - val_mse: 0.0086
# Epoch 79/128
# 2292/2292 [==============================] - 21s 9ms/step - loss: 0.0356 - accuracy: 0.9873 - mse: 0.0097 - val_loss: 0.0312 - val_accuracy: 0.9889 - val_mse: 0.0085
# Epoch 80/128
# 2292/2292 [==============================] - 21s 9ms/step - loss: 0.0353 - accuracy: 0.9874 - mse: 0.0096 - val_loss: 0.0310 - val_accuracy: 0.9890 - val_mse: 0.0085
# Epoch 81/128
# 2292/2292 [==============================] - 21s 9ms/step - loss: 0.0350 - accuracy: 0.9875 - mse: 0.0095 - val_loss: 0.0314 - val_accuracy: 0.9888 - val_mse: 0.0086
# Epoch 82/128
# 2292/2292 [==============================] - 21s 9ms/step - loss: 0.0351 - accuracy: 0.9874 - mse: 0.0096 - val_loss: 0.0308 - val_accuracy: 0.9891 - val_mse: 0.0084
# Epoch 83/128
# 2292/2292 [==============================] - 21s 9ms/step - loss: 0.0351 - accuracy: 0.9875 - mse: 0.0096 - val_loss: 0.0309 - val_accuracy: 0.9890 - val_mse: 0.0085
# Epoch 84/128
# 2292/2292 [==============================] - 21s 9ms/step - loss: 0.0350 - accuracy: 0.9877 - mse: 0.0095 - val_loss: 0.0309 - val_accuracy: 0.9889 - val_mse: 0.0085
# Epoch 85/128
# 2292/2292 [==============================] - 21s 9ms/step - loss: 0.0349 - accuracy: 0.9877 - mse: 0.0095 - val_loss: 0.0307 - val_accuracy: 0.9891 - val_mse: 0.0084
# Epoch 86/128
# 2292/2292 [==============================] - 21s 9ms/step - loss: 0.0345 - accuracy: 0.9877 - mse: 0.0094 - val_loss: 0.0309 - val_accuracy: 0.9891 - val_mse: 0.0084
# Epoch 87/128
# 2292/2292 [==============================] - 20s 9ms/step - loss: 0.0348 - accuracy: 0.9876 - mse: 0.0095 - val_loss: 0.0310 - val_accuracy: 0.9891 - val_mse: 0.0085
# Epoch 88/128
# 2292/2292 [==============================] - 21s 9ms/step - loss: 0.0342 - accuracy: 0.9880 - mse: 0.0093 - val_loss: 0.0308 - val_accuracy: 0.9890 - val_mse: 0.0084
# Epoch 89/128
# 2292/2292 [==============================] - 20s 9ms/step - loss: 0.0345 - accuracy: 0.9877 - mse: 0.0094 - val_loss: 0.0308 - val_accuracy: 0.9891 - val_mse: 0.0084
# Epoch 90/128
# 2292/2292 [==============================] - 20s 9ms/step - loss: 0.0343 - accuracy: 0.9879 - mse: 0.0093 - val_loss: 0.0308 - val_accuracy: 0.9890 - val_mse: 0.0084
# Epoch 91/128
# 2292/2292 [==============================] - 20s 9ms/step - loss: 0.0340 - accuracy: 0.9880 - mse: 0.0093 - val_loss: 0.0310 - val_accuracy: 0.9890 - val_mse: 0.0085
# Epoch 92/128
# 2292/2292 [==============================] - 21s 9ms/step - loss: 0.0338 - accuracy: 0.9880 - mse: 0.0092 - val_loss: 0.0307 - val_accuracy: 0.9892 - val_mse: 0.0084
# Epoch 93/128
# 2292/2292 [==============================] - 20s 9ms/step - loss: 0.0339 - accuracy: 0.9879 - mse: 0.0093 - val_loss: 0.0304 - val_accuracy: 0.9892 - val_mse: 0.0083
# Epoch 94/128
# 2292/2292 [==============================] - 21s 9ms/step - loss: 0.0336 - accuracy: 0.9880 - mse: 0.0092 - val_loss: 0.0308 - val_accuracy: 0.9892 - val_mse: 0.0084
# Epoch 95/128
# 2292/2292 [==============================] - 20s 9ms/step - loss: 0.0341 - accuracy: 0.9878 - mse: 0.0093 - val_loss: 0.0309 - val_accuracy: 0.9890 - val_mse: 0.0085
# Epoch 96/128
# 2292/2292 [==============================] - 20s 9ms/step - loss: 0.0336 - accuracy: 0.9881 - mse: 0.0091 - val_loss: 0.0308 - val_accuracy: 0.9891 - val_mse: 0.0084
# Epoch 97/128
# 2292/2292 [==============================] - 20s 9ms/step - loss: 0.0336 - accuracy: 0.9880 - mse: 0.0092 - val_loss: 0.0305 - val_accuracy: 0.9892 - val_mse: 0.0083
# Epoch 98/128
# 2292/2292 [==============================] - 20s 9ms/step - loss: 0.0335 - accuracy: 0.9880 - mse: 0.0092 - val_loss: 0.0308 - val_accuracy: 0.9891 - val_mse: 0.0084
# Epoch 99/128
# 2292/2292 [==============================] - 20s 9ms/step - loss: 0.0333 - accuracy: 0.9882 - mse: 0.0091 - val_loss: 0.0307 - val_accuracy: 0.9892 - val_mse: 0.0084
# Epoch 100/128
# 2292/2292 [==============================] - 20s 9ms/step - loss: 0.0334 - accuracy: 0.9882 - mse: 0.0091 - val_loss: 0.0304 - val_accuracy: 0.9893 - val_mse: 0.0083
# Epoch 101/128
# 2292/2292 [==============================] - 20s 9ms/step - loss: 0.0331 - accuracy: 0.9882 - mse: 0.0091 - val_loss: 0.0304 - val_accuracy: 0.9892 - val_mse: 0.0083
# Epoch 102/128
# 2292/2292 [==============================] - 21s 9ms/step - loss: 0.0332 - accuracy: 0.9882 - mse: 0.0091 - val_loss: 0.0304 - val_accuracy: 0.9891 - val_mse: 0.0083
# Epoch 103/128
# 2292/2292 [==============================] - 20s 9ms/step - loss: 0.0329 - accuracy: 0.9883 - mse: 0.0090 - val_loss: 0.0302 - val_accuracy: 0.9894 - val_mse: 0.0083
# Epoch 104/128
# 2292/2292 [==============================] - 20s 9ms/step - loss: 0.0329 - accuracy: 0.9882 - mse: 0.0090 - val_loss: 0.0306 - val_accuracy: 0.9892 - val_mse: 0.0083
# Epoch 105/128
# 2292/2292 [==============================] - 20s 9ms/step - loss: 0.0330 - accuracy: 0.9882 - mse: 0.0090 - val_loss: 0.0307 - val_accuracy: 0.9892 - val_mse: 0.0084
# Epoch 106/128
# 2292/2292 [==============================] - 20s 9ms/step - loss: 0.0329 - accuracy: 0.9883 - mse: 0.0090 - val_loss: 0.0307 - val_accuracy: 0.9891 - val_mse: 0.0084
# Epoch 107/128
# 2292/2292 [==============================] - 20s 9ms/step - loss: 0.0326 - accuracy: 0.9885 - mse: 0.0089 - val_loss: 0.0305 - val_accuracy: 0.9892 - val_mse: 0.0083
# Epoch 108/128
# 2292/2292 [==============================] - 20s 9ms/step - loss: 0.0328 - accuracy: 0.9884 - mse: 0.0090 - val_loss: 0.0303 - val_accuracy: 0.9892 - val_mse: 0.0083
# Epoch 109/128
# 2292/2292 [==============================] - 20s 9ms/step - loss: 0.0324 - accuracy: 0.9885 - mse: 0.0089 - val_loss: 0.0302 - val_accuracy: 0.9892 - val_mse: 0.0082
# Epoch 110/128
# 2292/2292 [==============================] - 20s 9ms/step - loss: 0.0324 - accuracy: 0.9885 - mse: 0.0088 - val_loss: 0.0309 - val_accuracy: 0.9891 - val_mse: 0.0085
# Epoch 111/128
# 2292/2292 [==============================] - 20s 9ms/step - loss: 0.0323 - accuracy: 0.9885 - mse: 0.0088 - val_loss: 0.0303 - val_accuracy: 0.9892 - val_mse: 0.0083
# Epoch 112/128
# 2292/2292 [==============================] - 20s 9ms/step - loss: 0.0322 - accuracy: 0.9885 - mse: 0.0088 - val_loss: 0.0306 - val_accuracy: 0.9893 - val_mse: 0.0083
# Epoch 113/128
# 2292/2292 [==============================] - 20s 9ms/step - loss: 0.0322 - accuracy: 0.9885 - mse: 0.0088 - val_loss: 0.0300 - val_accuracy: 0.9893 - val_mse: 0.0082
# Epoch 114/128
# 2292/2292 [==============================] - 20s 9ms/step - loss: 0.0320 - accuracy: 0.9886 - mse: 0.0087 - val_loss: 0.0306 - val_accuracy: 0.9893 - val_mse: 0.0083
# Epoch 115/128
# 2292/2292 [==============================] - 20s 9ms/step - loss: 0.0317 - accuracy: 0.9887 - mse: 0.0087 - val_loss: 0.0302 - val_accuracy: 0.9893 - val_mse: 0.0083
# Epoch 116/128
# 2292/2292 [==============================] - 20s 9ms/step - loss: 0.0318 - accuracy: 0.9886 - mse: 0.0087 - val_loss: 0.0305 - val_accuracy: 0.9892 - val_mse: 0.0083
# Epoch 117/128
# 2292/2292 [==============================] - 20s 9ms/step - loss: 0.0319 - accuracy: 0.9886 - mse: 0.0087 - val_loss: 0.0302 - val_accuracy: 0.9893 - val_mse: 0.0083
# Epoch 118/128
# 2292/2292 [==============================] - 20s 9ms/step - loss: 0.0317 - accuracy: 0.9887 - mse: 0.0087 - val_loss: 0.0304 - val_accuracy: 0.9893 - val_mse: 0.0083
# Epoch 119/128
# 2292/2292 [==============================] - 20s 9ms/step - loss: 0.0315 - accuracy: 0.9887 - mse: 0.0086 - val_loss: 0.0305 - val_accuracy: 0.9892 - val_mse: 0.0083
# Epoch 120/128
# 2292/2292 [==============================] - 20s 9ms/step - loss: 0.0316 - accuracy: 0.9886 - mse: 0.0087 - val_loss: 0.0301 - val_accuracy: 0.9895 - val_mse: 0.0082
# Epoch 121/128
# 2292/2292 [==============================] - 20s 9ms/step - loss: 0.0316 - accuracy: 0.9887 - mse: 0.0087 - val_loss: 0.0304 - val_accuracy: 0.9893 - val_mse: 0.0083
# Epoch 122/128
# 2292/2292 [==============================] - 20s 9ms/step - loss: 0.0311 - accuracy: 0.9889 - mse: 0.0085 - val_loss: 0.0303 - val_accuracy: 0.9893 - val_mse: 0.0083
# Epoch 123/128
# 2292/2292 [==============================] - 21s 9ms/step - loss: 0.0313 - accuracy: 0.9887 - mse: 0.0086 - val_loss: 0.0302 - val_accuracy: 0.9894 - val_mse: 0.0083
# Epoch 124/128
# 2292/2292 [==============================] - 20s 9ms/step - loss: 0.0313 - accuracy: 0.9888 - mse: 0.0086 - val_loss: 0.0298 - val_accuracy: 0.9895 - val_mse: 0.0082
# Epoch 125/128
# 2292/2292 [==============================] - 20s 9ms/step - loss: 0.0313 - accuracy: 0.9889 - mse: 0.0086 - val_loss: 0.0299 - val_accuracy: 0.9895 - val_mse: 0.0082
# Epoch 126/128
# 2292/2292 [==============================] - 20s 9ms/step - loss: 0.0313 - accuracy: 0.9888 - mse: 0.0086 - val_loss: 0.0300 - val_accuracy: 0.9895 - val_mse: 0.0082
# Epoch 127/128
# 2292/2292 [==============================] - 20s 9ms/step - loss: 0.0310 - accuracy: 0.9890 - mse: 0.0085 - val_loss: 0.0306 - val_accuracy: 0.9891 - val_mse: 0.0084
# Epoch 128/128
# 2292/2292 [==============================] - 20s 9ms/step - loss: 0.0309 - accuracy: 0.9890 - mse: 0.0084 - val_loss: 0.0302 - val_accuracy: 0.9894 - val_mse: 0.0082

# %%
### plot learning curve

fig, ax = plt.subplots(1,1, figsize=(8,8))
plt.plot(tr_model.history["loss"], label='training data',c='blue',linewidth = 2)
plt.plot(tr_model.history["val_loss"], label='validation data',c='red',linewidth = 2)
plt.title("DNN with TDA variable", fontsize=25)
ax.set_ylabel('loss', fontsize=25,horizontalalignment='right',y=1)
ax.set_xlabel('epoch', fontsize=25,horizontalalignment='right',x=1)
# plt.yscale("log")
plt.legend(loc='best', prop={'size':20}, edgecolor = "w",fancybox=False, framealpha=0)
plt.show()

fig, ax = plt.subplots(1,1, figsize=(8,8))
plt.plot(tr_model.history["accuracy"], label='training data',c='blue',linewidth = 2)
plt.plot(tr_model.history["val_accuracy"], label='validation data',c='red',linewidth = 2)
plt.title("DNN with TDA variable", fontsize=25)
ax.set_ylabel('accuracy', fontsize=25,horizontalalignment='right',y=1)
ax.set_xlabel('epoch', fontsize=25,horizontalalignment='right',x=1)
# plt.yscale("log")
plt.legend(loc='best', prop={'size':20}, edgecolor = "w",fancybox=False, framealpha=0)
plt.show()

# %%
print("Time:{:^8.4f}(s)".format(time.time()-t1))
# Out:
# Time:2590.6118(s)

# %%
### save the model ###

model.save("/root/data/mucollider/two_boosted/model_mucollider_v1.h5")
# Out:
# /root/miniconda3/envs/tf/lib/python3.10/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
### model test ###

HLtest = []
LLtest = []
targettest = []
prediction = []

processes = ["hhvv", "hhmumu", "jjBG_ptcut", "ttBG_ptcut", "bbBG_ptcut", "wwBG", "wwvvBG", "zzBG", "zzvvBG"]
event_num = [147518, 143791, 35834, 35591, 39064, 50582, 99709, 60870, 120594]
Xsection = [4.0360050e-02, +3.3945676e-03, 1.345150e+01, 4.423600e+00, 2.325600e+00, 1.506969e+02, 1.224052e+01, 9.618000e+00, 6.473005e+00]     ### unit: fb
simulation_num = 500000
Luminosity = 1000   ### unit: fb^-1

count = 0
for process in processes:
    HLtest.append(HLdata[count:count+event_num[processes.index(process)]])
    LLtest.append(LLdata[count:count+event_num[processes.index(process)]])
    targettest.append(target[count:count+event_num[processes.index(process)]])
    prediction.append(model.predict([HLtest[-1], LLtest[-1]]))
    count += event_num[processes.index(process)]
# Out:
# 4610/4610 [==============================] - 9s 2ms/step
# 4494/4494 [==============================] - 9s 2ms/step
# 1120/1120 [==============================] - 2s 2ms/step
# 1113/1113 [==============================] - 2s 2ms/step
# 1221/1221 [==============================] - 2s 2ms/step
# 1581/1581 [==============================] - 3s 2ms/step
# 3116/3116 [==============================] - 6s 2ms/step
# 1903/1903 [==============================] - 4s 2ms/step
# 3763/3763 [==============================] - 7s 2ms/step

# %%
##### plot the prediction histogram #####

plt.figure(1, figsize=(9,7))
bins = np.linspace(0,1,21)
for process in processes:
    plt.hist(prediction[processes.index(process)], bins=bins, label=process, histtype=('stepfilled' if (process=='hhvv' or process=='hhmumu') else 'step'), density=True, alpha=(0.5 if (process=='hhvv' or process=='hhmumu') else 1))
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
plt.xlabel(r"prediction score", fontsize=18)
plt.ylabel(r"Normalized $\frac{dN}{dx}$", fontsize=18)
# plt.yscale("log")
plt.title("Model", fontsize=18)
plt.legend(loc='best')
plt.show()

plt.figure(1, figsize=(9,7))
bins = np.linspace(0,1,21)
for process in processes:
    plt.hist(prediction[processes.index(process)], bins=bins, label=process, histtype=('stepfilled' if (process=='hhvv' or process=='hhmumu') else 'step'), density=True, alpha=(0.5 if (process=='hhvv' or process=='hhmumu') else 1))
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
plt.xlabel(r"prediction score", fontsize=18)
plt.ylabel(r"Normalized $\frac{dN}{dx}$", fontsize=18)
plt.yscale("log")
plt.title("Model", fontsize=18)
plt.legend(loc='best')
plt.show()

# %%
### Do the score cut ###

score_cuts = [0.5, 0.7, 0.8, 0.9, 0.95, 0.99, 0.999]

for score_cut in score_cuts:
    print("In score cut", score_cut)

    num_afterML = []
    for process in processes: num_afterML.append(sum(prediction[processes.index(process)]>=score_cut)[0])
    print("Number before ML: ", event_num)
    print("Number after  ML: ", num_afterML)
    
    ### calculate significance ###
    
    s, b = 0, 0
    for process in processes[0:2]:
        s += Luminosity * Xsection[processes.index(process)] * (num_afterML[processes.index(process)]/simulation_num)
    for process in processes[2:]:
        b += Luminosity * Xsection[processes.index(process)] * (num_afterML[processes.index(process)]/simulation_num)
        
    def significance(s,b):
        return np.sqrt(2*((s+b)*np.log(1+s/b)-s))
    
    z = significance(s,b)
    print("signal events:", s)
    print("background events:", b)
    print("significance:", z)
    print("\n")
# Out:
# In score cut 0.5
# Number before ML:  [147518, 143791, 35834, 35591, 39064, 50582, 99709, 60870, 120594]
# Number after  ML:  [145030, 142200, 53, 747, 168, 0, 147, 3, 1594]
# signal events: 12.672251128440001
# background events: 33.10847982
# significance: 2.0804260650966273
#
#
# In score cut 0.7
# Number before ML:  [147518, 143791, 35834, 35591, 39064, 50582, 99709, 60870, 120594]
# Number after  ML:  [143960, 141499, 28, 468, 98, 0, 107, 3, 903]
# signal events: 12.5811214376648
# background events: 19.717017509999998
# significance: 2.5918714537114407
#
#
# In score cut 0.8
# Number before ML:  [147518, 143791, 35834, 35591, 39064, 50582, 99709, 60870, 120594]
# Number after  ML:  [143054, 140934, 23, 343, 71, 0, 90, 2, 611]
# signal events: 12.504153165676799
# background events: 14.13537151
# significance: 2.958963548378557
#
#
# In score cut 0.9
# Number before ML:  [147518, 143791, 35834, 35591, 39064, 50582, 99709, 60870, 120594]
# Number after  ML:  [141486, 139879, 10, 201, 35, 0, 72, 2, 358]
# signal events: 12.370421511240801
# background events: 8.64588766
# significance: 3.548683959496741
#
#
# In score cut 0.95
# Number before ML:  [147518, 143791, 35834, 35591, 39064, 50582, 99709, 60870, 120594]
# Number after  ML:  [139549, 138646, 5, 129, 25, 0, 48, 1, 201]
# signal events: 12.2056956738392
# background events: 5.188557729999999
# significance: 4.203773661866583
#
#
# In score cut 0.99
# Number before ML:  [147518, 143791, 35834, 35591, 39064, 50582, 99709, 60870, 120594]
# Number after  ML:  [133078, 134239, 1, 50, 7, 0, 16, 0, 73]
# signal events: 11.653436187912801
# background events: 1.83857677
# significance: 5.520430624123578
#
#
# In score cut 0.999
# Number before ML:  [147518, 143791, 35834, 35591, 39064, 50582, 99709, 60870, 120594]
# Number after  ML:  [114508, 119989, 0, 5, 0, 0, 1, 0, 14]
# signal events: 10.0577187543128
# background events: 0.24996118
# significance: 7.520643076931821

# %%
### check which part of model is more important ###

weights, biases = model.get_layer('dense_4').get_weights()
hl_influence = np.mean(np.abs(weights[:128, :]))
ll_influence = np.mean(np.abs(weights[128:, :]))
print("high level influence: ", hl_influence)
print("low  level influence: ", ll_influence)

weights, _ = model.get_layer('dense_4').get_weights()

hl_weights = np.abs(weights[:128, :]).flatten()
ll_weights = np.abs(weights[128:, :]).flatten()

bins = np.linspace(0,max(hl_weights), 50)
plt.hist(hl_weights, bins=bins, alpha=0.5, label='HL Weights', color='blue')
plt.hist(ll_weights, bins=bins, alpha=0.5, label='LL Weights', color='green')
plt.title('Weight Magnitude Distribution at Fusion Layer')
plt.xlabel('weight')
plt.ylabel('count')
plt.legend()
plt.show()
# Out:
# high level influence:  0.05732154
# low  level influence:  0.05426176

# %%
import shap

background_indices = np.random.choice(HL_train.shape[0], 200, replace=False)
background = [HL_train[background_indices], LL_train[background_indices]]

explainer = shap.DeepExplainer(model, background)

test_data = [HL_val, LL_val]
shap_values = explainer.shap_values(test_data)
# Out:
# /root/miniconda3/envs/tf/lib/python3.10/site-packages/shap/explainers/_deep/deep_tf.py:94: UserWarning: Your TensorFlow version is newer than 2.4.0 and so graph support has been removed in eager mode and some static graphs may not be supported. See PR #1483 for discussion.
#   warnings.warn(
# /root/miniconda3/envs/tf/lib/python3.10/site-packages/keras/src/backend.py:452: UserWarning: `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.
#   warnings.warn(

# %%
hl_importance = np.abs(shap_values[0]).mean()
ll_importance = np.abs(shap_values[1]).mean()

print(f"HL 分支的平均影響力: {hl_importance:.4f}")
print(f"LL 分支的平均影響力: {ll_importance:.4f}")
# Out:
# HL 分支的平均影響力: 0.0399
# LL 分支的平均影響力: 0.0012

# %%
shap.summary_plot(shap_values[0][:,:,0], test_data[0], feature_names=HLfeatures)
# Out:
# /tmp/ipykernel_3758/3753211440.py:1: FutureWarning: The NumPy global RNG was seeded by calling `np.random.seed`. In a future version this function will no longer use the global RNG. Pass `rng` explicitly to opt-in to the new behaviour and silence this warning.
#   shap.summary_plot(shap_values[0][:,:,0], test_data[0], feature_names=HLfeatures)

# %%
shap.summary_plot(shap_values[1][:,:,0], test_data[1], max_display=50)
# Out:
# /tmp/ipykernel_3758/1648535994.py:1: FutureWarning: The NumPy global RNG was seeded by calling `np.random.seed`. In a future version this function will no longer use the global RNG. Pass `rng` explicitly to opt-in to the new behaviour and silence this warning.
#   shap.summary_plot(shap_values[1][:,:,0], test_data[1], max_display=50)

# %%
print("Time:{:^8.4f}(s)".format(time.time()-t1))
# Out:
# Time:3159.9400(s)
