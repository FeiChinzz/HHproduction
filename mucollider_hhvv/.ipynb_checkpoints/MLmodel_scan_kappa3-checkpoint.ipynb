# %%
import time
t1 = time.time()

import math
import os
import numpy as np
import pandas as pd
import h5py
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm

import tensorflow as tf
import tensorflow.keras as keras
from tensorflow.keras import layers, models
from tensorflow.keras.optimizers import Adam , SGD , Adagrad
from tensorflow.keras.callbacks import ModelCheckpoint, LearningRateScheduler, EarlyStopping, CSVLogger, ReduceLROnPlateau
from tensorflow.keras.utils import to_categorical, plot_model
from tensorflow.keras import regularizers , initializers
from sklearn.metrics import confusion_matrix
import tensorflow.keras.backend as K
from sklearn import metrics
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split

gpus = tf.config.experimental.list_physical_devices("GPU")
tf.config.set_visible_devices(gpus[1], "GPU")

### set seed ###
keras.utils.set_random_seed(2330)
tf.config.experimental.enable_op_determinism()
# Out:
# 2026-04-08 10:10:17.016497: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
##### load data #####

hhvv_HLdata_path = "/root/data/mucollider/two_boosted/scan_kappa3_hhvv_HL.h5"
hhvv_HLdata_file = h5py.File(hhvv_HLdata_path, 'r')
print(hhvv_HLdata_file.keys())

hhvv_LLdata_path = "/root/data/mucollider/two_boosted/scan_kappa3_hhvv_LL.h5"
hhvv_LLdata_file = h5py.File(hhvv_LLdata_path, 'r')
print(hhvv_LLdata_file.keys())

hhmumu_HLdata_path = "/root/data/mucollider/two_boosted/scan_kappa3_hhmumu_HL.h5"
hhmumu_HLdata_file = h5py.File(hhmumu_HLdata_path, 'r')
print(hhmumu_HLdata_file.keys())

hhmumu_LLdata_path = "/root/data/mucollider/two_boosted/scan_kappa3_hhmumu_LL.h5"
hhmumu_LLdata_file = h5py.File(hhmumu_LLdata_path, 'r')
print(hhmumu_LLdata_file.keys())

HLdata_path = "/root/data/mucollider/two_boosted/data_HLfeature.h5"
HLdata_file = h5py.File(HLdata_path, 'r')
print(HLdata_file.keys())

LLdata_path = "/root/data/mucollider/two_boosted/data_LLfeature.h5"
LLdata_file = h5py.File(LLdata_path, 'r')
print(LLdata_file.keys())
# Out:
# <KeysViewHDF5 ['BTag_leading', 'BTag_subleading', 'H_0', 'H_1', 'LB_1', 'M_JJ', 'S_0', 'S_1', 'X_HH', 'dEta_JJ', 'm_J_leading', 'm_J_subleading', 'missET', 'pT_JJ', 'pt_J_leading', 'pt_J_subleading', 'target_kappa_3']>
# <KeysViewHDF5 ['particle_info']>
# <KeysViewHDF5 ['BTag_leading', 'BTag_subleading', 'H_0', 'H_1', 'LB_1', 'M_JJ', 'S_0', 'S_1', 'X_HH', 'dEta_JJ', 'm_J_leading', 'm_J_subleading', 'missET', 'pT_JJ', 'pt_J_leading', 'pt_J_subleading', 'target_kappa_3']>
# <KeysViewHDF5 ['particle_info']>
# <KeysViewHDF5 ['BTag_leading', 'BTag_subleading', 'H_0', 'H_1', 'LB_1', 'M_JJ', 'S_0', 'S_1', 'X_HH', 'dEta_JJ', 'm_J_leading', 'm_J_subleading', 'missET', 'pT_JJ', 'pt_J_leading', 'pt_J_subleading', 'target_everytype', 'target_sigbg']>
# <KeysViewHDF5 ['particle_info']>

# %%
##### include data #####

HLfeatures = ['BTag_leading', 'BTag_subleading', 'H_0', 'H_1', 'LB_1', 'M_JJ', 'S_0', 'S_1', 'X_HH', 'dEta_JJ', 'm_J_leading', 'm_J_subleading', 'missET', 'pT_JJ', 'pt_J_leading', 'pt_J_subleading']
LLfeatures = ['particle_info']

where_BG = np.where(HLdata_file['target_sigbg'][:]==0)

kappa3_val = 1.8
hhvv_where_kappa3 = np.where(hhvv_HLdata_file['target_kappa_3'][:]==kappa3_val)
hhmumu_where_kappa3 = np.where(hhmumu_HLdata_file['target_kappa_3'][:]==kappa3_val)

##### select BTag work point at WP70 (BitNumber 1) #####

BG_BTag_leading = ((HLdata_file['BTag_leading'][:][where_BG])&2)
BG_BTag_subleading = ((HLdata_file['BTag_subleading'][:][where_BG])&2)

##### include Signal data #####

hhvv_BTag_leading = ((hhvv_HLdata_file['BTag_leading'][:][hhvv_where_kappa3])&2)
hhvv_BTag_subleading = ((hhvv_HLdata_file['BTag_subleading'][:][hhvv_where_kappa3])&2)
hhmumu_BTag_leading = ((hhmumu_HLdata_file['BTag_leading'][:][hhmumu_where_kappa3])&2)
hhmumu_BTag_subleading = ((hhmumu_HLdata_file['BTag_subleading'][:][hhmumu_where_kappa3])&2)

hhvv_HLdata = []
for feature in HLfeatures:
    if feature=='BTag_leading': hhvv_HLdata.append(hhvv_BTag_leading)
    elif feature=='BTag_subleading': hhvv_HLdata.append(hhvv_BTag_subleading)
    else: hhvv_HLdata.append(hhvv_HLdata_file[feature][:][hhvv_where_kappa3])
hhvv_HLdata = np.array(hhvv_HLdata).T
print('shape of hhvv high level data:', hhvv_HLdata.shape)

hhvv_LLdata = hhvv_LLdata_file['particle_info'][:][hhvv_where_kappa3]
print('shape of hhvv low level data:', hhvv_LLdata.shape)

hhvv_target = np.ones(len(hhvv_where_kappa3[0]))
print('shape of hhvv target:', hhvv_target.shape)

hhmumu_HLdata = []
for feature in HLfeatures:
    if feature=='BTag_leading': hhmumu_HLdata.append(hhmumu_BTag_leading)
    elif feature=='BTag_subleading': hhmumu_HLdata.append(hhmumu_BTag_subleading)
    else: hhmumu_HLdata.append(hhmumu_HLdata_file[feature][:][hhmumu_where_kappa3])
hhmumu_HLdata = np.array(hhmumu_HLdata).T
print('shape of hhmumu high level data:', hhmumu_HLdata.shape)

hhmumu_LLdata = hhmumu_LLdata_file['particle_info'][:][hhmumu_where_kappa3]
print('shape of hhmumu low level data:', hhmumu_LLdata.shape)

hhmumu_target = np.ones(len(hhmumu_where_kappa3[0]))
print('shape of hhmumu target:', hhmumu_target.shape)

##### include Background data #####

BG_HLdata = []
for feature in HLfeatures:
    if feature=='BTag_leading': BG_HLdata.append(BG_BTag_leading)
    elif feature=='BTag_subleading': BG_HLdata.append(BG_BTag_subleading)
    else: BG_HLdata.append(HLdata_file[feature][:][where_BG])
BG_HLdata = np.array(BG_HLdata).T
print('shape of BG high level data:', BG_HLdata.shape)

BG_LLdata = LLdata_file['particle_info'][:][where_BG]
print('shape of BG low level data:', BG_LLdata.shape)

BG_target = HLdata_file['target_sigbg'][:][where_BG]
print('shape of BG target:', BG_target.shape)

##### merge the data #####

HLdata = np.concatenate((hhvv_HLdata, hhmumu_HLdata, BG_HLdata))
LLdata = np.concatenate((hhvv_LLdata, hhmumu_LLdata, BG_LLdata))
target = np.concatenate((hhvv_target, hhmumu_target, BG_target))

#### Do training data and validation data split #####

HL_train, HL_val, LL_train, LL_val, y_train, y_val = train_test_split(HLdata, LLdata, target, test_size=0.25, random_state=2330, shuffle=True)
print("\nAfter training validation data split:")
print("HL training data: ", HL_train.shape, "HL validation data: ", HL_val.shape)
print("LL training data: ", LL_train.shape, "LL validation data: ", LL_val.shape)
print("training target: ", y_train.shape, "validation target: ", y_val.shape)
# Out:
# shape of hhvv high level data: (25768, 16)
# shape of hhvv low level data: (25768, 160)
# shape of hhvv target: (25768,)
# shape of hhmumu high level data: (25744, 16)
# shape of hhmumu low level data: (25744, 160)
# shape of hhmumu target: (25744,)
# shape of BG high level data: (575001, 16)
# shape of BG low level data: (575001, 160)
# shape of BG target: (575001,)
#
# After training validation data split:
# HL training data:  (469884, 16) HL validation data:  (156629, 16)
# LL training data:  (469884, 160) LL validation data:  (156629, 160)
# training target:  (469884,) validation target:  (156629,)

# %%
##### construct model #####

### high level features part ###

HL_input = layers.Input(shape=(16,), name='HL_Input')

x_hl = layers.Dense(128)(HL_input)
x_hl = layers.BatchNormalization()(x_hl)
x_hl = layers.Activation('relu')(x_hl)
x_hl = layers.Dropout(0.1)(x_hl)

x_hl = layers.Dense(128)(x_hl)
x_hl = layers.BatchNormalization()(x_hl)
x_hl = layers.Activation('relu')(x_hl)
x_hl = layers.Dropout(0.1)(x_hl)

### low level features part ###

LL_input = layers.Input(shape=(160,), name='LL_Input')

x_ll = layers.Dense(512)(LL_input)
x_ll = layers.BatchNormalization()(x_ll)
x_ll = layers.Activation('relu')(x_ll)
x_ll = layers.Dropout(0.1)(x_ll)

x_ll = layers.Dense(128)(x_ll)
x_ll = layers.BatchNormalization()(x_ll)
x_ll = layers.Activation('relu')(x_ll)
x_ll = layers.Dropout(0.1)(x_ll)

### combine two parts of model and the following node ###

combined = layers.Concatenate()([x_hl, x_ll])

x = layers.Dense(256, activation='relu')(combined)
x = layers.Dense(16, activation='relu')(x)
output = layers.Dense(1, activation='sigmoid', name='Output')(x)

model = models.Model(inputs=[HL_input, LL_input], outputs=output)

### optimizer ###

opt = keras.optimizers.Adam(learning_rate=1e-5)

### compile ###

model.compile(loss='binary_crossentropy', optimizer=opt, metrics=["accuracy","mse"])

### summary ###

model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  HL_Input (InputLayer)       [(None, 16)]                 0         []
#
#  LL_Input (InputLayer)       [(None, 160)]                0         []
#
#  dense (Dense)               (None, 128)                  2176      ['HL_Input[0][0]']
# 2026-04-08 10:10:21.455345: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 46696 MB memory:  -> device: 1, name: NVIDIA RTX A6000, pci bus id: 0000:25:00.0, compute capability: 8.6
#
#  dense_2 (Dense)             (None, 512)                  82432     ['LL_Input[0][0]']
#
#  batch_normalization (Batch  (None, 128)                  512       ['dense[0][0]']
#  Normalization)
#
#  batch_normalization_2 (Bat  (None, 512)                  2048      ['dense_2[0][0]']
#  chNormalization)
#
#  activation (Activation)     (None, 128)                  0         ['batch_normalization[0][0]']
#
#  activation_2 (Activation)   (None, 512)                  0         ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  dropout (Dropout)           (None, 128)                  0         ['activation[0][0]']
#
#  dropout_2 (Dropout)         (None, 512)                  0         ['activation_2[0][0]']
#
#  dense_1 (Dense)             (None, 128)                  16512     ['dropout[0][0]']
#
#  dense_3 (Dense)             (None, 128)                  65664     ['dropout_2[0][0]']
#
#  batch_normalization_1 (Bat  (None, 128)                  512       ['dense_1[0][0]']
#  chNormalization)
#
#  batch_normalization_3 (Bat  (None, 128)                  512       ['dense_3[0][0]']
#  chNormalization)
#
#  activation_1 (Activation)   (None, 128)                  0         ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  activation_3 (Activation)   (None, 128)                  0         ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  dropout_1 (Dropout)         (None, 128)                  0         ['activation_1[0][0]']
#
#  dropout_3 (Dropout)         (None, 128)                  0         ['activation_3[0][0]']
#
#  concatenate (Concatenate)   (None, 256)                  0         ['dropout_1[0][0]',
#                                                                      'dropout_3[0][0]']
#
#  dense_4 (Dense)             (None, 256)                  65792     ['concatenate[0][0]']
#
#  dense_5 (Dense)             (None, 16)                   4112      ['dense_4[0][0]']
#
#  Output (Dense)              (None, 1)                    17        ['dense_5[0][0]']
#
# ==================================================================================================
# Total params: 240289 (938.63 KB)
# Trainable params: 238497 (931.63 KB)
# Non-trainable params: 1792 (7.00 KB)
# __________________________________________________________________________________________________

# %%
##### training model #####

tr_model = model.fit(x=[HL_train, LL_train], y=y_train, validation_data=([HL_val, LL_val], y_val), epochs=96, batch_size=256, verbose=1)
# Out:
# Epoch 1/96
# 2026-04-08 10:10:25.756143: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:606] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2026-04-08 10:10:25.762074: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x55b2263e6950 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2026-04-08 10:10:25.762106: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA RTX A6000, Compute Capability 8.6
# 2026-04-08 10:10:25.769479: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:255] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2026-04-08 10:10:25.951939: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:432] Loaded cuDNN version 8600
# 2026-04-08 10:10:26.080484: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 1836/1836 [==============================] - 20s 8ms/step - loss: 0.2290 - accuracy: 0.9199 - mse: 0.0655 - val_loss: 0.1942 - val_accuracy: 0.9298 - val_mse: 0.0557
# Epoch 2/96
# 1836/1836 [==============================] - 14s 8ms/step - loss: 0.1805 - accuracy: 0.9322 - mse: 0.0522 - val_loss: 0.1568 - val_accuracy: 0.9411 - val_mse: 0.0449
# Epoch 3/96
# 1836/1836 [==============================] - 14s 8ms/step - loss: 0.1615 - accuracy: 0.9392 - mse: 0.0465 - val_loss: 0.1416 - val_accuracy: 0.9479 - val_mse: 0.0403
# Epoch 4/96
# 1836/1836 [==============================] - 14s 7ms/step - loss: 0.1516 - accuracy: 0.9435 - mse: 0.0435 - val_loss: 0.1347 - val_accuracy: 0.9514 - val_mse: 0.0381
# Epoch 5/96
# 1836/1836 [==============================] - 14s 8ms/step - loss: 0.1455 - accuracy: 0.9463 - mse: 0.0416 - val_loss: 0.1299 - val_accuracy: 0.9544 - val_mse: 0.0364
# Epoch 6/96
# 1836/1836 [==============================] - 14s 7ms/step - loss: 0.1405 - accuracy: 0.9486 - mse: 0.0399 - val_loss: 0.1264 - val_accuracy: 0.9563 - val_mse: 0.0353
# Epoch 7/96
# 1836/1836 [==============================] - 14s 7ms/step - loss: 0.1378 - accuracy: 0.9500 - mse: 0.0391 - val_loss: 0.1232 - val_accuracy: 0.9575 - val_mse: 0.0343
# Epoch 8/96
# 1836/1836 [==============================] - 14s 8ms/step - loss: 0.1340 - accuracy: 0.9518 - mse: 0.0378 - val_loss: 0.1207 - val_accuracy: 0.9590 - val_mse: 0.0334
# Epoch 9/96
# 1836/1836 [==============================] - 14s 7ms/step - loss: 0.1315 - accuracy: 0.9529 - mse: 0.0370 - val_loss: 0.1185 - val_accuracy: 0.9597 - val_mse: 0.0327
# Epoch 10/96
# 1836/1836 [==============================] - 14s 7ms/step - loss: 0.1292 - accuracy: 0.9543 - mse: 0.0362 - val_loss: 0.1165 - val_accuracy: 0.9606 - val_mse: 0.0321
# Epoch 11/96
# 1836/1836 [==============================] - 15s 8ms/step - loss: 0.1273 - accuracy: 0.9550 - mse: 0.0357 - val_loss: 0.1146 - val_accuracy: 0.9612 - val_mse: 0.0315
# Epoch 12/96
# 1836/1836 [==============================] - 14s 8ms/step - loss: 0.1252 - accuracy: 0.9560 - mse: 0.0349 - val_loss: 0.1127 - val_accuracy: 0.9621 - val_mse: 0.0309
# Epoch 13/96
# 1836/1836 [==============================] - 14s 8ms/step - loss: 0.1232 - accuracy: 0.9568 - mse: 0.0343 - val_loss: 0.1110 - val_accuracy: 0.9628 - val_mse: 0.0303
# Epoch 14/96
# 1836/1836 [==============================] - 14s 8ms/step - loss: 0.1211 - accuracy: 0.9578 - mse: 0.0336 - val_loss: 0.1092 - val_accuracy: 0.9634 - val_mse: 0.0298
# Epoch 15/96
# 1836/1836 [==============================] - 14s 7ms/step - loss: 0.1190 - accuracy: 0.9588 - mse: 0.0330 - val_loss: 0.1071 - val_accuracy: 0.9643 - val_mse: 0.0292
# Epoch 16/96
# 1836/1836 [==============================] - 14s 8ms/step - loss: 0.1171 - accuracy: 0.9592 - mse: 0.0324 - val_loss: 0.1049 - val_accuracy: 0.9651 - val_mse: 0.0285
# Epoch 17/96
# 1836/1836 [==============================] - 14s 8ms/step - loss: 0.1146 - accuracy: 0.9606 - mse: 0.0316 - val_loss: 0.1030 - val_accuracy: 0.9660 - val_mse: 0.0279
# Epoch 18/96
# 1836/1836 [==============================] - 14s 8ms/step - loss: 0.1127 - accuracy: 0.9615 - mse: 0.0311 - val_loss: 0.1008 - val_accuracy: 0.9668 - val_mse: 0.0273
# Epoch 19/96
# 1836/1836 [==============================] - 15s 8ms/step - loss: 0.1103 - accuracy: 0.9625 - mse: 0.0303 - val_loss: 0.0987 - val_accuracy: 0.9675 - val_mse: 0.0267
# Epoch 20/96
# 1836/1836 [==============================] - 14s 8ms/step - loss: 0.1084 - accuracy: 0.9632 - mse: 0.0297 - val_loss: 0.0970 - val_accuracy: 0.9681 - val_mse: 0.0262
# Epoch 21/96
# 1836/1836 [==============================] - 14s 8ms/step - loss: 0.1062 - accuracy: 0.9638 - mse: 0.0291 - val_loss: 0.0953 - val_accuracy: 0.9686 - val_mse: 0.0258
# Epoch 22/96
# 1836/1836 [==============================] - 14s 7ms/step - loss: 0.1048 - accuracy: 0.9642 - mse: 0.0287 - val_loss: 0.0936 - val_accuracy: 0.9693 - val_mse: 0.0253
# Epoch 23/96
# 1836/1836 [==============================] - 14s 8ms/step - loss: 0.1032 - accuracy: 0.9651 - mse: 0.0282 - val_loss: 0.0921 - val_accuracy: 0.9696 - val_mse: 0.0249
# Epoch 24/96
# 1836/1836 [==============================] - 14s 8ms/step - loss: 0.1017 - accuracy: 0.9655 - mse: 0.0278 - val_loss: 0.0905 - val_accuracy: 0.9699 - val_mse: 0.0246
# Epoch 25/96
# 1836/1836 [==============================] - 15s 8ms/step - loss: 0.1002 - accuracy: 0.9658 - mse: 0.0275 - val_loss: 0.0894 - val_accuracy: 0.9702 - val_mse: 0.0243
# Epoch 26/96
# 1836/1836 [==============================] - 15s 8ms/step - loss: 0.0989 - accuracy: 0.9663 - mse: 0.0271 - val_loss: 0.0883 - val_accuracy: 0.9706 - val_mse: 0.0240
# Epoch 27/96
# 1836/1836 [==============================] - 14s 8ms/step - loss: 0.0972 - accuracy: 0.9668 - mse: 0.0267 - val_loss: 0.0873 - val_accuracy: 0.9707 - val_mse: 0.0238
# Epoch 28/96
# 1836/1836 [==============================] - 15s 8ms/step - loss: 0.0962 - accuracy: 0.9671 - mse: 0.0264 - val_loss: 0.0859 - val_accuracy: 0.9711 - val_mse: 0.0234
# Epoch 29/96
# 1836/1836 [==============================] - 14s 8ms/step - loss: 0.0951 - accuracy: 0.9677 - mse: 0.0260 - val_loss: 0.0854 - val_accuracy: 0.9713 - val_mse: 0.0233
# Epoch 30/96
# 1836/1836 [==============================] - 14s 8ms/step - loss: 0.0942 - accuracy: 0.9677 - mse: 0.0258 - val_loss: 0.0844 - val_accuracy: 0.9716 - val_mse: 0.0231
# Epoch 31/96
# 1836/1836 [==============================] - 14s 8ms/step - loss: 0.0937 - accuracy: 0.9678 - mse: 0.0257 - val_loss: 0.0838 - val_accuracy: 0.9716 - val_mse: 0.0230
# Epoch 32/96
# 1836/1836 [==============================] - 14s 8ms/step - loss: 0.0930 - accuracy: 0.9683 - mse: 0.0255 - val_loss: 0.0831 - val_accuracy: 0.9719 - val_mse: 0.0228
# Epoch 33/96
# 1836/1836 [==============================] - 15s 8ms/step - loss: 0.0921 - accuracy: 0.9684 - mse: 0.0253 - val_loss: 0.0825 - val_accuracy: 0.9721 - val_mse: 0.0226
# Epoch 34/96
# 1836/1836 [==============================] - 14s 8ms/step - loss: 0.0911 - accuracy: 0.9686 - mse: 0.0251 - val_loss: 0.0822 - val_accuracy: 0.9718 - val_mse: 0.0226
# Epoch 35/96
# 1836/1836 [==============================] - 14s 8ms/step - loss: 0.0907 - accuracy: 0.9688 - mse: 0.0249 - val_loss: 0.0817 - val_accuracy: 0.9721 - val_mse: 0.0224
# Epoch 36/96
# 1836/1836 [==============================] - 14s 7ms/step - loss: 0.0902 - accuracy: 0.9689 - mse: 0.0248 - val_loss: 0.0810 - val_accuracy: 0.9723 - val_mse: 0.0223
# Epoch 37/96
# 1836/1836 [==============================] - 14s 8ms/step - loss: 0.0893 - accuracy: 0.9692 - mse: 0.0246 - val_loss: 0.0803 - val_accuracy: 0.9725 - val_mse: 0.0221
# Epoch 38/96
# 1836/1836 [==============================] - 14s 7ms/step - loss: 0.0891 - accuracy: 0.9693 - mse: 0.0245 - val_loss: 0.0801 - val_accuracy: 0.9725 - val_mse: 0.0221
# Epoch 39/96
# 1836/1836 [==============================] - 14s 7ms/step - loss: 0.0881 - accuracy: 0.9695 - mse: 0.0243 - val_loss: 0.0799 - val_accuracy: 0.9724 - val_mse: 0.0220
# Epoch 40/96
# 1836/1836 [==============================] - 14s 8ms/step - loss: 0.0876 - accuracy: 0.9696 - mse: 0.0241 - val_loss: 0.0793 - val_accuracy: 0.9727 - val_mse: 0.0219
# Epoch 41/96
# 1836/1836 [==============================] - 14s 8ms/step - loss: 0.0870 - accuracy: 0.9699 - mse: 0.0240 - val_loss: 0.0789 - val_accuracy: 0.9727 - val_mse: 0.0218
# Epoch 42/96
# 1836/1836 [==============================] - 14s 8ms/step - loss: 0.0864 - accuracy: 0.9700 - mse: 0.0238 - val_loss: 0.0786 - val_accuracy: 0.9728 - val_mse: 0.0217
# Epoch 43/96
# 1836/1836 [==============================] - 14s 8ms/step - loss: 0.0861 - accuracy: 0.9700 - mse: 0.0238 - val_loss: 0.0784 - val_accuracy: 0.9729 - val_mse: 0.0216
# Epoch 44/96
# 1836/1836 [==============================] - 14s 8ms/step - loss: 0.0857 - accuracy: 0.9702 - mse: 0.0236 - val_loss: 0.0780 - val_accuracy: 0.9730 - val_mse: 0.0216
# Epoch 45/96
# 1836/1836 [==============================] - 14s 8ms/step - loss: 0.0851 - accuracy: 0.9704 - mse: 0.0235 - val_loss: 0.0775 - val_accuracy: 0.9732 - val_mse: 0.0214
# Epoch 46/96
# 1836/1836 [==============================] - 14s 8ms/step - loss: 0.0850 - accuracy: 0.9704 - mse: 0.0234 - val_loss: 0.0772 - val_accuracy: 0.9731 - val_mse: 0.0214
# Epoch 47/96
# 1836/1836 [==============================] - 14s 8ms/step - loss: 0.0843 - accuracy: 0.9708 - mse: 0.0232 - val_loss: 0.0769 - val_accuracy: 0.9733 - val_mse: 0.0213
# Epoch 48/96
# 1836/1836 [==============================] - 14s 8ms/step - loss: 0.0840 - accuracy: 0.9706 - mse: 0.0232 - val_loss: 0.0767 - val_accuracy: 0.9733 - val_mse: 0.0212
# Epoch 49/96
# 1836/1836 [==============================] - 14s 8ms/step - loss: 0.0836 - accuracy: 0.9709 - mse: 0.0231 - val_loss: 0.0764 - val_accuracy: 0.9734 - val_mse: 0.0212
# Epoch 50/96
# 1836/1836 [==============================] - 15s 8ms/step - loss: 0.0829 - accuracy: 0.9712 - mse: 0.0229 - val_loss: 0.0761 - val_accuracy: 0.9735 - val_mse: 0.0211
# Epoch 51/96
# 1836/1836 [==============================] - 14s 7ms/step - loss: 0.0825 - accuracy: 0.9712 - mse: 0.0228 - val_loss: 0.0757 - val_accuracy: 0.9735 - val_mse: 0.0210
# Epoch 52/96
# 1836/1836 [==============================] - 14s 8ms/step - loss: 0.0819 - accuracy: 0.9713 - mse: 0.0227 - val_loss: 0.0754 - val_accuracy: 0.9736 - val_mse: 0.0209
# Epoch 53/96
# 1836/1836 [==============================] - 14s 8ms/step - loss: 0.0822 - accuracy: 0.9712 - mse: 0.0227 - val_loss: 0.0754 - val_accuracy: 0.9735 - val_mse: 0.0209
# Epoch 54/96
# 1836/1836 [==============================] - 14s 7ms/step - loss: 0.0818 - accuracy: 0.9713 - mse: 0.0227 - val_loss: 0.0750 - val_accuracy: 0.9737 - val_mse: 0.0208
# Epoch 55/96
# 1836/1836 [==============================] - 14s 8ms/step - loss: 0.0813 - accuracy: 0.9715 - mse: 0.0225 - val_loss: 0.0746 - val_accuracy: 0.9737 - val_mse: 0.0207
# Epoch 56/96
# 1836/1836 [==============================] - 14s 8ms/step - loss: 0.0805 - accuracy: 0.9719 - mse: 0.0223 - val_loss: 0.0747 - val_accuracy: 0.9736 - val_mse: 0.0207
# Epoch 57/96
# 1836/1836 [==============================] - 14s 8ms/step - loss: 0.0805 - accuracy: 0.9719 - mse: 0.0223 - val_loss: 0.0743 - val_accuracy: 0.9737 - val_mse: 0.0206
# Epoch 58/96
# 1836/1836 [==============================] - 14s 8ms/step - loss: 0.0802 - accuracy: 0.9718 - mse: 0.0222 - val_loss: 0.0740 - val_accuracy: 0.9738 - val_mse: 0.0206
# Epoch 59/96
# 1836/1836 [==============================] - 13s 7ms/step - loss: 0.0801 - accuracy: 0.9717 - mse: 0.0222 - val_loss: 0.0738 - val_accuracy: 0.9738 - val_mse: 0.0205
# Epoch 60/96
# 1836/1836 [==============================] - 14s 8ms/step - loss: 0.0794 - accuracy: 0.9717 - mse: 0.0220 - val_loss: 0.0736 - val_accuracy: 0.9738 - val_mse: 0.0205
# Epoch 61/96
# 1836/1836 [==============================] - 14s 8ms/step - loss: 0.0793 - accuracy: 0.9719 - mse: 0.0220 - val_loss: 0.0734 - val_accuracy: 0.9740 - val_mse: 0.0204
# Epoch 62/96
# 1836/1836 [==============================] - 14s 8ms/step - loss: 0.0786 - accuracy: 0.9722 - mse: 0.0218 - val_loss: 0.0733 - val_accuracy: 0.9740 - val_mse: 0.0204
# Epoch 63/96
# 1836/1836 [==============================] - 14s 8ms/step - loss: 0.0787 - accuracy: 0.9722 - mse: 0.0218 - val_loss: 0.0730 - val_accuracy: 0.9740 - val_mse: 0.0203
# Epoch 64/96
# 1836/1836 [==============================] - 14s 8ms/step - loss: 0.0784 - accuracy: 0.9721 - mse: 0.0218 - val_loss: 0.0729 - val_accuracy: 0.9740 - val_mse: 0.0203
# Epoch 65/96
# 1836/1836 [==============================] - 14s 7ms/step - loss: 0.0779 - accuracy: 0.9725 - mse: 0.0216 - val_loss: 0.0726 - val_accuracy: 0.9740 - val_mse: 0.0202
# Epoch 66/96
# 1836/1836 [==============================] - 14s 8ms/step - loss: 0.0776 - accuracy: 0.9723 - mse: 0.0216 - val_loss: 0.0724 - val_accuracy: 0.9740 - val_mse: 0.0202
# Epoch 67/96
# 1836/1836 [==============================] - 14s 8ms/step - loss: 0.0778 - accuracy: 0.9724 - mse: 0.0216 - val_loss: 0.0725 - val_accuracy: 0.9740 - val_mse: 0.0202
# Epoch 68/96
# 1836/1836 [==============================] - 14s 8ms/step - loss: 0.0772 - accuracy: 0.9726 - mse: 0.0214 - val_loss: 0.0721 - val_accuracy: 0.9742 - val_mse: 0.0201
# Epoch 69/96
# 1836/1836 [==============================] - 14s 8ms/step - loss: 0.0770 - accuracy: 0.9726 - mse: 0.0214 - val_loss: 0.0719 - val_accuracy: 0.9741 - val_mse: 0.0200
# Epoch 70/96
# 1836/1836 [==============================] - 14s 8ms/step - loss: 0.0766 - accuracy: 0.9727 - mse: 0.0213 - val_loss: 0.0716 - val_accuracy: 0.9743 - val_mse: 0.0199
# Epoch 71/96
# 1836/1836 [==============================] - 14s 8ms/step - loss: 0.0768 - accuracy: 0.9726 - mse: 0.0214 - val_loss: 0.0716 - val_accuracy: 0.9742 - val_mse: 0.0200
# Epoch 72/96
# 1836/1836 [==============================] - 14s 8ms/step - loss: 0.0762 - accuracy: 0.9727 - mse: 0.0212 - val_loss: 0.0714 - val_accuracy: 0.9742 - val_mse: 0.0199
# Epoch 73/96
# 1836/1836 [==============================] - 14s 8ms/step - loss: 0.0760 - accuracy: 0.9729 - mse: 0.0212 - val_loss: 0.0712 - val_accuracy: 0.9742 - val_mse: 0.0199
# Epoch 74/96
# 1836/1836 [==============================] - 14s 8ms/step - loss: 0.0760 - accuracy: 0.9729 - mse: 0.0212 - val_loss: 0.0710 - val_accuracy: 0.9744 - val_mse: 0.0198
# Epoch 75/96
# 1836/1836 [==============================] - 14s 7ms/step - loss: 0.0755 - accuracy: 0.9729 - mse: 0.0211 - val_loss: 0.0710 - val_accuracy: 0.9743 - val_mse: 0.0198
# Epoch 76/96
# 1836/1836 [==============================] - 14s 8ms/step - loss: 0.0750 - accuracy: 0.9732 - mse: 0.0209 - val_loss: 0.0709 - val_accuracy: 0.9743 - val_mse: 0.0198
# Epoch 77/96
# 1836/1836 [==============================] - 14s 8ms/step - loss: 0.0750 - accuracy: 0.9730 - mse: 0.0209 - val_loss: 0.0708 - val_accuracy: 0.9742 - val_mse: 0.0198
# Epoch 78/96
# 1836/1836 [==============================] - 15s 8ms/step - loss: 0.0749 - accuracy: 0.9730 - mse: 0.0209 - val_loss: 0.0707 - val_accuracy: 0.9743 - val_mse: 0.0198
# Epoch 79/96
# 1836/1836 [==============================] - 14s 8ms/step - loss: 0.0746 - accuracy: 0.9731 - mse: 0.0208 - val_loss: 0.0703 - val_accuracy: 0.9745 - val_mse: 0.0197
# Epoch 80/96
# 1836/1836 [==============================] - 14s 8ms/step - loss: 0.0746 - accuracy: 0.9732 - mse: 0.0208 - val_loss: 0.0704 - val_accuracy: 0.9745 - val_mse: 0.0197
# Epoch 81/96
# 1836/1836 [==============================] - 15s 8ms/step - loss: 0.0744 - accuracy: 0.9732 - mse: 0.0208 - val_loss: 0.0701 - val_accuracy: 0.9746 - val_mse: 0.0196
# Epoch 82/96
# 1836/1836 [==============================] - 15s 8ms/step - loss: 0.0741 - accuracy: 0.9735 - mse: 0.0207 - val_loss: 0.0703 - val_accuracy: 0.9745 - val_mse: 0.0197
# Epoch 83/96
# 1836/1836 [==============================] - 15s 8ms/step - loss: 0.0738 - accuracy: 0.9734 - mse: 0.0206 - val_loss: 0.0700 - val_accuracy: 0.9746 - val_mse: 0.0196
# Epoch 84/96
# 1836/1836 [==============================] - 15s 8ms/step - loss: 0.0736 - accuracy: 0.9734 - mse: 0.0206 - val_loss: 0.0698 - val_accuracy: 0.9747 - val_mse: 0.0195
# Epoch 85/96
# 1836/1836 [==============================] - 15s 8ms/step - loss: 0.0737 - accuracy: 0.9735 - mse: 0.0206 - val_loss: 0.0697 - val_accuracy: 0.9746 - val_mse: 0.0195
# Epoch 86/96
# 1836/1836 [==============================] - 16s 9ms/step - loss: 0.0729 - accuracy: 0.9738 - mse: 0.0204 - val_loss: 0.0696 - val_accuracy: 0.9747 - val_mse: 0.0195
# Epoch 87/96
# 1836/1836 [==============================] - 16s 9ms/step - loss: 0.0732 - accuracy: 0.9735 - mse: 0.0205 - val_loss: 0.0695 - val_accuracy: 0.9748 - val_mse: 0.0195
# Epoch 88/96
# 1836/1836 [==============================] - 16s 9ms/step - loss: 0.0724 - accuracy: 0.9736 - mse: 0.0203 - val_loss: 0.0694 - val_accuracy: 0.9747 - val_mse: 0.0195
# Epoch 89/96
# 1836/1836 [==============================] - 16s 9ms/step - loss: 0.0730 - accuracy: 0.9737 - mse: 0.0204 - val_loss: 0.0695 - val_accuracy: 0.9747 - val_mse: 0.0195
# Epoch 90/96
# 1836/1836 [==============================] - 16s 9ms/step - loss: 0.0723 - accuracy: 0.9738 - mse: 0.0202 - val_loss: 0.0694 - val_accuracy: 0.9747 - val_mse: 0.0195
# Epoch 91/96
# 1836/1836 [==============================] - 15s 8ms/step - loss: 0.0725 - accuracy: 0.9738 - mse: 0.0203 - val_loss: 0.0691 - val_accuracy: 0.9748 - val_mse: 0.0194
# Epoch 92/96
# 1836/1836 [==============================] - 16s 9ms/step - loss: 0.0721 - accuracy: 0.9738 - mse: 0.0202 - val_loss: 0.0690 - val_accuracy: 0.9747 - val_mse: 0.0194
# Epoch 93/96
# 1836/1836 [==============================] - 16s 9ms/step - loss: 0.0718 - accuracy: 0.9738 - mse: 0.0201 - val_loss: 0.0690 - val_accuracy: 0.9748 - val_mse: 0.0194
# Epoch 94/96
# 1836/1836 [==============================] - 16s 9ms/step - loss: 0.0718 - accuracy: 0.9739 - mse: 0.0201 - val_loss: 0.0690 - val_accuracy: 0.9748 - val_mse: 0.0194
# Epoch 95/96
# 1836/1836 [==============================] - 16s 9ms/step - loss: 0.0715 - accuracy: 0.9739 - mse: 0.0201 - val_loss: 0.0687 - val_accuracy: 0.9750 - val_mse: 0.0193
# Epoch 96/96
# 1836/1836 [==============================] - 17s 9ms/step - loss: 0.0715 - accuracy: 0.9741 - mse: 0.0200 - val_loss: 0.0688 - val_accuracy: 0.9750 - val_mse: 0.0193

# %%
### plot learning curve

fig, ax = plt.subplots(1,1, figsize=(8,8))
plt.plot(tr_model.history["loss"], label='training data',c='blue',linewidth = 2)
plt.plot(tr_model.history["val_loss"], label='validation data',c='red',linewidth = 2)
plt.title("DNN with TDA variable", fontsize=25)
ax.set_ylabel('loss', fontsize=25,horizontalalignment='right',y=1)
ax.set_xlabel('epoch', fontsize=25,horizontalalignment='right',x=1)
# plt.yscale("log")
plt.legend(loc='best', prop={'size':20}, edgecolor = "w",fancybox=False, framealpha=0)
plt.show()

fig, ax = plt.subplots(1,1, figsize=(8,8))
plt.plot(tr_model.history["accuracy"], label='training data',c='blue',linewidth = 2)
plt.plot(tr_model.history["val_accuracy"], label='validation data',c='red',linewidth = 2)
plt.title("DNN with TDA variable", fontsize=25)
ax.set_ylabel('accuracy', fontsize=25,horizontalalignment='right',y=1)
ax.set_xlabel('epoch', fontsize=25,horizontalalignment='right',x=1)
# plt.yscale("log")
plt.legend(loc='best', prop={'size':20}, edgecolor = "w",fancybox=False, framealpha=0)
plt.show()

# %%
print("Time:{:^8.4f}(s)".format(time.time()-t1))
# Out:
# Time:1389.3620(s)

# %%
### save the model ###

model.save("/root/data/mucollider/two_boosted/ML_model/model_mucollider_18.h5")
# Out:
# /root/miniconda3/envs/tf/lib/python3.10/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
### check which part of model is more important ###

weights, biases = model.get_layer('dense_4').get_weights()
hl_influence = np.mean(np.abs(weights[:128, :]))
ll_influence = np.mean(np.abs(weights[128:, :]))
print("high level influence: ", hl_influence)
print("low  level influence: ", ll_influence)

weights, _ = model.get_layer('dense_4').get_weights()

hl_weights = np.abs(weights[:128, :]).flatten()
ll_weights = np.abs(weights[128:, :]).flatten()

bins = np.linspace(0,max(hl_weights), 50)
plt.hist(hl_weights, bins=bins, alpha=0.5, label='HL Weights', color='blue')
plt.hist(ll_weights, bins=bins, alpha=0.5, label='LL Weights', color='green')
plt.title('Weight Magnitude Distribution at Fusion Layer')
plt.xlabel('weight')
plt.ylabel('count')
plt.legend()
plt.show()
# Out:
# high level influence:  0.05643172
# low  level influence:  0.053854965

# %%
print("Time:{:^8.4f}(s)".format(time.time()-t1))
# Out:
# Time:1389.7087(s)
