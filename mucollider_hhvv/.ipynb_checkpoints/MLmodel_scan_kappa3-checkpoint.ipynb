# %%
import time
t1 = time.time()

import math
import os
import numpy as np
import pandas as pd
import h5py
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm

import tensorflow as tf
import tensorflow.keras as keras
from tensorflow.keras import layers, models
from tensorflow.keras.optimizers import Adam , SGD , Adagrad
from tensorflow.keras.callbacks import ModelCheckpoint, LearningRateScheduler, EarlyStopping, CSVLogger, ReduceLROnPlateau
from tensorflow.keras.utils import to_categorical, plot_model
from tensorflow.keras import regularizers , initializers
from sklearn.metrics import confusion_matrix
import tensorflow.keras.backend as K
from sklearn import metrics
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split

gpus = tf.config.experimental.list_physical_devices("GPU")
tf.config.set_visible_devices(gpus[1], "GPU")

### set seed ###
keras.utils.set_random_seed(2330)
tf.config.experimental.enable_op_determinism()
# Out:
# 2026-04-07 04:09:46.284754: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
##### load data #####

hhvv_HLdata_path = "/root/data/mucollider/two_boosted/scan_kappa3_hhvv_HL.h5"
hhvv_HLdata_file = h5py.File(hhvv_HLdata_path, 'r')
print(hhvv_HLdata_file.keys())

hhvv_LLdata_path = "/root/data/mucollider/two_boosted/scan_kappa3_hhvv_LL.h5"
hhvv_LLdata_file = h5py.File(hhvv_LLdata_path, 'r')
print(hhvv_LLdata_file.keys())

hhmumu_HLdata_path = "/root/data/mucollider/two_boosted/scan_kappa3_hhmumu_HL.h5"
hhmumu_HLdata_file = h5py.File(hhmumu_HLdata_path, 'r')
print(hhmumu_HLdata_file.keys())

hhmumu_LLdata_path = "/root/data/mucollider/two_boosted/scan_kappa3_hhmumu_LL.h5"
hhmumu_LLdata_file = h5py.File(hhmumu_LLdata_path, 'r')
print(hhmumu_LLdata_file.keys())

HLdata_path = "/root/data/mucollider/two_boosted/data_HLfeature.h5"
HLdata_file = h5py.File(HLdata_path, 'r')
print(HLdata_file.keys())

LLdata_path = "/root/data/mucollider/two_boosted/data_LLfeature.h5"
LLdata_file = h5py.File(LLdata_path, 'r')
print(LLdata_file.keys())
# Out:
# <KeysViewHDF5 ['BTag_leading', 'BTag_subleading', 'H_0', 'H_1', 'LB_1', 'M_JJ', 'S_0', 'S_1', 'X_HH', 'dEta_JJ', 'm_J_leading', 'm_J_subleading', 'missET', 'pT_JJ', 'pt_J_leading', 'pt_J_subleading', 'target_kappa_3']>
# <KeysViewHDF5 ['particle_info']>
# <KeysViewHDF5 ['BTag_leading', 'BTag_subleading', 'H_0', 'H_1', 'LB_1', 'M_JJ', 'S_0', 'S_1', 'X_HH', 'dEta_JJ', 'm_J_leading', 'm_J_subleading', 'missET', 'pT_JJ', 'pt_J_leading', 'pt_J_subleading', 'target_kappa_3']>
# <KeysViewHDF5 ['particle_info']>
# <KeysViewHDF5 ['BTag_leading', 'BTag_subleading', 'H_0', 'H_1', 'LB_1', 'M_JJ', 'S_0', 'S_1', 'X_HH', 'dEta_JJ', 'm_J_leading', 'm_J_subleading', 'missET', 'pT_JJ', 'pt_J_leading', 'pt_J_subleading', 'target_everytype', 'target_sigbg']>
# <KeysViewHDF5 ['particle_info']>

# %%
##### include data #####

HLfeatures = ['BTag_leading', 'BTag_subleading', 'H_0', 'H_1', 'LB_1', 'M_JJ', 'S_0', 'S_1', 'X_HH', 'dEta_JJ', 'm_J_leading', 'm_J_subleading', 'missET', 'pT_JJ', 'pt_J_leading', 'pt_J_subleading']
LLfeatures = ['particle_info']

where_BG = np.where(HLdata_file['target_sigbg'][:]==0)

kappa3_val = 0.2
hhvv_where_kappa3 = np.where(hhvv_HLdata_file['target_kappa_3'][:]==kappa3_val)
hhmumu_where_kappa3 = np.where(hhmumu_HLdata_file['target_kappa_3'][:]==kappa3_val)

##### select BTag work point at WP70 (BitNumber 1) #####

BG_BTag_leading = ((HLdata_file['BTag_leading'][:][where_BG])&2)
BG_BTag_subleading = ((HLdata_file['BTag_subleading'][:][where_BG])&2)

##### include Signal data #####

hhvv_BTag_leading = ((hhvv_HLdata_file['BTag_leading'][:][hhvv_where_kappa3])&2)
hhvv_BTag_subleading = ((hhvv_HLdata_file['BTag_subleading'][:][hhvv_where_kappa3])&2)
hhmumu_BTag_leading = ((hhmumu_HLdata_file['BTag_leading'][:][hhmumu_where_kappa3])&2)
hhmumu_BTag_subleading = ((hhmumu_HLdata_file['BTag_subleading'][:][hhmumu_where_kappa3])&2)

hhvv_HLdata = []
for feature in HLfeatures:
    if feature=='BTag_leading': hhvv_HLdata.append(hhvv_BTag_leading)
    elif feature=='BTag_subleading': hhvv_HLdata.append(hhvv_BTag_subleading)
    else: hhvv_HLdata.append(hhvv_HLdata_file[feature][:][hhvv_where_kappa3])
hhvv_HLdata = np.array(hhvv_HLdata).T
print('shape of hhvv high level data:', hhvv_HLdata.shape)

hhvv_LLdata = hhvv_LLdata_file['particle_info'][:][hhvv_where_kappa3]
print('shape of hhvv low level data:', hhvv_LLdata.shape)

hhvv_target = np.ones(len(hhvv_where_kappa3[0]))
print('shape of hhvv target:', hhvv_target.shape)

hhmumu_HLdata = []
for feature in HLfeatures:
    if feature=='BTag_leading': hhmumu_HLdata.append(hhmumu_BTag_leading)
    elif feature=='BTag_subleading': hhmumu_HLdata.append(hhmumu_BTag_subleading)
    else: hhmumu_HLdata.append(hhmumu_HLdata_file[feature][:][hhmumu_where_kappa3])
hhmumu_HLdata = np.array(hhmumu_HLdata).T
print('shape of hhmumu high level data:', hhmumu_HLdata.shape)

hhmumu_LLdata = hhmumu_LLdata_file['particle_info'][:][hhmumu_where_kappa3]
print('shape of hhmumu low level data:', hhmumu_LLdata.shape)

hhmumu_target = np.ones(len(hhmumu_where_kappa3[0]))
print('shape of hhmumu target:', hhmumu_target.shape)

##### include Background data #####

BG_HLdata = []
for feature in HLfeatures:
    if feature=='BTag_leading': BG_HLdata.append(BG_BTag_leading)
    elif feature=='BTag_subleading': BG_HLdata.append(BG_BTag_subleading)
    else: BG_HLdata.append(HLdata_file[feature][:][where_BG])
BG_HLdata = np.array(BG_HLdata).T
print('shape of BG high level data:', BG_HLdata.shape)

BG_LLdata = LLdata_file['particle_info'][:][where_BG]
print('shape of BG low level data:', BG_LLdata.shape)

BG_target = HLdata_file['target_sigbg'][:][where_BG]
print('shape of BG target:', BG_target.shape)

##### merge the data #####

HLdata = np.concatenate((hhvv_HLdata, hhmumu_HLdata, BG_HLdata))
LLdata = np.concatenate((hhvv_LLdata, hhmumu_LLdata, BG_LLdata))
target = np.concatenate((hhvv_target, hhmumu_target, BG_target))

#### Do training data and validation data split #####

HL_train, HL_val, LL_train, LL_val, y_train, y_val = train_test_split(HLdata, LLdata, target, test_size=0.25, random_state=2330, shuffle=True)
print("\nAfter training validation data split:")
print("HL training data: ", HL_train.shape, "HL validation data: ", HL_val.shape)
print("LL training data: ", LL_train.shape, "LL validation data: ", LL_val.shape)
print("training target: ", y_train.shape, "validation target: ", y_val.shape)
# Out:
# shape of hhvv high level data: (31536, 16)
# shape of hhvv low level data: (31536, 160)
# shape of hhvv target: (31536,)
# shape of hhmumu high level data: (30469, 16)
# shape of hhmumu low level data: (30469, 160)
# shape of hhmumu target: (30469,)
# shape of BG high level data: (575001, 16)
# shape of BG low level data: (575001, 160)
# shape of BG target: (575001,)
#
# After training validation data split:
# HL training data:  (477754, 16) HL validation data:  (159252, 16)
# LL training data:  (477754, 160) LL validation data:  (159252, 160)
# training target:  (477754,) validation target:  (159252,)

# %%
##### construct model #####

### high level features part ###

HL_input = layers.Input(shape=(16,), name='HL_Input')

x_hl = layers.Dense(128)(HL_input)
x_hl = layers.BatchNormalization()(x_hl)
x_hl = layers.Activation('relu')(x_hl)
x_hl = layers.Dropout(0.1)(x_hl)

x_hl = layers.Dense(128)(x_hl)
x_hl = layers.BatchNormalization()(x_hl)
x_hl = layers.Activation('relu')(x_hl)
x_hl = layers.Dropout(0.1)(x_hl)

### low level features part ###

LL_input = layers.Input(shape=(160,), name='LL_Input')

x_ll = layers.Dense(512)(LL_input)
x_ll = layers.BatchNormalization()(x_ll)
x_ll = layers.Activation('relu')(x_ll)
x_ll = layers.Dropout(0.1)(x_ll)

x_ll = layers.Dense(128)(x_ll)
x_ll = layers.BatchNormalization()(x_ll)
x_ll = layers.Activation('relu')(x_ll)
x_ll = layers.Dropout(0.1)(x_ll)

### combine two parts of model and the following node ###

combined = layers.Concatenate()([x_hl, x_ll])

x = layers.Dense(256, activation='relu')(combined)
x = layers.Dense(16, activation='relu')(x)
output = layers.Dense(1, activation='sigmoid', name='Output')(x)

model = models.Model(inputs=[HL_input, LL_input], outputs=output)

### optimizer ###

opt = keras.optimizers.Adam(learning_rate=1e-5)

### compile ###

model.compile(loss='binary_crossentropy', optimizer=opt, metrics=["accuracy","mse"])

### summary ###

model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  HL_Input (InputLayer)       [(None, 16)]                 0         []
#
#  LL_Input (InputLayer)       [(None, 160)]                0         []
#
#  dense (Dense)               (None, 128)                  2176      ['HL_Input[0][0]']
#
#  dense_2 (Dense)             (None, 512)                  82432     ['LL_Input[0][0]']
#
#  batch_normalization (Batch  (None, 128)                  512       ['dense[0][0]']
#  Normalization)
#
#  batch_normalization_2 (Bat  (None, 512)                  2048      ['dense_2[0][0]']
#  chNormalization)
#
#  activation (Activation)     (None, 128)                  0         ['batch_normalization[0][0]']
#
#  activation_2 (Activation)   (None, 512)                  0         ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  dropout (Dropout)           (None, 128)                  0         ['activation[0][0]']
#
#  dropout_2 (Dropout)         (None, 512)                  0         ['activation_2[0][0]']
#
#  dense_1 (Dense)             (None, 128)                  16512     ['dropout[0][0]']
#
#  dense_3 (Dense)             (None, 128)                  65664     ['dropout_2[0][0]']
#
#  batch_normalization_1 (Bat  (None, 128)                  512       ['dense_1[0][0]']
#  chNormalization)
#
#  batch_normalization_3 (Bat  (None, 128)                  512       ['dense_3[0][0]']
#  chNormalization)
#
#  activation_1 (Activation)   (None, 128)                  0         ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  activation_3 (Activation)   (None, 128)                  0         ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  dropout_1 (Dropout)         (None, 128)                  0         ['activation_1[0][0]']
#
#  dropout_3 (Dropout)         (None, 128)                  0         ['activation_3[0][0]']
#
#  concatenate (Concatenate)   (None, 256)                  0         ['dropout_1[0][0]',
#                                                                      'dropout_3[0][0]']
#
#  dense_4 (Dense)             (None, 256)                  65792     ['concatenate[0][0]']
#
#  dense_5 (Dense)             (None, 16)                   4112      ['dense_4[0][0]']
#
#  Output (Dense)              (None, 1)                    17        ['dense_5[0][0]']
#
# ==================================================================================================
# Total params: 240289 (938.63 KB)
# Trainable params: 238497 (931.63 KB)
# Non-trainable params: 1792 (7.00 KB)
# __________________________________________________________________________________________________
# 2026-04-07 04:09:50.425324: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 46696 MB memory:  -> device: 1, name: NVIDIA RTX A6000, pci bus id: 0000:25:00.0, compute capability: 8.6

# %%
##### training model #####

tr_model = model.fit(x=[HL_train, LL_train], y=y_train, validation_data=([HL_val, LL_val], y_val), epochs=64, batch_size=256, verbose=1)
# Out:
# Epoch 1/64
# 2026-04-07 04:09:54.261853: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:606] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2026-04-07 04:09:54.268126: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7fad622b5cc0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2026-04-07 04:09:54.268147: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA RTX A6000, Compute Capability 8.6
# 2026-04-07 04:09:54.273132: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:255] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2026-04-07 04:09:54.412498: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:432] Loaded cuDNN version 8600
# 2026-04-07 04:09:54.531442: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 1867/1867 [==============================] - 22s 9ms/step - loss: 0.2310 - accuracy: 0.9099 - mse: 0.0687 - val_loss: 0.1874 - val_accuracy: 0.9279 - val_mse: 0.0549
# Epoch 2/64
# 1867/1867 [==============================] - 17s 9ms/step - loss: 0.1763 - accuracy: 0.9300 - mse: 0.0521 - val_loss: 0.1483 - val_accuracy: 0.9422 - val_mse: 0.0430
# Epoch 3/64
# 1867/1867 [==============================] - 17s 9ms/step - loss: 0.1569 - accuracy: 0.9382 - mse: 0.0461 - val_loss: 0.1369 - val_accuracy: 0.9467 - val_mse: 0.0398
# Epoch 4/64
# 1867/1867 [==============================] - 17s 9ms/step - loss: 0.1471 - accuracy: 0.9426 - mse: 0.0430 - val_loss: 0.1300 - val_accuracy: 0.9500 - val_mse: 0.0376
# Epoch 5/64
# 1867/1867 [==============================] - 17s 9ms/step - loss: 0.1413 - accuracy: 0.9450 - mse: 0.0413 - val_loss: 0.1256 - val_accuracy: 0.9521 - val_mse: 0.0362
# Epoch 6/64
# 1867/1867 [==============================] - 17s 9ms/step - loss: 0.1367 - accuracy: 0.9472 - mse: 0.0398 - val_loss: 0.1210 - val_accuracy: 0.9554 - val_mse: 0.0346
# Epoch 7/64
# 1867/1867 [==============================] - 17s 9ms/step - loss: 0.1329 - accuracy: 0.9489 - mse: 0.0386 - val_loss: 0.1179 - val_accuracy: 0.9569 - val_mse: 0.0336
# Epoch 8/64
# 1867/1867 [==============================] - 17s 9ms/step - loss: 0.1295 - accuracy: 0.9505 - mse: 0.0375 - val_loss: 0.1153 - val_accuracy: 0.9580 - val_mse: 0.0327
# Epoch 9/64
# 1867/1867 [==============================] - 17s 9ms/step - loss: 0.1266 - accuracy: 0.9523 - mse: 0.0365 - val_loss: 0.1128 - val_accuracy: 0.9593 - val_mse: 0.0319
# Epoch 10/64
# 1867/1867 [==============================] - 17s 9ms/step - loss: 0.1237 - accuracy: 0.9535 - mse: 0.0356 - val_loss: 0.1102 - val_accuracy: 0.9604 - val_mse: 0.0311
# Epoch 11/64
# 1867/1867 [==============================] - 17s 9ms/step - loss: 0.1209 - accuracy: 0.9550 - mse: 0.0347 - val_loss: 0.1083 - val_accuracy: 0.9615 - val_mse: 0.0304
# Epoch 12/64
# 1867/1867 [==============================] - 17s 9ms/step - loss: 0.1184 - accuracy: 0.9559 - mse: 0.0338 - val_loss: 0.1061 - val_accuracy: 0.9624 - val_mse: 0.0297
# Epoch 13/64
# 1867/1867 [==============================] - 16s 9ms/step - loss: 0.1169 - accuracy: 0.9565 - mse: 0.0334 - val_loss: 0.1044 - val_accuracy: 0.9631 - val_mse: 0.0292
# Epoch 14/64
# 1867/1867 [==============================] - 16s 9ms/step - loss: 0.1147 - accuracy: 0.9575 - mse: 0.0327 - val_loss: 0.1028 - val_accuracy: 0.9639 - val_mse: 0.0287
# Epoch 15/64
# 1867/1867 [==============================] - 17s 9ms/step - loss: 0.1131 - accuracy: 0.9586 - mse: 0.0321 - val_loss: 0.1012 - val_accuracy: 0.9646 - val_mse: 0.0282
# Epoch 16/64
# 1867/1867 [==============================] - 17s 9ms/step - loss: 0.1112 - accuracy: 0.9593 - mse: 0.0316 - val_loss: 0.0994 - val_accuracy: 0.9654 - val_mse: 0.0276
# Epoch 17/64
# 1867/1867 [==============================] - 17s 9ms/step - loss: 0.1098 - accuracy: 0.9598 - mse: 0.0312 - val_loss: 0.0979 - val_accuracy: 0.9658 - val_mse: 0.0272
# Epoch 18/64
# 1867/1867 [==============================] - 16s 9ms/step - loss: 0.1077 - accuracy: 0.9606 - mse: 0.0306 - val_loss: 0.0961 - val_accuracy: 0.9666 - val_mse: 0.0267
# Epoch 19/64
# 1867/1867 [==============================] - 17s 9ms/step - loss: 0.1060 - accuracy: 0.9612 - mse: 0.0300 - val_loss: 0.0945 - val_accuracy: 0.9669 - val_mse: 0.0263
# Epoch 20/64
# 1867/1867 [==============================] - 17s 9ms/step - loss: 0.1044 - accuracy: 0.9619 - mse: 0.0296 - val_loss: 0.0933 - val_accuracy: 0.9673 - val_mse: 0.0259
# Epoch 21/64
# 1867/1867 [==============================] - 17s 9ms/step - loss: 0.1028 - accuracy: 0.9625 - mse: 0.0291 - val_loss: 0.0917 - val_accuracy: 0.9677 - val_mse: 0.0255
# Epoch 22/64
# 1867/1867 [==============================] - 17s 9ms/step - loss: 0.1015 - accuracy: 0.9629 - mse: 0.0287 - val_loss: 0.0903 - val_accuracy: 0.9681 - val_mse: 0.0251
# Epoch 23/64
# 1867/1867 [==============================] - 16s 9ms/step - loss: 0.1000 - accuracy: 0.9631 - mse: 0.0284 - val_loss: 0.0891 - val_accuracy: 0.9687 - val_mse: 0.0248
# Epoch 24/64
# 1867/1867 [==============================] - 16s 9ms/step - loss: 0.0991 - accuracy: 0.9636 - mse: 0.0281 - val_loss: 0.0880 - val_accuracy: 0.9689 - val_mse: 0.0245
# Epoch 25/64
# 1867/1867 [==============================] - 16s 9ms/step - loss: 0.0977 - accuracy: 0.9646 - mse: 0.0276 - val_loss: 0.0869 - val_accuracy: 0.9692 - val_mse: 0.0242
# Epoch 26/64
# 1867/1867 [==============================] - 17s 9ms/step - loss: 0.0959 - accuracy: 0.9650 - mse: 0.0272 - val_loss: 0.0858 - val_accuracy: 0.9695 - val_mse: 0.0239
# Epoch 27/64
# 1867/1867 [==============================] - 16s 9ms/step - loss: 0.0949 - accuracy: 0.9652 - mse: 0.0269 - val_loss: 0.0846 - val_accuracy: 0.9699 - val_mse: 0.0236
# Epoch 28/64
# 1867/1867 [==============================] - 17s 9ms/step - loss: 0.0943 - accuracy: 0.9652 - mse: 0.0267 - val_loss: 0.0837 - val_accuracy: 0.9701 - val_mse: 0.0234
# Epoch 29/64
# 1867/1867 [==============================] - 16s 9ms/step - loss: 0.0936 - accuracy: 0.9657 - mse: 0.0265 - val_loss: 0.0828 - val_accuracy: 0.9705 - val_mse: 0.0231
# Epoch 30/64
# 1867/1867 [==============================] - 17s 9ms/step - loss: 0.0921 - accuracy: 0.9663 - mse: 0.0261 - val_loss: 0.0821 - val_accuracy: 0.9706 - val_mse: 0.0229
# Epoch 31/64
# 1867/1867 [==============================] - 17s 9ms/step - loss: 0.0915 - accuracy: 0.9663 - mse: 0.0259 - val_loss: 0.0815 - val_accuracy: 0.9708 - val_mse: 0.0228
# Epoch 32/64
# 1867/1867 [==============================] - 17s 9ms/step - loss: 0.0905 - accuracy: 0.9667 - mse: 0.0257 - val_loss: 0.0812 - val_accuracy: 0.9709 - val_mse: 0.0227
# Epoch 33/64
# 1867/1867 [==============================] - 17s 9ms/step - loss: 0.0897 - accuracy: 0.9671 - mse: 0.0254 - val_loss: 0.0803 - val_accuracy: 0.9712 - val_mse: 0.0225
# Epoch 34/64
# 1867/1867 [==============================] - 16s 9ms/step - loss: 0.0895 - accuracy: 0.9670 - mse: 0.0255 - val_loss: 0.0798 - val_accuracy: 0.9712 - val_mse: 0.0223
# Epoch 35/64
# 1867/1867 [==============================] - 16s 9ms/step - loss: 0.0886 - accuracy: 0.9673 - mse: 0.0251 - val_loss: 0.0792 - val_accuracy: 0.9713 - val_mse: 0.0222
# Epoch 36/64
# 1867/1867 [==============================] - 16s 9ms/step - loss: 0.0882 - accuracy: 0.9674 - mse: 0.0250 - val_loss: 0.0787 - val_accuracy: 0.9715 - val_mse: 0.0221
# Epoch 37/64
# 1867/1867 [==============================] - 17s 9ms/step - loss: 0.0874 - accuracy: 0.9678 - mse: 0.0248 - val_loss: 0.0781 - val_accuracy: 0.9717 - val_mse: 0.0219
# Epoch 38/64
# 1867/1867 [==============================] - 17s 9ms/step - loss: 0.0865 - accuracy: 0.9678 - mse: 0.0246 - val_loss: 0.0777 - val_accuracy: 0.9718 - val_mse: 0.0218
# Epoch 39/64
# 1867/1867 [==============================] - 17s 9ms/step - loss: 0.0862 - accuracy: 0.9680 - mse: 0.0245 - val_loss: 0.0774 - val_accuracy: 0.9718 - val_mse: 0.0218
# Epoch 40/64
# 1867/1867 [==============================] - 17s 9ms/step - loss: 0.0854 - accuracy: 0.9683 - mse: 0.0242 - val_loss: 0.0768 - val_accuracy: 0.9719 - val_mse: 0.0216
# Epoch 41/64
# 1867/1867 [==============================] - 17s 9ms/step - loss: 0.0849 - accuracy: 0.9687 - mse: 0.0241 - val_loss: 0.0766 - val_accuracy: 0.9722 - val_mse: 0.0215
# Epoch 42/64
# 1867/1867 [==============================] - 16s 9ms/step - loss: 0.0847 - accuracy: 0.9686 - mse: 0.0241 - val_loss: 0.0763 - val_accuracy: 0.9721 - val_mse: 0.0215
# Epoch 43/64
# 1867/1867 [==============================] - 17s 9ms/step - loss: 0.0842 - accuracy: 0.9684 - mse: 0.0240 - val_loss: 0.0759 - val_accuracy: 0.9724 - val_mse: 0.0213
# Epoch 44/64
# 1867/1867 [==============================] - 17s 9ms/step - loss: 0.0832 - accuracy: 0.9691 - mse: 0.0237 - val_loss: 0.0755 - val_accuracy: 0.9726 - val_mse: 0.0212
# Epoch 45/64
# 1867/1867 [==============================] - 17s 9ms/step - loss: 0.0832 - accuracy: 0.9693 - mse: 0.0236 - val_loss: 0.0752 - val_accuracy: 0.9725 - val_mse: 0.0212
# Epoch 46/64
# 1867/1867 [==============================] - 17s 9ms/step - loss: 0.0824 - accuracy: 0.9692 - mse: 0.0235 - val_loss: 0.0749 - val_accuracy: 0.9726 - val_mse: 0.0211
# Epoch 47/64
# 1867/1867 [==============================] - 16s 9ms/step - loss: 0.0819 - accuracy: 0.9697 - mse: 0.0233 - val_loss: 0.0745 - val_accuracy: 0.9729 - val_mse: 0.0210
# Epoch 48/64
# 1867/1867 [==============================] - 17s 9ms/step - loss: 0.0820 - accuracy: 0.9694 - mse: 0.0234 - val_loss: 0.0745 - val_accuracy: 0.9727 - val_mse: 0.0210
# Epoch 49/64
# 1867/1867 [==============================] - 17s 9ms/step - loss: 0.0812 - accuracy: 0.9698 - mse: 0.0231 - val_loss: 0.0740 - val_accuracy: 0.9729 - val_mse: 0.0209
# Epoch 50/64
# 1867/1867 [==============================] - 16s 9ms/step - loss: 0.0809 - accuracy: 0.9699 - mse: 0.0230 - val_loss: 0.0737 - val_accuracy: 0.9731 - val_mse: 0.0208
# Epoch 51/64
# 1867/1867 [==============================] - 17s 9ms/step - loss: 0.0806 - accuracy: 0.9699 - mse: 0.0230 - val_loss: 0.0736 - val_accuracy: 0.9729 - val_mse: 0.0208
# Epoch 52/64
# 1867/1867 [==============================] - 17s 9ms/step - loss: 0.0803 - accuracy: 0.9702 - mse: 0.0229 - val_loss: 0.0734 - val_accuracy: 0.9732 - val_mse: 0.0207
# Epoch 53/64
# 1867/1867 [==============================] - 17s 9ms/step - loss: 0.0799 - accuracy: 0.9702 - mse: 0.0227 - val_loss: 0.0728 - val_accuracy: 0.9733 - val_mse: 0.0205
# Epoch 54/64
# 1867/1867 [==============================] - 17s 9ms/step - loss: 0.0793 - accuracy: 0.9705 - mse: 0.0226 - val_loss: 0.0726 - val_accuracy: 0.9736 - val_mse: 0.0205
# Epoch 55/64
# 1867/1867 [==============================] - 17s 9ms/step - loss: 0.0788 - accuracy: 0.9706 - mse: 0.0224 - val_loss: 0.0725 - val_accuracy: 0.9734 - val_mse: 0.0205
# Epoch 56/64
# 1867/1867 [==============================] - 17s 9ms/step - loss: 0.0786 - accuracy: 0.9709 - mse: 0.0223 - val_loss: 0.0723 - val_accuracy: 0.9733 - val_mse: 0.0205
# Epoch 57/64
# 1867/1867 [==============================] - 17s 9ms/step - loss: 0.0783 - accuracy: 0.9707 - mse: 0.0223 - val_loss: 0.0718 - val_accuracy: 0.9737 - val_mse: 0.0203
# Epoch 58/64
# 1867/1867 [==============================] - 17s 9ms/step - loss: 0.0780 - accuracy: 0.9706 - mse: 0.0222 - val_loss: 0.0717 - val_accuracy: 0.9736 - val_mse: 0.0202
# Epoch 59/64
# 1867/1867 [==============================] - 17s 9ms/step - loss: 0.0779 - accuracy: 0.9708 - mse: 0.0222 - val_loss: 0.0714 - val_accuracy: 0.9738 - val_mse: 0.0201
# Epoch 60/64
# 1867/1867 [==============================] - 17s 9ms/step - loss: 0.0772 - accuracy: 0.9711 - mse: 0.0220 - val_loss: 0.0713 - val_accuracy: 0.9736 - val_mse: 0.0202
# Epoch 61/64
# 1867/1867 [==============================] - 17s 9ms/step - loss: 0.0768 - accuracy: 0.9711 - mse: 0.0219 - val_loss: 0.0711 - val_accuracy: 0.9737 - val_mse: 0.0201
# Epoch 62/64
# 1867/1867 [==============================] - 17s 9ms/step - loss: 0.0766 - accuracy: 0.9713 - mse: 0.0218 - val_loss: 0.0708 - val_accuracy: 0.9738 - val_mse: 0.0200
# Epoch 63/64
# 1867/1867 [==============================] - 17s 9ms/step - loss: 0.0760 - accuracy: 0.9716 - mse: 0.0216 - val_loss: 0.0704 - val_accuracy: 0.9742 - val_mse: 0.0199
# Epoch 64/64
# 1867/1867 [==============================] - 17s 9ms/step - loss: 0.0762 - accuracy: 0.9714 - mse: 0.0217 - val_loss: 0.0703 - val_accuracy: 0.9741 - val_mse: 0.0199

# %%
### plot learning curve

fig, ax = plt.subplots(1,1, figsize=(8,8))
plt.plot(tr_model.history["loss"], label='training data',c='blue',linewidth = 2)
plt.plot(tr_model.history["val_loss"], label='validation data',c='red',linewidth = 2)
plt.title("DNN with TDA variable", fontsize=25)
ax.set_ylabel('loss', fontsize=25,horizontalalignment='right',y=1)
ax.set_xlabel('epoch', fontsize=25,horizontalalignment='right',x=1)
# plt.yscale("log")
plt.legend(loc='best', prop={'size':20}, edgecolor = "w",fancybox=False, framealpha=0)
plt.show()

fig, ax = plt.subplots(1,1, figsize=(8,8))
plt.plot(tr_model.history["accuracy"], label='training data',c='blue',linewidth = 2)
plt.plot(tr_model.history["val_accuracy"], label='validation data',c='red',linewidth = 2)
plt.title("DNN with TDA variable", fontsize=25)
ax.set_ylabel('accuracy', fontsize=25,horizontalalignment='right',y=1)
ax.set_xlabel('epoch', fontsize=25,horizontalalignment='right',x=1)
# plt.yscale("log")
plt.legend(loc='best', prop={'size':20}, edgecolor = "w",fancybox=False, framealpha=0)
plt.show()

# %%
print("Time:{:^8.4f}(s)".format(time.time()-t1))
# Out:
# Time:1078.8886(s)

# %%
### save the model ###

model.save("/root/data/mucollider/two_boosted/ML_model/model_mucollider_02.h5")
# Out:
# /root/miniconda3/envs/tf/lib/python3.10/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
### check which part of model is more important ###

weights, biases = model.get_layer('dense_4').get_weights()
hl_influence = np.mean(np.abs(weights[:128, :]))
ll_influence = np.mean(np.abs(weights[128:, :]))
print("high level influence: ", hl_influence)
print("low  level influence: ", ll_influence)

weights, _ = model.get_layer('dense_4').get_weights()

hl_weights = np.abs(weights[:128, :]).flatten()
ll_weights = np.abs(weights[128:, :]).flatten()

bins = np.linspace(0,max(hl_weights), 50)
plt.hist(hl_weights, bins=bins, alpha=0.5, label='HL Weights', color='blue')
plt.hist(ll_weights, bins=bins, alpha=0.5, label='LL Weights', color='green')
plt.title('Weight Magnitude Distribution at Fusion Layer')
plt.xlabel('weight')
plt.ylabel('count')
plt.legend()
plt.show()
# Out:
# high level influence:  0.055940185
# low  level influence:  0.0537833

# %%
import shap

background_indices = np.random.choice(HL_train.shape[0], 200, replace=False)
background = [HL_train[background_indices], LL_train[background_indices]]

explainer = shap.DeepExplainer(model, background)

test_data = [HL_val, LL_val]
shap_values = explainer.shap_values(test_data)
# Out:
# /root/miniconda3/envs/tf/lib/python3.10/site-packages/shap/explainers/_deep/deep_tf.py:94: UserWarning: Your TensorFlow version is newer than 2.4.0 and so graph support has been removed in eager mode and some static graphs may not be supported. See PR #1483 for discussion.
#   warnings.warn(
# /root/miniconda3/envs/tf/lib/python3.10/site-packages/keras/src/backend.py:452: UserWarning: `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.
#   warnings.warn(

# %%
hl_importance = np.abs(shap_values[0]).mean()
ll_importance = np.abs(shap_values[1]).mean()

print(f"HL 分支的平均影響力: {hl_importance:.4f}")
print(f"LL 分支的平均影響力: {ll_importance:.4f}")
# Out:
# HL 分支的平均影響力: 0.0147
# LL 分支的平均影響力: 0.0006

# %%
shap.summary_plot(shap_values[0][:,:,0], test_data[0], feature_names=HLfeatures)
# Out:
# /tmp/ipykernel_4366/3753211440.py:1: FutureWarning: The NumPy global RNG was seeded by calling `np.random.seed`. In a future version this function will no longer use the global RNG. Pass `rng` explicitly to opt-in to the new behaviour and silence this warning.
#   shap.summary_plot(shap_values[0][:,:,0], test_data[0], feature_names=HLfeatures)

# %%
shap.summary_plot(shap_values[1][:,:,0], test_data[1], max_display=50)
# Out:
# /tmp/ipykernel_4366/1648535994.py:1: FutureWarning: The NumPy global RNG was seeded by calling `np.random.seed`. In a future version this function will no longer use the global RNG. Pass `rng` explicitly to opt-in to the new behaviour and silence this warning.
#   shap.summary_plot(shap_values[1][:,:,0], test_data[1], max_display=50)

# %%
print("Time:{:^8.4f}(s)".format(time.time()-t1))
# Out:
# Time:1631.3604(s)
