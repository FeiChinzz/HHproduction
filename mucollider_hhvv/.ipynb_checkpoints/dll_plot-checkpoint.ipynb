# %%
import os, sys
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

sys.path.insert(0, '/root/work/Papers')
import paper_style as ps; ps.set_style(); ps.compact_12()

# %%
# ══════════════════ EDIT HERE ═══════════════════════════════════════════
# Per panel: kappa3 scan points, -DeltalnL values (any reference; they are
# re-anchored at kappa3=1 below), fit window (None = use all points).
K_3TEV   = np.array([0.2, 0.4, 0.6, 0.8, 0.9, 1.0, 1.1, 1.2, 1.4, 1.6, 1.8])
DLL_3TEV = np.array([2.0323589640135147, 1.0026563782442466, 0.38625998474891743, 0.08209702434603816, 0.01867676746251412, 0.0, 0.021188942514065445, 0.0658606444545935, 0.18780994387455507, 0.2665079902572298, 0.2861000862477603])   # REPLACE with your 3 TeV scan
DLL_3TEV_woTDA = np.array([1.4333173934970924, 0.6792959552931608, 0.26136834394892716, 0.05549710187641388, 0.012142101361162005, 0.0, 0.012351394840203866, 0.03756365235106074, 0.10605471895105012, 0.15113697351716482, 0.16175323685648202])
WIN_3TEV = None

K_10TEV   = np.array([0.8, 0.84, 0.88, 0.92, 0.96, 1, 1.04, 1.08, 1.12, 1.16, 1.2])
DLL_10TEV = np.array([5.390230968299612, 3.4191532573963253, 1.9700141464683343, 1.033281104115753, 0.3635378465576524, 0.0, 0.20581223369753143, 0.6304249434351785, 1.3274954653068223, 2.354489671207422, 3.445849533271196])
DLL_10TEV_DHH = np.array([3.496243482466781, 1.9253618862504709, 1.1123759796419108, 0.6899904691935319, 0.22039158650198942, 0.0, 0.02271013482516082, 0.23536450792099117, 0.5044226993400969, 1.1621976545093844, 1.5541191237473697])
DLL_10TEV_DHH_woTDA = np.array([3.3023817146007843, 1.7961071702980291, 1.1132519572118156, 0.6146663743482748, 0.18187157683092892, 0.0, 0.05150543952035491, 0.2736403373780263, 0.5775936515066746, 1.2738852660825444, 1.6064359792885625])
WIN_10TEV = (0.8, 1.2)                   # suggested: fit only the refined grid

TAG_EXTRA = 'boosted'                    # region label inside the panel
OUTPDF    = '/root/data/mucollider/two_boosted/generated_fig/fig_result_boosted_hypo_k3.pdf'
# ═════════════════════════════════════════════════════════════════════════


def poly4_cl(k, dll, window=None, n_fine=5000):
    """Shift at kappa3=1, poly4 fit (inside `window`), CL bands referenced
    to the fitted minimum. Returns dict for plotting."""
    k = np.asarray(k, float); dll = np.asarray(dll, float)
    dll = dll - dll[np.argmin(np.abs(k - 1.0))]          # anchor at kappa3=1
    m = np.ones(len(k), bool) if window is None else \
        (k >= window[0] - 1e-9) & (k <= window[1] + 1e-9)
    coef = np.polyfit(k[m], dll[m], 4)
    kf = np.linspace(k[m].min(), k[m].max(), n_fine)
    df = np.polyval(coef, kf)
    sh = np.maximum(df - df.min(), 0.0)                  # fitted-min reference

    def connected(thresh):
        mask = sh < thresh
        i = int(sh.argmin()); lo = hi = i
        while lo > 0 and mask[lo - 1]: lo -= 1
        while hi < len(mask) - 1 and mask[hi + 1]: hi += 1
        return float(kf[lo]), float(kf[hi])

    lo68, hi68 = connected(0.50)
    lo95, hi95 = connected(1.92)
    # display curve re-anchored at kappa3=1 so it passes through the points
    disp = np.maximum(df - np.polyval(coef, 1.0), 0.0)
    return dict(k=k, dll=dll, kf=kf, disp=disp,
                lo68=lo68, hi68=hi68, lo95=lo95, hi95=hi95)


# 重新組織 PANELS，讓每個 Panel 可以包裝多條數據
PANELS_DATA = [
    {
        'title': '3 TeV',
        'lines': [
            {'label': 'Paper', 'c': ps.C_3TEV, 'k': K_3TEV, 'dll': DLL_3TEV, 'win': WIN_3TEV, 'ls': '-'},
            {'label': 'woTDA',   'c': 'C1',      'k': K_3TEV, 'dll': DLL_3TEV_woTDA, 'win': WIN_3TEV, 'ls': '--'}
        ]
    },
    {
        'title': '10 TeV',
        'lines': [
            {'label': 'Paper',   'c': ps.C_10TEV, 'k': K_10TEV, 'dll': DLL_10TEV, 'win': WIN_10TEV, 'ls': '-'},
            {'label': 'DHH',       'c': 'C3',       'k': K_10TEV, 'dll': DLL_10TEV_DHH, 'win': WIN_10TEV, 'ls': '-.'},
            {'label': 'DHH woTDA', 'c': 'C2',       'k': K_10TEV, 'dll': DLL_10TEV_DHH_woTDA, 'win': WIN_10TEV, 'ls': '--'}
        ]
    }
]

fig, ax = plt.subplots(1, 2, figsize=ps.SIZE12)
for a, panel in zip(ax, PANELS_DATA):
    title = panel['title']
    
    # 在該 panel 內迭代畫出每一條線
    for line in panel['lines']:
        lbl = line['label']
        c = line['c']
        ls = line['ls']
        
        P = poly4_cl(line['k'], line['dll'], line['win'])
        
        # 繪製 CI bands (這邊有把 alpha 調淡一點點，以免多條線重疊太深)
        if lbl=='Paper':
            a.axvspan(P['lo95'], P['hi95'], color=c, alpha=0.08, zorder=1)   # 95% band
            a.axvspan(P['lo68'], P['hi68'], color=c, alpha=0.15, zorder=2)   # 68% band
        
        # 繪製 Fitted Curve (加入了 linestyle(ls) 與 label 來產生圖例)
        a.plot(P['kf'], P['disp'], ls=ls, color=c, lw=1.4, zorder=4, label=lbl)
        
        # 繪製真實數據點
        a.plot(P['k'], P['dll'], marker='o', ls='none', mfc='white', mec=c,
               mew=0.9, ms=3.2, zorder=5)
               
        # 自動印出每條線的計算結果
        print(f'{title} [{lbl}]: 68% [{P["lo68"]:.3f}, {P["hi68"]:.3f}]   '
              f'95% [{P["lo95"]:.3f}, {P["hi95"]:.3f}]   window={line["win"]}')

    # 基本網格與標籤設定
    a.axhline(0.50, color='0.45', ls=':', lw=1.0)
    a.axhline(1.92, color='0.65', ls=':', lw=1.0)
    a.axvline(1.0, color='0.7', lw=0.7, alpha=0.5)
    a.set_xlim(0.2, 1.8)
    a.set_ylim(-0.1, 3.0)
    a.set_xticks(np.arange(0.2, 1.81, 0.2))
    a.set_xlabel(r'$\kappa_3 = \lambda_3/\lambda_3^{\rm SM}$')
    a.set_ylabel(r'$-\Delta\ln L$')
    
    # 加上 hep_tag
    ps.hep_tag(a, [rf'$\sqrt{{s}}={title.split()[0]}$ TeV', TAG_EXTRA],
               loc='upper right', simulation=True, fontsize=7.5)
    
    # 加入圖例 (因為現在有多條線了，沒圖例會分不出來)
    a.legend(loc='upper left', frameon=False, fontsize=8)

fig.tight_layout(w_pad=2.0)
# fig.savefig(OUTPDF, bbox_inches='tight')
print(f'saved {OUTPDF}')
# Out:
# 3 TeV [Paper]: 68% [0.551, 1.800]   95% [0.218, 1.800]   window=None
# 3 TeV [woTDA]: 68% [0.470, 1.800]   95% [0.200, 1.800]   window=None
# 10 TeV [Paper]: 68% [0.941, 1.076]   95% [0.880, 1.148]   window=(0.8, 1.2)
# 10 TeV [DHH]: 68% [0.919, 1.118]   95% [0.844, 1.200]   window=(0.8, 1.2)
# 10 TeV [DHH woTDA]: 68% [0.917, 1.108]   95% [0.841, 1.200]   window=(0.8, 1.2)
# saved /root/data/mucollider/two_boosted/generated_fig/fig_result_boosted_hypo_k3.pdf

# %%
# ══════════════════ EDIT HERE ═══════════════════════════════════════════
# Case-1 scans (null = no HH).  DUMMY values = your Colab boosted scans.
K_3TEV   = np.array([0.2, 0.4, 0.6, 0.8, 0.9, 1.0, 1.1, 1.2, 1.4, 1.6, 1.8])
DLL_3TEV = np.array([14.064215765747058, 10.36620847026378, 7.514388721222976, 5.364456097073727, 4.514888766392209, 3.801340810435473, 3.1060753971662933, 2.620892901534984, 1.930592395445842, 1.6418256415564516, 1.5799752989646059])          # REPLACE with your scan
DLL_3TEV_woTDA = np.array([6.132223678328514, 4.272706795414057, 2.968580059517456, 2.014279358657185, 1.6407227888112912, 1.343777968555746, 1.0740530949824771, 0.8928353233357105, 0.6382341287354323, 0.5313725916436063, 0.5098968257700713])

K_10TEV   = np.array([0.2, 0.4, 0.6, 0.8, 0.9, 1.0, 1.1, 1.2, 1.4, 1.6, 1.8])
DLL_10TEV = np.array([757.0052734451558, 590.8276988831125, 447.97453627582087, 345.49754642003904, 307.10525216033386, 260.10903687295723, 226.67919625649157, 200.3635135733958, 157.07537249467148, 132.27587821615535, 126.36826683241999])   # REPLACE with your scan
DLL_10TEV_DHH_woTDA = np.array([744.7793192867764, 575.2312886863504, 437.10709618398954, 337.6441159500033, 296.72426601047283, 251.3301245264214, 220.68753281613536, 193.52020541626194, 150.9817583631922, 127.22356120394473, 119.57556163085243])

YLIM_3TEV  = (0, 15)
YLIM_10TEV = (0, 700)
TAG_EXTRA  = 'boosted'
OUTPDF     = '/root/data/mucollider/two_boosted/generated_fig/fig_result_boosted_hypo_noHH.pdf'
# ═════════════════════════════════════════════════════════════════════════

# 重新組織 PANELS_DATA，讓每個 Panel 可以包含多條曲線
PANELS_DATA = [
    {
        'title': '3 TeV',
        'ylim': YLIM_3TEV,
        'lines': [
            {'label': 'Paper', 'c': ps.C_3TEV, 'k': K_3TEV, 'dll': DLL_3TEV, 'ls': '-'},
            {'label': 'woTDA',   'c': 'C1',      'k': K_3TEV, 'dll': DLL_3TEV_woTDA, 'ls': '--'}
        ]
    },
    {
        'title': '10 TeV',
        'ylim': YLIM_10TEV,
        'lines': [
            {'label': 'Paper',   'c': ps.C_10TEV, 'k': K_10TEV, 'dll': DLL_10TEV, 'ls': '-'},
            {'label': 'DHH woTDA', 'c': 'C2',       'k': K_10TEV, 'dll': DLL_10TEV_DHH_woTDA, 'ls': '--'},
        ]
    }
]

kfine = np.linspace(0.2, 1.8, 401)
fig, ax = plt.subplots(1, 2, figsize=ps.SIZE12)

for a, panel in zip(ax, PANELS_DATA):
    title = panel['title']
    ylim = panel['ylim']
    
    # 迴圈畫出同一張圖內的多條線
    for line in panel['lines']:
        lbl = line['label']
        c = line['c']
        ls = line['ls']
        k = line['k']
        dll = line['dll']
        
        # 平滑曲線
        curve = np.poly1d(np.polyfit(k, dll, 4))(kfine)
        
        # 繪製曲線與數據點 (加入了 linestyle 與 label)
        a.plot(kfine, curve, ls=ls, color=c, lw=1.3, zorder=4, label=lbl)
        a.plot(k, dll, marker='o', ls='none', mfc='white', mec=c,
               mew=0.9, ms=3.2, zorder=5)
               
        # 自動找出 kappa3 接近 1.0 的位置，並印出 Z 顯著性
        i1 = int(np.argmin(np.abs(k - 1.0)))
        print(f'{title} [{lbl}]: kappa3=1  -DeltalnL={dll[i1]:.2f}  Z={np.sqrt(2*dll[i1]):.2f} sigma')

    # 基本網格與標籤設定
    a.axvline(1.0, color='0.7', lw=0.7, alpha=0.5)
    a.set_xlim(0.2, 1.8)
    a.set_ylim(*ylim)
    a.set_xticks(np.arange(0.2, 1.81, 0.2))
    a.set_xlabel(r'$\kappa_3 = \lambda_3/\lambda_3^{\rm SM}$')
    a.set_ylabel(r'$-\Delta\ln L$')
    
    # 加入 hep_tag 標籤
    ps.hep_tag(a, [rf'$\sqrt{{s}}={title.split()[0]}$ TeV', TAG_EXTRA],
               loc='upper right', simulation=True, fontsize=7.5)
               
    # 加入圖例 (Legend)，設定位置避免與數據和 hep_tag 重疊
    a.legend(loc='lower left', frameon=False, fontsize=8)

fig.tight_layout(w_pad=2.0)
# fig.savefig(OUTPDF, bbox_inches='tight')
print(f'saved {OUTPDF}')
# Out:
# 3 TeV [Paper]: kappa3=1  -DeltalnL=3.80  Z=2.76 sigma
# 3 TeV [woTDA]: kappa3=1  -DeltalnL=1.34  Z=1.64 sigma
# 10 TeV [Paper]: kappa3=1  -DeltalnL=260.11  Z=22.81 sigma
# 10 TeV [DHH woTDA]: kappa3=1  -DeltalnL=251.33  Z=22.42 sigma
# saved /root/data/mucollider/two_boosted/generated_fig/fig_result_boosted_hypo_noHH.pdf
