# %%
########## import some useful package ##########

import time
t1 = time.time()

import uproot
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm

import ripser
import persim

# %%
########## read the data ##########

processes = [f"run_{i:02d}_decayed_1" for i in range(1,12)]
kappa_3 = [0.2, 0.4, 0.6, 0.8, 0.9, 1, 1.1, 1.2, 1.4, 1.6, 1.8]
# kappa_3 = [0.8, 0.84, 0.88, 0.92, 0.96, 1, 1.04, 1.08, 1.12, 1.16, 1.2]
# Xsection_NoDecay = [5.713479e-1, 4.93855e-1, 4.268583e-1, 3.712657e-1, 3.481293e-1, 3.27342e-1, 3.09414e-1, 2.93892e-1, 2.714127e-1, 2.60030e-1, 2.593994e-1]     ### hhvv 0.2~1.8 unit: fb
Xsection_NoDecay = [8.02693355e-2, 7.0764282e-2, 6.2857524e-2, 5.5497495e-2, 5.25197799e-2, 4.94539493e-2, 4.67723243e-2, 4.4483030e-2, 4.055381e-2, 3.75464350e-2, 3.5563333e-2]     ### hhmumu 0.2~1.8 unit: fb
# Xsection_NoDecay = [3.7154566e-01, 3.617386e-01, 3.524371e-01, 3.4375437e-01, 3.3552887e-01, 3.273126e-01, 3.197475e-01, 3.126318e-01, 3.058909e-01, 2.993453e-01, 2.935034e-01]     ### hhvv 0.8~1.2 unit: fb
# Xsection_NoDecay = [5.5479319e-2, 5.433959e-2, 5.3013911e-2, 5.1688287e-2, 5.06150778e-2, 4.9453757e-2, 4.833858e-2, 4.740145e-2, 4.6342168e-2, 4.543942e-2, 4.4229705e-2]     ### hhmumu 0.8~1.2 unit: fb
BR_hbb = 0.5824
Xsection = []
for i in range(11):
    Xsection.append(Xsection_NoDecay[i]*BR_hbb*BR_hbb)
    
Luminosity = 10000   ### unit: fb^-1
simulation_num = 100000

features = ["VLCjetR10N2", "VLCjetR10N2.PT", "VLCjetR10N2.Mass", "VLCjetR10N2.Constituents", "EFlowTrack.fUniqueID", "EFlowTrack.PT", "EFlowTrack.Eta", "EFlowTrack.Phi", "EFlowTrack.PID", "EFlowPhoton.fUniqueID", "EFlowPhoton.ET", "EFlowPhoton.Eta", "EFlowPhoton.Phi", "EFlowNeutralHadron.fUniqueID", "EFlowNeutralHadron.ET", "EFlowNeutralHadron.Eta", "EFlowNeutralHadron.Phi"]

##### set data path #####

event_path = []
for type in processes:
    event_path.append("/data/mucollider/two_boosted/10TeV/scan_kappa3_hhmumu/Events/" + type + "/delphes_events.root")

##### get the data file #####

data_file =[]
for path in event_path:
    data_file.append(uproot.open(path))
    
##### read data with features #####
events = []     ### total events
for process in processes:
    tmp_events = []
    for feature in features:
        tmp_events.append(data_file[processes.index(process)]["Delphes;1"][feature].array())
    tmp_events = np.expand_dims(tmp_events, axis=-1)
    tmp_events = tmp_events.transpose((1,0,2))
    tmp_events = np.squeeze(tmp_events,axis=(2,))
    events.append(tmp_events)
    print(process, "Time:{:^8.4f}(s)".format(time.time()-t1))
del tmp_events
# Out:
# /usr/local/lib/python3.8/dist-packages/awkward/array/base.py:394: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return cls.numpy.array(value, copy=False)
# run_01_decayed_1 Time:13.9087 (s)
# run_02_decayed_1 Time:26.2240 (s)
# run_03_decayed_1 Time:39.1362 (s)
# run_04_decayed_1 Time:51.5988 (s)
# run_05_decayed_1 Time:64.4115 (s)
# run_06_decayed_1 Time:77.0925 (s)
# run_07_decayed_1 Time:88.6811 (s)
# run_08_decayed_1 Time:101.9580(s)
# run_09_decayed_1 Time:115.2739(s)
# run_10_decayed_1 Time:126.3720(s)
# run_11_decayed_1 Time:137.7196(s)

# %%
########## define useful function ##########

##### calculate significance #####

def significance(s,b):
    return np.sqrt(2*((s+b)*np.log(1+s/b)-s))

##### count event number #####

def count(events):
    events_num = []
    for i, process in enumerate(processes):
        events_num.append(len(events[processes.index(process)]))
        print("There are", events_num[i], process, "events. Corresponding cross section:", Xsection[processes.index(process)]*events_num[i]/simulation_num, "(fb)")
        
##### select if Fat Jet >= 2 #####
        
def Fat_Jet_selection(events):
    where1 = np.where(events[:,features.index("VLCjetR10N2")]>=2)
    return events[where1]

##### select if M_jet_leading > XX GeV #####

def mass_leading_selection(events, low_mass_cut, high_mass_cut):
    where1 = []
    for i in range(len(events)):
        switch=1
        if events[i][features.index("VLCjetR10N2.Mass")][0]<low_mass_cut:
            switch=0
        if events[i][features.index("VLCjetR10N2.Mass")][0]>high_mass_cut:
            switch=0
        if switch==1:
            where1.append(i)
    return events[where1]

##### select if M_jet_subleading > XX GeV #####

def mass_subleading_selection(events, low_mass_cut, high_mass_cut):
    where1 = []
    for i in range(len(events)):
        switch=1
        if events[i][features.index("VLCjetR10N2.Mass")][1]<low_mass_cut:
            switch=0
        if events[i][features.index("VLCjetR10N2.Mass")][1]>high_mass_cut:
            switch=0
        if switch==1:
            where1.append(i)
    return events[where1]

##### select if pT_J_leading > XX GeV #####

def pT_leading_selection(events, low_pT_cut, high_pT_cut):
    where1 = []
    for i in range(len(events)):
        switch = 1
        if events[i][features.index("VLCjetR10N2.PT")][0]<low_pT_cut:
            switch=0
        if events[i][features.index("VLCjetR10N2.PT")][0]>high_pT_cut:
            switch=0
        if switch==1:
            where1.append(i)
    return events[where1]

##### select if pT_J_subleading > XX GeV #####

def pT_subleading_selection(events, low_pT_cut, high_pT_cut):
    where1 = []
    for i in range(len(events)):
        switch = 1
        if events[i][features.index("VLCjetR10N2.PT")][1]<low_pT_cut:
            switch=0
        if events[i][features.index("VLCjetR10N2.PT")][1]>high_pT_cut:
            switch=0
        if switch==1:
            where1.append(i)
    return events[where1]

# %%
def get_particle_info(event):
    ##### set jet constituents ID #####

    leadingJ_constituents = event[features.index("VLCjetR10N2.Constituents")][0][:-1]
    subleadingJ_constituents= event[features.index("VLCjetR10N2.Constituents")][1][:-1]

    ##### construct infromation for all EFlow particles in this events and sort by PT #####

    all_ID = np.concatenate((event[features.index("EFlowTrack.fUniqueID")], event[features.index("EFlowPhoton.fUniqueID")], event[features.index("EFlowNeutralHadron.fUniqueID")]))
    all_PT = np.concatenate((event[features.index("EFlowTrack.PT")], event[features.index("EFlowPhoton.ET")], event[features.index("EFlowNeutralHadron.ET")]))
    all_Eta = np.concatenate((event[features.index("EFlowTrack.Eta")], event[features.index("EFlowPhoton.Eta")], event[features.index("EFlowNeutralHadron.Eta")]))
    all_Phi = np.concatenate((event[features.index("EFlowTrack.Phi")], event[features.index("EFlowPhoton.Phi")], event[features.index("EFlowNeutralHadron.Phi")]))
    all_PID = np.concatenate((event[features.index("EFlowTrack.PID")], np.full(len(event[features.index("EFlowPhoton.fUniqueID")]), 22), np.full(len(event[features.index("EFlowNeutralHadron.fUniqueID")]), 4)))

    #####                          categorize PID                      #####
    ##### 1:electron 2:muon 3:photon 4:neutral hadron 5:charged hadron #####

    condlist = [abs(all_PID)==11, abs(all_PID)==13, abs(all_PID)==22, abs(all_PID)==4]
    choicelist = [1, 2, 3, 4]
    all_PID = np.select(condlist, choicelist, 5)

    sort_order = np.argsort(all_PT)[::-1]   ### from large PT to low PT

    all_ID = all_ID[sort_order]
    all_PT = all_PT[sort_order]
    all_Eta = all_Eta[sort_order]
    all_Phi = all_Phi[sort_order]
    all_PID = all_PID[sort_order]

    ##### find Jet particle in EFlow particle #####
    if len(leadingJ_constituents)>20: where_leading = np.where(np.isin(all_ID, leadingJ_constituents))[0][0:20]
    else: where_leading = np.where(np.isin(all_ID, leadingJ_constituents))[0]

    if len(subleadingJ_constituents)>20: where_subleading = np.where(np.isin(all_ID, subleadingJ_constituents))[0][0:20]
    else: where_subleading = np.where(np.isin(all_ID, subleadingJ_constituents))[0]

    leadingJ_PT, subleadingJ_PT = all_PT[where_leading], all_PT[where_subleading]
    leadingJ_Eta, subleadingJ_Eta = all_Eta[where_leading], all_Eta[where_subleading]
    leadingJ_Phi, subleadingJ_Phi = all_Phi[where_leading], all_Phi[where_subleading]
    leadingJ_PID, subleadingJ_PID = all_PID[where_leading], all_PID[where_subleading]

    leadingJ_info, subleadingJ_info = np.stack((leadingJ_PT, leadingJ_Eta, leadingJ_Phi, leadingJ_PID), axis=1).ravel(), np.stack((subleadingJ_PT, subleadingJ_Eta, subleadingJ_Phi, subleadingJ_PID), axis=1).ravel()

    ##### do zero padding #####

    particle_info = np.zeros(2*20*4)
    particle_info[0:len(leadingJ_info)] = leadingJ_info
    particle_info[80:80+len(subleadingJ_info)] = subleadingJ_info
    
    return particle_info

# %%
########## preselection ##########

print("Before any selection:")
count(events)

##### 2 fat jet selection #####

for process in processes:
    events[processes.index(process)] = Fat_Jet_selection(events[processes.index(process)])
print("\nAfter 2 fat jet selection:")
count(events)

##### leading jet pT selection #####

leading_low_pT_cut = 200   ### GeV
leading_high_pT_cut = 800   ### GeV
for process in processes:
    events[processes.index(process)] = pT_leading_selection(events[processes.index(process)], leading_low_pT_cut, leading_high_pT_cut)
print("\nAfter leading jet pT selection:")
count(events)

##### subleading jet pT selection #####

subleading_low_pT_cut = 200   ### GeV
subleading_high_pT_cut = 600   ### GeV
for process in processes:
    events[processes.index(process)] = pT_subleading_selection(events[processes.index(process)], subleading_low_pT_cut, subleading_high_pT_cut)
print("\nAfter subleading jet pT selection:")
count(events)

##### leading jet mass selection #####

leading_low_mass_cut = 65
leading_high_mass_cut = 150
for process in processes:
    events[processes.index(process)] = mass_leading_selection(events[processes.index(process)], leading_low_mass_cut, leading_high_mass_cut)
print("\nAfter leading jet mass selection:")
count(events)

##### subleading jet mass selection #####

subleading_low_mass_cut = 65
subleading_high_mass_cut = 150
for process in processes:
    events[processes.index(process)] = mass_subleading_selection(events[processes.index(process)], subleading_low_mass_cut, subleading_high_mass_cut)
print("\nAfter subleading jet mass selection:")
count(events)
# Out:
# Before any selection:
# There are 100000 run_01_decayed_1 events. Corresponding cross section: 0.02722653664360448 (fb)
# There are 100000 run_02_decayed_1 events. Corresponding cross section: 0.02400251982815232 (fb)
# There are 100000 run_03_decayed_1 events. Corresponding cross section: 0.02132062847975424 (fb)
# There are 100000 run_04_decayed_1 events. Corresponding cross section: 0.018824182009651202 (fb)
# There are 100000 run_05_decayed_1 events. Corresponding cross section: 0.017814171539533824 (fb)
# There are 100000 run_06_decayed_1 events. Corresponding cross section: 0.01677427319411917 (fb)
# There are 100000 run_07_decayed_1 events. Corresponding cross section: 0.015864693453959168 (fb)
# There are 100000 run_08_decayed_1 events. Corresponding cross section: 0.015088188269772802 (fb)
# There are 100000 run_09_decayed_1 events. Corresponding cross section: 0.0137554370809856 (fb)
# There are 100000 run_10_decayed_1 events. Corresponding cross section: 0.012735366276505605 (fb)
# There are 100000 run_11_decayed_1 events. Corresponding cross section: 0.012062718385070084 (fb)
#
# After 2 fat jet selection:
# There are 99901 run_01_decayed_1 events. Corresponding cross section: 0.027199582372327315 (fb)
# There are 99892 run_02_decayed_1 events. Corresponding cross section: 0.02397659710673792 (fb)
# There are 99886 run_03_decayed_1 events. Corresponding cross section: 0.02129632296328732 (fb)
# There are 99874 run_04_decayed_1 events. Corresponding cross section: 0.018800463540319043 (fb)
# There are 99837 run_05_decayed_1 events. Corresponding cross section: 0.017785134439924383 (fb)
# There are 99849 run_06_decayed_1 events. Corresponding cross section: 0.01674894404159605 (fb)
# There are 99836 run_07_decayed_1 events. Corresponding cross section: 0.015838675356694674 (fb)
# There are 99820 run_08_decayed_1 events. Corresponding cross section: 0.015061029530887211 (fb)
# There are 99802 run_09_decayed_1 events. Corresponding cross section: 0.01372820131556525 (fb)
# There are 99821 run_10_decayed_1 events. Corresponding cross section: 0.012712569970870658 (fb)
# There are 99784 run_11_decayed_1 events. Corresponding cross section: 0.012036662913358332 (fb)
#
# After leading jet pT selection:
# There are 82174 run_01_decayed_1 events. Corresponding cross section: 0.02237313422151555 (fb)
# There are 81716 run_02_decayed_1 events. Corresponding cross section: 0.01961389910277295 (fb)
# There are 81077 run_03_decayed_1 events. Corresponding cross section: 0.017286125952530346 (fb)
# There are 80372 run_04_decayed_1 events. Corresponding cross section: 0.015129371564796863 (fb)
# There are 80171 run_05_decayed_1 events. Corresponding cross section: 0.014281799464959662 (fb)
# There are 79745 run_06_decayed_1 events. Corresponding cross section: 0.013376644158650332 (fb)
# There are 79339 run_07_decayed_1 events. Corresponding cross section: 0.012586889139436664 (fb)
# There are 79153 run_08_decayed_1 events. Corresponding cross section: 0.011942753661173264 (fb)
# There are 78404 run_09_decayed_1 events. Corresponding cross section: 0.01078481288897595 (fb)
# There are 78155 run_10_decayed_1 events. Corresponding cross section: 0.009953325513402953 (fb)
# There are 77747 run_11_decayed_1 events. Corresponding cross section: 0.009378401662840439 (fb)
#
# After subleading jet pT selection:
# There are 49170 run_01_decayed_1 events. Corresponding cross section: 0.013387288067660324 (fb)
# There are 48086 run_02_decayed_1 events. Corresponding cross section: 0.011541851684565325 (fb)
# There are 47026 run_03_decayed_1 events. Corresponding cross section: 0.01002623874888923 (fb)
# There are 45968 run_04_decayed_1 events. Corresponding cross section: 0.008653099986196464 (fb)
# There are 44933 run_05_decayed_1 events. Corresponding cross section: 0.008004441697858734 (fb)
# There are 44413 run_06_decayed_1 events. Corresponding cross section: 0.007449957953704147 (fb)
# There are 43539 run_07_decayed_1 events. Corresponding cross section: 0.006907328882919283 (fb)
# There are 42966 run_08_decayed_1 events. Corresponding cross section: 0.006482790971990582 (fb)
# There are 41538 run_09_decayed_1 events. Corresponding cross section: 0.005713733454699799 (fb)
# There are 40477 run_10_decayed_1 events. Corresponding cross section: 0.005154894207741173 (fb)
# There are 39577 run_11_decayed_1 events. Corresponding cross section: 0.004774062055259187 (fb)
#
# After leading jet mass selection:
# There are 39542 run_01_decayed_1 events. Corresponding cross section: 0.010765917119614084 (fb)
# There are 38613 run_02_decayed_1 events. Corresponding cross section: 0.009268092981244456 (fb)
# There are 37819 run_03_decayed_1 events. Corresponding cross section: 0.008063248484758256 (fb)
# There are 36974 run_04_decayed_1 events. Corresponding cross section: 0.0069600530562484355 (fb)
# There are 35982 run_05_decayed_1 events. Corresponding cross section: 0.006409895203355061 (fb)
# There are 35532 run_06_decayed_1 events. Corresponding cross section: 0.0059602347513344235 (fb)
# There are 34862 run_07_decayed_1 events. Corresponding cross section: 0.005530749431919245 (fb)
# There are 34136 run_08_decayed_1 events. Corresponding cross section: 0.005150503947769644 (fb)
# There are 32980 run_09_decayed_1 events. Corresponding cross section: 0.004536543149309051 (fb)
# There are 32138 run_10_decayed_1 events. Corresponding cross section: 0.004092892013943371 (fb)
# There are 31057 run_11_decayed_1 events. Corresponding cross section: 0.003746318448851216 (fb)
#
# After subleading jet mass selection:
# There are 27509 run_01_decayed_1 events. Corresponding cross section: 0.007489747965289157 (fb)
# There are 26827 run_02_decayed_1 events. Corresponding cross section: 0.006439155994298423 (fb)
# There are 26032 run_03_decayed_1 events. Corresponding cross section: 0.005550186005849624 (fb)
# There are 25242 run_04_decayed_1 events. Corresponding cross section: 0.004751600022876156 (fb)
# There are 24700 run_05_decayed_1 events. Corresponding cross section: 0.004400100370264855 (fb)
# There are 24391 run_06_decayed_1 events. Corresponding cross section: 0.004091412974777607 (fb)
# There are 23795 run_07_decayed_1 events. Corresponding cross section: 0.003775003807369584 (fb)
# There are 23234 run_08_decayed_1 events. Corresponding cross section: 0.003505589662599013 (fb)
# There are 22206 run_09_decayed_1 events. Corresponding cross section: 0.003054532358203663 (fb)
# There are 21426 run_10_decayed_1 events. Corresponding cross section: 0.00272867957840409 (fb)
# There are 20306 run_11_decayed_1 events. Corresponding cross section: 0.002449455595272331 (fb)
