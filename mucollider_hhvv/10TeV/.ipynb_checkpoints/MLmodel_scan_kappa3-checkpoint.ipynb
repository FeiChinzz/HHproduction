# %%
import time
t1 = time.time()

import math
import os
import numpy as np
import pandas as pd
import h5py
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm

import tensorflow as tf
import tensorflow.keras as keras
from tensorflow.keras import layers, models
from tensorflow.keras.optimizers import Adam , SGD , Adagrad
from tensorflow.keras.callbacks import ModelCheckpoint, LearningRateScheduler, EarlyStopping, CSVLogger, ReduceLROnPlateau
from tensorflow.keras.utils import to_categorical, plot_model
from tensorflow.keras import regularizers , initializers
from sklearn.metrics import confusion_matrix
import tensorflow.keras.backend as K
from sklearn import metrics
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split

gpus = tf.config.experimental.list_physical_devices("GPU")
tf.config.set_visible_devices(gpus[1], "GPU")

### set seed ###
keras.utils.set_random_seed(2330)
tf.config.experimental.enable_op_determinism()
# Out:
# 2026-05-06 02:41:56.443213: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
##### load data #####

hhvv_HLdata_path = "/root/data/mucollider/two_boosted/10TeV/scan_kappa3_hhvv_HL.h5"
hhvv_HLdata_file = h5py.File(hhvv_HLdata_path, 'r')
print(hhvv_HLdata_file.keys())

hhvv_LLdata_path = "/root/data/mucollider/two_boosted/10TeV/scan_kappa3_hhvv_LL.h5"
hhvv_LLdata_file = h5py.File(hhvv_LLdata_path, 'r')
print(hhvv_LLdata_file.keys())

hhmumu_HLdata_path = "/root/data/mucollider/two_boosted/10TeV/scan_kappa3_hhmumu_HL.h5"
hhmumu_HLdata_file = h5py.File(hhmumu_HLdata_path, 'r')
print(hhmumu_HLdata_file.keys())

hhmumu_LLdata_path = "/root/data/mucollider/two_boosted/10TeV/scan_kappa3_hhmumu_LL.h5"
hhmumu_LLdata_file = h5py.File(hhmumu_LLdata_path, 'r')
print(hhmumu_LLdata_file.keys())

HLdata_path = "/root/data/mucollider/two_boosted/10TeV/data_HLfeature.h5"
HLdata_file = h5py.File(HLdata_path, 'r')
print(HLdata_file.keys())

LLdata_path = "/root/data/mucollider/two_boosted/10TeV/data_LLfeature.h5"
LLdata_file = h5py.File(LLdata_path, 'r')
print(LLdata_file.keys())
# Out:
# <KeysViewHDF5 ['BTag_leading', 'BTag_subleading', 'H_0', 'H_1', 'LB_1', 'M_JJ', 'S_0', 'S_1', 'X_HH', 'dEta_JJ', 'm_J_leading', 'm_J_subleading', 'missET', 'pT_JJ', 'pt_J_leading', 'pt_J_subleading', 'target_kappa_3']>
# <KeysViewHDF5 ['particle_info']>
# <KeysViewHDF5 ['BTag_leading', 'BTag_subleading', 'H_0', 'H_1', 'LB_1', 'M_JJ', 'S_0', 'S_1', 'X_HH', 'dEta_JJ', 'm_J_leading', 'm_J_subleading', 'missET', 'pT_JJ', 'pt_J_leading', 'pt_J_subleading', 'target_kappa_3']>
# <KeysViewHDF5 ['particle_info']>
# <KeysViewHDF5 ['BTag_leading', 'BTag_subleading', 'H_0', 'H_1', 'LB_1', 'M_JJ', 'S_0', 'S_1', 'X_HH', 'dEta_JJ', 'm_J_leading', 'm_J_subleading', 'missET', 'pT_JJ', 'pt_J_leading', 'pt_J_subleading', 'target_everytype', 'target_sigbg']>
# <KeysViewHDF5 ['particle_info']>

# %%
##### include data #####

HLfeatures = ['BTag_leading', 'BTag_subleading', 'H_0', 'H_1', 'LB_1', 'M_JJ', 'S_0', 'S_1', 'X_HH', 'dEta_JJ', 'm_J_leading', 'm_J_subleading', 'missET', 'pT_JJ', 'pt_J_leading', 'pt_J_subleading']
LLfeatures = ['particle_info']

where_BG = np.where(HLdata_file['target_sigbg'][:]==0)

kappa3_val = 1.0
hhvv_where_kappa3 = np.where(hhvv_HLdata_file['target_kappa_3'][:]==kappa3_val)
hhmumu_where_kappa3 = np.where(hhmumu_HLdata_file['target_kappa_3'][:]==kappa3_val)

##### select BTag work point at WP70 (BitNumber 1) #####

BG_BTag_leading = ((HLdata_file['BTag_leading'][:][where_BG])&2)
BG_BTag_subleading = ((HLdata_file['BTag_subleading'][:][where_BG])&2)

##### include Signal data #####

hhvv_BTag_leading = ((hhvv_HLdata_file['BTag_leading'][:][hhvv_where_kappa3])&2)
hhvv_BTag_subleading = ((hhvv_HLdata_file['BTag_subleading'][:][hhvv_where_kappa3])&2)
hhmumu_BTag_leading = ((hhmumu_HLdata_file['BTag_leading'][:][hhmumu_where_kappa3])&2)
hhmumu_BTag_subleading = ((hhmumu_HLdata_file['BTag_subleading'][:][hhmumu_where_kappa3])&2)

hhvv_HLdata = []
for feature in HLfeatures:
    if feature=='BTag_leading': hhvv_HLdata.append(hhvv_BTag_leading)
    elif feature=='BTag_subleading': hhvv_HLdata.append(hhvv_BTag_subleading)
    else: hhvv_HLdata.append(hhvv_HLdata_file[feature][:][hhvv_where_kappa3])
hhvv_HLdata = np.array(hhvv_HLdata).T
print('shape of hhvv high level data:', hhvv_HLdata.shape)

hhvv_LLdata = hhvv_LLdata_file['particle_info'][:][hhvv_where_kappa3]
print('shape of hhvv low level data:', hhvv_LLdata.shape)

hhvv_target = np.ones(len(hhvv_where_kappa3[0]))
print('shape of hhvv target:', hhvv_target.shape)

hhmumu_HLdata = []
for feature in HLfeatures:
    if feature=='BTag_leading': hhmumu_HLdata.append(hhmumu_BTag_leading)
    elif feature=='BTag_subleading': hhmumu_HLdata.append(hhmumu_BTag_subleading)
    else: hhmumu_HLdata.append(hhmumu_HLdata_file[feature][:][hhmumu_where_kappa3])
hhmumu_HLdata = np.array(hhmumu_HLdata).T
print('shape of hhmumu high level data:', hhmumu_HLdata.shape)

hhmumu_LLdata = hhmumu_LLdata_file['particle_info'][:][hhmumu_where_kappa3]
print('shape of hhmumu low level data:', hhmumu_LLdata.shape)

hhmumu_target = np.ones(len(hhmumu_where_kappa3[0]))
print('shape of hhmumu target:', hhmumu_target.shape)

##### include Background data #####

BG_HLdata = []
for feature in HLfeatures:
    if feature=='BTag_leading': BG_HLdata.append(BG_BTag_leading)
    elif feature=='BTag_subleading': BG_HLdata.append(BG_BTag_subleading)
    else: BG_HLdata.append(HLdata_file[feature][:][where_BG])
BG_HLdata = np.array(BG_HLdata).T
print('shape of BG high level data:', BG_HLdata.shape)

BG_LLdata = LLdata_file['particle_info'][:][where_BG]
print('shape of BG low level data:', BG_LLdata.shape)

BG_target = HLdata_file['target_sigbg'][:][where_BG]
print('shape of BG target:', BG_target.shape)

##### merge the data #####

HLdata = np.concatenate((hhvv_HLdata, hhmumu_HLdata, BG_HLdata))
LLdata = np.concatenate((hhvv_LLdata, hhmumu_LLdata, BG_LLdata))
target = np.concatenate((hhvv_target, hhmumu_target, BG_target))

#### Do training data and validation data split #####

HL_train, HL_val, LL_train, LL_val, y_train, y_val = train_test_split(HLdata, LLdata, target, test_size=0.25, random_state=2330, shuffle=True)
print("\nAfter training validation data split:")
print("HL training data: ", HL_train.shape, "HL validation data: ", HL_val.shape)
print("LL training data: ", LL_train.shape, "LL validation data: ", LL_val.shape)
print("training target: ", y_train.shape, "validation target: ", y_val.shape)
# Out:
# shape of hhvv high level data: (22742, 16)
# shape of hhvv low level data: (22742, 160)
# shape of hhvv target: (22742,)
# shape of hhmumu high level data: (24391, 16)
# shape of hhmumu low level data: (24391, 160)
# shape of hhmumu target: (24391,)
# shape of BG high level data: (239264, 16)
# shape of BG low level data: (239264, 160)
# shape of BG target: (239264,)
#
# After training validation data split:
# HL training data:  (214797, 16) HL validation data:  (71600, 16)
# LL training data:  (214797, 160) LL validation data:  (71600, 160)
# training target:  (214797,) validation target:  (71600,)

# %%
where_BG
# Out:
# (array([     0,      1,      2, ..., 239261, 239262, 239263]),)

# %%
##### construct model #####

### high level features part ###

HL_input = layers.Input(shape=(16,), name='HL_Input')

x_hl = layers.Dense(128)(HL_input)
x_hl = layers.BatchNormalization()(x_hl)
x_hl = layers.Activation('relu')(x_hl)
x_hl = layers.Dropout(0.1)(x_hl)

x_hl = layers.Dense(128)(x_hl)
x_hl = layers.BatchNormalization()(x_hl)
x_hl = layers.Activation('relu')(x_hl)
x_hl = layers.Dropout(0.1)(x_hl)

### low level features part ###

LL_input = layers.Input(shape=(160,), name='LL_Input')

x_ll = layers.Dense(512)(LL_input)
x_ll = layers.BatchNormalization()(x_ll)
x_ll = layers.Activation('relu')(x_ll)
x_ll = layers.Dropout(0.1)(x_ll)

x_ll = layers.Dense(128)(x_ll)
x_ll = layers.BatchNormalization()(x_ll)
x_ll = layers.Activation('relu')(x_ll)
x_ll = layers.Dropout(0.1)(x_ll)

### combine two parts of model and the following node ###

combined = layers.Concatenate()([x_hl, x_ll])

x = layers.Dense(256, activation='relu')(combined)
x = layers.Dense(16, activation='relu')(x)
output = layers.Dense(1, activation='sigmoid', name='Output')(x)

model = models.Model(inputs=[HL_input, LL_input], outputs=output)

### optimizer ###

opt = keras.optimizers.Adam(learning_rate=1e-5)

### compile ###

model.compile(loss='binary_crossentropy', optimizer=opt, metrics=["accuracy","mse"])

### summary ###

model.summary()
# Out:
# 2026-05-06 02:42:00.511027: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 46696 MB memory:  -> device: 1, name: NVIDIA RTX A6000, pci bus id: 0000:25:00.0, compute capability: 8.6
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  HL_Input (InputLayer)       [(None, 16)]                 0         []
#
#  LL_Input (InputLayer)       [(None, 160)]                0         []
#
#  dense (Dense)               (None, 128)                  2176      ['HL_Input[0][0]']
#
#  dense_2 (Dense)             (None, 512)                  82432     ['LL_Input[0][0]']
#
#  batch_normalization (Batch  (None, 128)                  512       ['dense[0][0]']
#  Normalization)
#
#  batch_normalization_2 (Bat  (None, 512)                  2048      ['dense_2[0][0]']
#  chNormalization)
#
#  activation (Activation)     (None, 128)                  0         ['batch_normalization[0][0]']
#
#  activation_2 (Activation)   (None, 512)                  0         ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  dropout (Dropout)           (None, 128)                  0         ['activation[0][0]']
#
#  dropout_2 (Dropout)         (None, 512)                  0         ['activation_2[0][0]']
#
#  dense_1 (Dense)             (None, 128)                  16512     ['dropout[0][0]']
#
#  dense_3 (Dense)             (None, 128)                  65664     ['dropout_2[0][0]']
#
#  batch_normalization_1 (Bat  (None, 128)                  512       ['dense_1[0][0]']
#  chNormalization)
#
#  batch_normalization_3 (Bat  (None, 128)                  512       ['dense_3[0][0]']
#  chNormalization)
#
#  activation_1 (Activation)   (None, 128)                  0         ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  activation_3 (Activation)   (None, 128)                  0         ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  dropout_1 (Dropout)         (None, 128)                  0         ['activation_1[0][0]']
#
#  dropout_3 (Dropout)         (None, 128)                  0         ['activation_3[0][0]']
#
#  concatenate (Concatenate)   (None, 256)                  0         ['dropout_1[0][0]',
#                                                                      'dropout_3[0][0]']
#
#  dense_4 (Dense)             (None, 256)                  65792     ['concatenate[0][0]']
#
#  dense_5 (Dense)             (None, 16)                   4112      ['dense_4[0][0]']
#
#  Output (Dense)              (None, 1)                    17        ['dense_5[0][0]']
#
# ==================================================================================================
# Total params: 240289 (938.63 KB)
# Trainable params: 238497 (931.63 KB)
# Non-trainable params: 1792 (7.00 KB)
# __________________________________________________________________________________________________

# %%
##### training model #####

tr_model = model.fit(x=[HL_train, LL_train], y=y_train, validation_data=([HL_val, LL_val], y_val), epochs=160, batch_size=256, verbose=1)
# Out:
# Epoch 1/160
# 2026-05-06 02:42:05.486915: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:606] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2026-05-06 02:42:05.499975: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7f39500054a0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2026-05-06 02:42:05.500138: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA RTX A6000, Compute Capability 8.6
# 2026-05-06 02:42:05.508725: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:255] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2026-05-06 02:42:05.711425: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:432] Loaded cuDNN version 8600
# 2026-05-06 02:42:05.851798: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 840/840 [==============================] - 17s 12ms/step - loss: 0.3991 - accuracy: 0.8376 - mse: 0.1238 - val_loss: 0.3680 - val_accuracy: 0.8494 - val_mse: 0.1129
# Epoch 2/160
# 840/840 [==============================] - 9s 10ms/step - loss: 0.3533 - accuracy: 0.8533 - mse: 0.1083 - val_loss: 0.3259 - val_accuracy: 0.8700 - val_mse: 0.0981
# Epoch 3/160
# 840/840 [==============================] - 9s 11ms/step - loss: 0.3046 - accuracy: 0.8761 - mse: 0.0916 - val_loss: 0.2670 - val_accuracy: 0.8922 - val_mse: 0.0788
# Epoch 4/160
# 840/840 [==============================] - 10s 12ms/step - loss: 0.2724 - accuracy: 0.8906 - mse: 0.0811 - val_loss: 0.2447 - val_accuracy: 0.9016 - val_mse: 0.0724
# Epoch 5/160
# 840/840 [==============================] - 10s 12ms/step - loss: 0.2622 - accuracy: 0.8948 - mse: 0.0780 - val_loss: 0.2381 - val_accuracy: 0.9045 - val_mse: 0.0704
# Epoch 6/160
# 840/840 [==============================] - 11s 13ms/step - loss: 0.2577 - accuracy: 0.8969 - mse: 0.0765 - val_loss: 0.2337 - val_accuracy: 0.9064 - val_mse: 0.0691
# Epoch 7/160
# 840/840 [==============================] - 9s 11ms/step - loss: 0.2532 - accuracy: 0.8992 - mse: 0.0752 - val_loss: 0.2312 - val_accuracy: 0.9080 - val_mse: 0.0682
# Epoch 8/160
# 840/840 [==============================] - 10s 12ms/step - loss: 0.2513 - accuracy: 0.9000 - mse: 0.0745 - val_loss: 0.2264 - val_accuracy: 0.9113 - val_mse: 0.0665
# Epoch 9/160
# 840/840 [==============================] - 9s 11ms/step - loss: 0.2474 - accuracy: 0.9015 - mse: 0.0734 - val_loss: 0.2240 - val_accuracy: 0.9120 - val_mse: 0.0658
# Epoch 10/160
# 840/840 [==============================] - 10s 11ms/step - loss: 0.2443 - accuracy: 0.9032 - mse: 0.0723 - val_loss: 0.2228 - val_accuracy: 0.9125 - val_mse: 0.0654
# Epoch 11/160
# 840/840 [==============================] - 9s 11ms/step - loss: 0.2427 - accuracy: 0.9040 - mse: 0.0718 - val_loss: 0.2192 - val_accuracy: 0.9148 - val_mse: 0.0642
# Epoch 12/160
# 840/840 [==============================] - 9s 11ms/step - loss: 0.2399 - accuracy: 0.9048 - mse: 0.0711 - val_loss: 0.2165 - val_accuracy: 0.9160 - val_mse: 0.0635
# Epoch 13/160
# 840/840 [==============================] - 10s 12ms/step - loss: 0.2380 - accuracy: 0.9058 - mse: 0.0704 - val_loss: 0.2152 - val_accuracy: 0.9167 - val_mse: 0.0630
# Epoch 14/160
# 840/840 [==============================] - 9s 10ms/step - loss: 0.2360 - accuracy: 0.9062 - mse: 0.0698 - val_loss: 0.2124 - val_accuracy: 0.9191 - val_mse: 0.0619
# Epoch 15/160
# 840/840 [==============================] - 10s 11ms/step - loss: 0.2333 - accuracy: 0.9075 - mse: 0.0690 - val_loss: 0.2108 - val_accuracy: 0.9194 - val_mse: 0.0615
# Epoch 16/160
# 840/840 [==============================] - 9s 11ms/step - loss: 0.2314 - accuracy: 0.9086 - mse: 0.0684 - val_loss: 0.2091 - val_accuracy: 0.9201 - val_mse: 0.0610
# Epoch 17/160
# 840/840 [==============================] - 9s 11ms/step - loss: 0.2295 - accuracy: 0.9086 - mse: 0.0680 - val_loss: 0.2066 - val_accuracy: 0.9221 - val_mse: 0.0601
# Epoch 18/160
# 840/840 [==============================] - 8s 10ms/step - loss: 0.2276 - accuracy: 0.9100 - mse: 0.0672 - val_loss: 0.2053 - val_accuracy: 0.9228 - val_mse: 0.0598
# Epoch 19/160
# 840/840 [==============================] - 9s 11ms/step - loss: 0.2264 - accuracy: 0.9102 - mse: 0.0670 - val_loss: 0.2037 - val_accuracy: 0.9225 - val_mse: 0.0593
# Epoch 20/160
# 840/840 [==============================] - 8s 10ms/step - loss: 0.2240 - accuracy: 0.9118 - mse: 0.0662 - val_loss: 0.2018 - val_accuracy: 0.9240 - val_mse: 0.0588
# Epoch 21/160
# 840/840 [==============================] - 10s 12ms/step - loss: 0.2227 - accuracy: 0.9123 - mse: 0.0658 - val_loss: 0.2007 - val_accuracy: 0.9242 - val_mse: 0.0584
# Epoch 22/160
# 840/840 [==============================] - 10s 12ms/step - loss: 0.2228 - accuracy: 0.9115 - mse: 0.0659 - val_loss: 0.1994 - val_accuracy: 0.9247 - val_mse: 0.0579
# Epoch 23/160
# 840/840 [==============================] - 9s 11ms/step - loss: 0.2182 - accuracy: 0.9140 - mse: 0.0644 - val_loss: 0.1976 - val_accuracy: 0.9256 - val_mse: 0.0575
# Epoch 24/160
# 840/840 [==============================] - 9s 10ms/step - loss: 0.2179 - accuracy: 0.9141 - mse: 0.0643 - val_loss: 0.1969 - val_accuracy: 0.9254 - val_mse: 0.0573
# Epoch 25/160
# 840/840 [==============================] - 9s 11ms/step - loss: 0.2170 - accuracy: 0.9145 - mse: 0.0641 - val_loss: 0.1954 - val_accuracy: 0.9261 - val_mse: 0.0568
# Epoch 26/160
# 840/840 [==============================] - 10s 11ms/step - loss: 0.2155 - accuracy: 0.9148 - mse: 0.0638 - val_loss: 0.1940 - val_accuracy: 0.9271 - val_mse: 0.0564
# Epoch 27/160
# 840/840 [==============================] - 9s 11ms/step - loss: 0.2138 - accuracy: 0.9157 - mse: 0.0631 - val_loss: 0.1933 - val_accuracy: 0.9273 - val_mse: 0.0562
# Epoch 28/160
# 840/840 [==============================] - 8s 10ms/step - loss: 0.2128 - accuracy: 0.9162 - mse: 0.0628 - val_loss: 0.1923 - val_accuracy: 0.9277 - val_mse: 0.0559
# Epoch 29/160
# 840/840 [==============================] - 9s 10ms/step - loss: 0.2116 - accuracy: 0.9161 - mse: 0.0625 - val_loss: 0.1919 - val_accuracy: 0.9270 - val_mse: 0.0559
# Epoch 30/160
# 840/840 [==============================] - 9s 11ms/step - loss: 0.2099 - accuracy: 0.9173 - mse: 0.0620 - val_loss: 0.1900 - val_accuracy: 0.9286 - val_mse: 0.0553
# Epoch 31/160
# 840/840 [==============================] - 8s 10ms/step - loss: 0.2086 - accuracy: 0.9175 - mse: 0.0616 - val_loss: 0.1899 - val_accuracy: 0.9284 - val_mse: 0.0552
# Epoch 32/160
# 840/840 [==============================] - 9s 11ms/step - loss: 0.2085 - accuracy: 0.9177 - mse: 0.0616 - val_loss: 0.1886 - val_accuracy: 0.9291 - val_mse: 0.0548
# Epoch 33/160
# 840/840 [==============================] - 9s 11ms/step - loss: 0.2076 - accuracy: 0.9181 - mse: 0.0613 - val_loss: 0.1868 - val_accuracy: 0.9300 - val_mse: 0.0542
# Epoch 34/160
# 840/840 [==============================] - 10s 12ms/step - loss: 0.2061 - accuracy: 0.9190 - mse: 0.0608 - val_loss: 0.1862 - val_accuracy: 0.9303 - val_mse: 0.0541
# Epoch 35/160
# 840/840 [==============================] - 9s 11ms/step - loss: 0.2052 - accuracy: 0.9195 - mse: 0.0605 - val_loss: 0.1852 - val_accuracy: 0.9306 - val_mse: 0.0538
# Epoch 36/160
# 840/840 [==============================] - 10s 12ms/step - loss: 0.2048 - accuracy: 0.9194 - mse: 0.0605 - val_loss: 0.1842 - val_accuracy: 0.9310 - val_mse: 0.0534
# Epoch 37/160
# 840/840 [==============================] - 8s 10ms/step - loss: 0.2035 - accuracy: 0.9198 - mse: 0.0601 - val_loss: 0.1838 - val_accuracy: 0.9303 - val_mse: 0.0535
# Epoch 38/160
# 840/840 [==============================] - 10s 12ms/step - loss: 0.2030 - accuracy: 0.9206 - mse: 0.0599 - val_loss: 0.1830 - val_accuracy: 0.9314 - val_mse: 0.0531
# Epoch 39/160
# 840/840 [==============================] - 9s 11ms/step - loss: 0.2018 - accuracy: 0.9209 - mse: 0.0595 - val_loss: 0.1822 - val_accuracy: 0.9312 - val_mse: 0.0530
# Epoch 40/160
# 840/840 [==============================] - 9s 11ms/step - loss: 0.2005 - accuracy: 0.9212 - mse: 0.0592 - val_loss: 0.1808 - val_accuracy: 0.9319 - val_mse: 0.0525
# Epoch 41/160
# 840/840 [==============================] - 9s 11ms/step - loss: 0.2000 - accuracy: 0.9209 - mse: 0.0592 - val_loss: 0.1803 - val_accuracy: 0.9321 - val_mse: 0.0523
# Epoch 42/160
# 840/840 [==============================] - 9s 11ms/step - loss: 0.1985 - accuracy: 0.9221 - mse: 0.0587 - val_loss: 0.1794 - val_accuracy: 0.9327 - val_mse: 0.0520
# Epoch 43/160
# 840/840 [==============================] - 8s 10ms/step - loss: 0.1978 - accuracy: 0.9221 - mse: 0.0584 - val_loss: 0.1790 - val_accuracy: 0.9322 - val_mse: 0.0520
# Epoch 44/160
# 840/840 [==============================] - 9s 11ms/step - loss: 0.1977 - accuracy: 0.9226 - mse: 0.0583 - val_loss: 0.1783 - val_accuracy: 0.9328 - val_mse: 0.0517
# Epoch 45/160
# 840/840 [==============================] - 10s 12ms/step - loss: 0.1963 - accuracy: 0.9227 - mse: 0.0579 - val_loss: 0.1767 - val_accuracy: 0.9339 - val_mse: 0.0512
# Epoch 46/160
# 840/840 [==============================] - 9s 11ms/step - loss: 0.1957 - accuracy: 0.9230 - mse: 0.0578 - val_loss: 0.1762 - val_accuracy: 0.9339 - val_mse: 0.0511
# Epoch 47/160
# 840/840 [==============================] - 10s 12ms/step - loss: 0.1948 - accuracy: 0.9234 - mse: 0.0576 - val_loss: 0.1753 - val_accuracy: 0.9336 - val_mse: 0.0509
# Epoch 48/160
# 840/840 [==============================] - 9s 11ms/step - loss: 0.1935 - accuracy: 0.9239 - mse: 0.0571 - val_loss: 0.1744 - val_accuracy: 0.9347 - val_mse: 0.0506
# Epoch 49/160
# 840/840 [==============================] - 9s 11ms/step - loss: 0.1929 - accuracy: 0.9247 - mse: 0.0569 - val_loss: 0.1737 - val_accuracy: 0.9351 - val_mse: 0.0504
# Epoch 50/160
# 840/840 [==============================] - 10s 12ms/step - loss: 0.1915 - accuracy: 0.9243 - mse: 0.0567 - val_loss: 0.1723 - val_accuracy: 0.9354 - val_mse: 0.0499
# Epoch 51/160
# 840/840 [==============================] - 10s 12ms/step - loss: 0.1911 - accuracy: 0.9254 - mse: 0.0563 - val_loss: 0.1723 - val_accuracy: 0.9350 - val_mse: 0.0501
# Epoch 52/160
# 840/840 [==============================] - 9s 11ms/step - loss: 0.1903 - accuracy: 0.9259 - mse: 0.0561 - val_loss: 0.1709 - val_accuracy: 0.9354 - val_mse: 0.0496
# Epoch 53/160
# 840/840 [==============================] - 11s 13ms/step - loss: 0.1890 - accuracy: 0.9260 - mse: 0.0558 - val_loss: 0.1696 - val_accuracy: 0.9364 - val_mse: 0.0491
# Epoch 54/160
# 840/840 [==============================] - 10s 12ms/step - loss: 0.1875 - accuracy: 0.9265 - mse: 0.0554 - val_loss: 0.1692 - val_accuracy: 0.9364 - val_mse: 0.0491
# Epoch 55/160
# 840/840 [==============================] - 9s 11ms/step - loss: 0.1861 - accuracy: 0.9268 - mse: 0.0549 - val_loss: 0.1679 - val_accuracy: 0.9370 - val_mse: 0.0486
# Epoch 56/160
# 840/840 [==============================] - 9s 11ms/step - loss: 0.1857 - accuracy: 0.9275 - mse: 0.0547 - val_loss: 0.1672 - val_accuracy: 0.9371 - val_mse: 0.0485
# Epoch 57/160
# 840/840 [==============================] - 9s 10ms/step - loss: 0.1840 - accuracy: 0.9281 - mse: 0.0542 - val_loss: 0.1659 - val_accuracy: 0.9378 - val_mse: 0.0481
# Epoch 58/160
# 840/840 [==============================] - 10s 12ms/step - loss: 0.1840 - accuracy: 0.9282 - mse: 0.0542 - val_loss: 0.1650 - val_accuracy: 0.9381 - val_mse: 0.0478
# Epoch 59/160
# 840/840 [==============================] - 9s 11ms/step - loss: 0.1818 - accuracy: 0.9290 - mse: 0.0536 - val_loss: 0.1639 - val_accuracy: 0.9387 - val_mse: 0.0475
# Epoch 60/160
# 840/840 [==============================] - 9s 11ms/step - loss: 0.1821 - accuracy: 0.9293 - mse: 0.0536 - val_loss: 0.1634 - val_accuracy: 0.9391 - val_mse: 0.0473
# Epoch 61/160
# 840/840 [==============================] - 11s 13ms/step - loss: 0.1810 - accuracy: 0.9293 - mse: 0.0534 - val_loss: 0.1623 - val_accuracy: 0.9393 - val_mse: 0.0470
# Epoch 62/160
# 840/840 [==============================] - 9s 11ms/step - loss: 0.1796 - accuracy: 0.9299 - mse: 0.0529 - val_loss: 0.1621 - val_accuracy: 0.9391 - val_mse: 0.0470
# Epoch 63/160
# 840/840 [==============================] - 9s 10ms/step - loss: 0.1794 - accuracy: 0.9300 - mse: 0.0529 - val_loss: 0.1608 - val_accuracy: 0.9403 - val_mse: 0.0465
# Epoch 64/160
# 840/840 [==============================] - 8s 10ms/step - loss: 0.1778 - accuracy: 0.9308 - mse: 0.0523 - val_loss: 0.1603 - val_accuracy: 0.9399 - val_mse: 0.0465
# Epoch 65/160
# 840/840 [==============================] - 10s 11ms/step - loss: 0.1775 - accuracy: 0.9310 - mse: 0.0523 - val_loss: 0.1592 - val_accuracy: 0.9405 - val_mse: 0.0462
# Epoch 66/160
# 840/840 [==============================] - 11s 13ms/step - loss: 0.1765 - accuracy: 0.9315 - mse: 0.0520 - val_loss: 0.1585 - val_accuracy: 0.9408 - val_mse: 0.0459
# Epoch 67/160
# 840/840 [==============================] - 9s 11ms/step - loss: 0.1752 - accuracy: 0.9319 - mse: 0.0515 - val_loss: 0.1577 - val_accuracy: 0.9412 - val_mse: 0.0457
# Epoch 68/160
# 840/840 [==============================] - 10s 12ms/step - loss: 0.1738 - accuracy: 0.9324 - mse: 0.0512 - val_loss: 0.1570 - val_accuracy: 0.9415 - val_mse: 0.0455
# Epoch 69/160
# 840/840 [==============================] - 10s 12ms/step - loss: 0.1729 - accuracy: 0.9332 - mse: 0.0508 - val_loss: 0.1557 - val_accuracy: 0.9421 - val_mse: 0.0451
# Epoch 70/160
# 840/840 [==============================] - 9s 11ms/step - loss: 0.1709 - accuracy: 0.9338 - mse: 0.0503 - val_loss: 0.1549 - val_accuracy: 0.9424 - val_mse: 0.0448
# Epoch 71/160
# 840/840 [==============================] - 10s 12ms/step - loss: 0.1710 - accuracy: 0.9333 - mse: 0.0503 - val_loss: 0.1542 - val_accuracy: 0.9423 - val_mse: 0.0447
# Epoch 72/160
# 840/840 [==============================] - 10s 12ms/step - loss: 0.1704 - accuracy: 0.9337 - mse: 0.0501 - val_loss: 0.1541 - val_accuracy: 0.9422 - val_mse: 0.0446
# Epoch 73/160
# 840/840 [==============================] - 10s 12ms/step - loss: 0.1698 - accuracy: 0.9342 - mse: 0.0499 - val_loss: 0.1534 - val_accuracy: 0.9424 - val_mse: 0.0445
# Epoch 74/160
# 840/840 [==============================] - 9s 10ms/step - loss: 0.1673 - accuracy: 0.9352 - mse: 0.0491 - val_loss: 0.1523 - val_accuracy: 0.9432 - val_mse: 0.0441
# Epoch 75/160
# 840/840 [==============================] - 8s 10ms/step - loss: 0.1677 - accuracy: 0.9348 - mse: 0.0493 - val_loss: 0.1515 - val_accuracy: 0.9435 - val_mse: 0.0439
# Epoch 76/160
# 840/840 [==============================] - 9s 10ms/step - loss: 0.1665 - accuracy: 0.9357 - mse: 0.0490 - val_loss: 0.1523 - val_accuracy: 0.9423 - val_mse: 0.0443
# Epoch 77/160
# 840/840 [==============================] - 9s 11ms/step - loss: 0.1661 - accuracy: 0.9354 - mse: 0.0488 - val_loss: 0.1503 - val_accuracy: 0.9436 - val_mse: 0.0436
# Epoch 78/160
# 840/840 [==============================] - 10s 12ms/step - loss: 0.1648 - accuracy: 0.9361 - mse: 0.0484 - val_loss: 0.1496 - val_accuracy: 0.9438 - val_mse: 0.0434
# Epoch 79/160
# 840/840 [==============================] - 10s 11ms/step - loss: 0.1646 - accuracy: 0.9359 - mse: 0.0484 - val_loss: 0.1491 - val_accuracy: 0.9441 - val_mse: 0.0432
# Epoch 80/160
# 840/840 [==============================] - 9s 10ms/step - loss: 0.1629 - accuracy: 0.9371 - mse: 0.0478 - val_loss: 0.1488 - val_accuracy: 0.9437 - val_mse: 0.0432
# Epoch 81/160
# 840/840 [==============================] - 10s 12ms/step - loss: 0.1621 - accuracy: 0.9370 - mse: 0.0477 - val_loss: 0.1473 - val_accuracy: 0.9443 - val_mse: 0.0427
# Epoch 82/160
# 840/840 [==============================] - 10s 12ms/step - loss: 0.1614 - accuracy: 0.9374 - mse: 0.0474 - val_loss: 0.1475 - val_accuracy: 0.9442 - val_mse: 0.0429
# Epoch 83/160
# 840/840 [==============================] - 10s 11ms/step - loss: 0.1607 - accuracy: 0.9375 - mse: 0.0472 - val_loss: 0.1461 - val_accuracy: 0.9450 - val_mse: 0.0424
# Epoch 84/160
# 840/840 [==============================] - 8s 10ms/step - loss: 0.1604 - accuracy: 0.9377 - mse: 0.0471 - val_loss: 0.1460 - val_accuracy: 0.9448 - val_mse: 0.0424
# Epoch 85/160
# 840/840 [==============================] - 8s 9ms/step - loss: 0.1595 - accuracy: 0.9386 - mse: 0.0467 - val_loss: 0.1451 - val_accuracy: 0.9448 - val_mse: 0.0422
# Epoch 86/160
# 840/840 [==============================] - 9s 10ms/step - loss: 0.1589 - accuracy: 0.9386 - mse: 0.0467 - val_loss: 0.1449 - val_accuracy: 0.9450 - val_mse: 0.0421
# Epoch 87/160
# 840/840 [==============================] - 10s 12ms/step - loss: 0.1575 - accuracy: 0.9391 - mse: 0.0463 - val_loss: 0.1443 - val_accuracy: 0.9452 - val_mse: 0.0420
# Epoch 88/160
# 840/840 [==============================] - 11s 13ms/step - loss: 0.1574 - accuracy: 0.9392 - mse: 0.0462 - val_loss: 0.1438 - val_accuracy: 0.9455 - val_mse: 0.0418
# Epoch 89/160
# 840/840 [==============================] - 9s 11ms/step - loss: 0.1560 - accuracy: 0.9396 - mse: 0.0458 - val_loss: 0.1429 - val_accuracy: 0.9454 - val_mse: 0.0416
# Epoch 90/160
# 840/840 [==============================] - 9s 10ms/step - loss: 0.1565 - accuracy: 0.9391 - mse: 0.0460 - val_loss: 0.1428 - val_accuracy: 0.9457 - val_mse: 0.0416
# Epoch 91/160
# 840/840 [==============================] - 9s 11ms/step - loss: 0.1553 - accuracy: 0.9398 - mse: 0.0457 - val_loss: 0.1436 - val_accuracy: 0.9453 - val_mse: 0.0419
# Epoch 92/160
# 840/840 [==============================] - 11s 13ms/step - loss: 0.1544 - accuracy: 0.9398 - mse: 0.0453 - val_loss: 0.1421 - val_accuracy: 0.9455 - val_mse: 0.0414
# Epoch 93/160
# 840/840 [==============================] - 9s 11ms/step - loss: 0.1539 - accuracy: 0.9401 - mse: 0.0453 - val_loss: 0.1419 - val_accuracy: 0.9459 - val_mse: 0.0413
# Epoch 94/160
# 840/840 [==============================] - 9s 11ms/step - loss: 0.1533 - accuracy: 0.9407 - mse: 0.0450 - val_loss: 0.1411 - val_accuracy: 0.9462 - val_mse: 0.0411
# Epoch 95/160
# 840/840 [==============================] - 10s 11ms/step - loss: 0.1525 - accuracy: 0.9412 - mse: 0.0448 - val_loss: 0.1409 - val_accuracy: 0.9460 - val_mse: 0.0411
# Epoch 96/160
# 840/840 [==============================] - 9s 11ms/step - loss: 0.1518 - accuracy: 0.9412 - mse: 0.0446 - val_loss: 0.1402 - val_accuracy: 0.9463 - val_mse: 0.0409
# Epoch 97/160
# 840/840 [==============================] - 9s 11ms/step - loss: 0.1510 - accuracy: 0.9412 - mse: 0.0444 - val_loss: 0.1397 - val_accuracy: 0.9465 - val_mse: 0.0408
# Epoch 98/160
# 840/840 [==============================] - 10s 12ms/step - loss: 0.1505 - accuracy: 0.9413 - mse: 0.0442 - val_loss: 0.1396 - val_accuracy: 0.9465 - val_mse: 0.0408
# Epoch 99/160
# 840/840 [==============================] - 10s 12ms/step - loss: 0.1491 - accuracy: 0.9418 - mse: 0.0438 - val_loss: 0.1389 - val_accuracy: 0.9467 - val_mse: 0.0406
# Epoch 100/160
# 840/840 [==============================] - 9s 11ms/step - loss: 0.1495 - accuracy: 0.9423 - mse: 0.0440 - val_loss: 0.1387 - val_accuracy: 0.9471 - val_mse: 0.0405
# Epoch 101/160
# 840/840 [==============================] - 8s 9ms/step - loss: 0.1486 - accuracy: 0.9425 - mse: 0.0436 - val_loss: 0.1385 - val_accuracy: 0.9470 - val_mse: 0.0405
# Epoch 102/160
# 840/840 [==============================] - 10s 11ms/step - loss: 0.1488 - accuracy: 0.9420 - mse: 0.0438 - val_loss: 0.1381 - val_accuracy: 0.9468 - val_mse: 0.0404
# Epoch 103/160
# 840/840 [==============================] - 9s 11ms/step - loss: 0.1474 - accuracy: 0.9427 - mse: 0.0434 - val_loss: 0.1375 - val_accuracy: 0.9471 - val_mse: 0.0402
# Epoch 104/160
# 840/840 [==============================] - 9s 11ms/step - loss: 0.1474 - accuracy: 0.9423 - mse: 0.0434 - val_loss: 0.1378 - val_accuracy: 0.9469 - val_mse: 0.0403
# Epoch 105/160
# 840/840 [==============================] - 8s 10ms/step - loss: 0.1468 - accuracy: 0.9429 - mse: 0.0432 - val_loss: 0.1374 - val_accuracy: 0.9472 - val_mse: 0.0402
# Epoch 106/160
# 840/840 [==============================] - 9s 11ms/step - loss: 0.1468 - accuracy: 0.9431 - mse: 0.0432 - val_loss: 0.1369 - val_accuracy: 0.9472 - val_mse: 0.0401
# Epoch 107/160
# 840/840 [==============================] - 9s 10ms/step - loss: 0.1465 - accuracy: 0.9432 - mse: 0.0431 - val_loss: 0.1364 - val_accuracy: 0.9475 - val_mse: 0.0400
# Epoch 108/160
# 840/840 [==============================] - 8s 10ms/step - loss: 0.1452 - accuracy: 0.9436 - mse: 0.0427 - val_loss: 0.1365 - val_accuracy: 0.9474 - val_mse: 0.0400
# Epoch 109/160
# 840/840 [==============================] - 9s 10ms/step - loss: 0.1446 - accuracy: 0.9437 - mse: 0.0425 - val_loss: 0.1357 - val_accuracy: 0.9476 - val_mse: 0.0398
# Epoch 110/160
# 840/840 [==============================] - 8s 10ms/step - loss: 0.1448 - accuracy: 0.9436 - mse: 0.0426 - val_loss: 0.1356 - val_accuracy: 0.9477 - val_mse: 0.0398
# Epoch 111/160
# 840/840 [==============================] - 8s 9ms/step - loss: 0.1440 - accuracy: 0.9437 - mse: 0.0424 - val_loss: 0.1351 - val_accuracy: 0.9478 - val_mse: 0.0397
# Epoch 112/160
# 840/840 [==============================] - 8s 9ms/step - loss: 0.1435 - accuracy: 0.9442 - mse: 0.0422 - val_loss: 0.1351 - val_accuracy: 0.9481 - val_mse: 0.0396
# Epoch 113/160
# 840/840 [==============================] - 7s 9ms/step - loss: 0.1436 - accuracy: 0.9446 - mse: 0.0423 - val_loss: 0.1344 - val_accuracy: 0.9481 - val_mse: 0.0394
# Epoch 114/160
# 840/840 [==============================] - 8s 9ms/step - loss: 0.1436 - accuracy: 0.9440 - mse: 0.0423 - val_loss: 0.1344 - val_accuracy: 0.9477 - val_mse: 0.0394
# Epoch 115/160
# 840/840 [==============================] - 8s 9ms/step - loss: 0.1426 - accuracy: 0.9443 - mse: 0.0420 - val_loss: 0.1339 - val_accuracy: 0.9482 - val_mse: 0.0393
# Epoch 116/160
# 840/840 [==============================] - 9s 10ms/step - loss: 0.1425 - accuracy: 0.9446 - mse: 0.0419 - val_loss: 0.1339 - val_accuracy: 0.9480 - val_mse: 0.0394
# Epoch 117/160
# 840/840 [==============================] - 9s 10ms/step - loss: 0.1421 - accuracy: 0.9446 - mse: 0.0418 - val_loss: 0.1341 - val_accuracy: 0.9481 - val_mse: 0.0394
# Epoch 118/160
# 840/840 [==============================] - 7s 8ms/step - loss: 0.1424 - accuracy: 0.9442 - mse: 0.0420 - val_loss: 0.1332 - val_accuracy: 0.9482 - val_mse: 0.0391
# Epoch 119/160
# 840/840 [==============================] - 6s 8ms/step - loss: 0.1409 - accuracy: 0.9447 - mse: 0.0415 - val_loss: 0.1330 - val_accuracy: 0.9485 - val_mse: 0.0391
# Epoch 120/160
# 840/840 [==============================] - 7s 8ms/step - loss: 0.1410 - accuracy: 0.9445 - mse: 0.0416 - val_loss: 0.1332 - val_accuracy: 0.9479 - val_mse: 0.0391
# Epoch 121/160
# 840/840 [==============================] - 6s 8ms/step - loss: 0.1406 - accuracy: 0.9449 - mse: 0.0414 - val_loss: 0.1326 - val_accuracy: 0.9484 - val_mse: 0.0389
# Epoch 122/160
# 840/840 [==============================] - 6s 7ms/step - loss: 0.1405 - accuracy: 0.9444 - mse: 0.0414 - val_loss: 0.1319 - val_accuracy: 0.9485 - val_mse: 0.0388
# Epoch 123/160
# 840/840 [==============================] - 6s 8ms/step - loss: 0.1397 - accuracy: 0.9450 - mse: 0.0412 - val_loss: 0.1322 - val_accuracy: 0.9486 - val_mse: 0.0388
# Epoch 124/160
# 840/840 [==============================] - 7s 8ms/step - loss: 0.1393 - accuracy: 0.9453 - mse: 0.0411 - val_loss: 0.1315 - val_accuracy: 0.9485 - val_mse: 0.0387
# Epoch 125/160
# 840/840 [==============================] - 6s 8ms/step - loss: 0.1390 - accuracy: 0.9452 - mse: 0.0411 - val_loss: 0.1316 - val_accuracy: 0.9486 - val_mse: 0.0387
# Epoch 126/160
# 840/840 [==============================] - 6s 8ms/step - loss: 0.1387 - accuracy: 0.9451 - mse: 0.0410 - val_loss: 0.1315 - val_accuracy: 0.9484 - val_mse: 0.0387
# Epoch 127/160
# 840/840 [==============================] - 6s 7ms/step - loss: 0.1381 - accuracy: 0.9459 - mse: 0.0407 - val_loss: 0.1311 - val_accuracy: 0.9487 - val_mse: 0.0386
# Epoch 128/160
# 840/840 [==============================] - 6s 7ms/step - loss: 0.1377 - accuracy: 0.9460 - mse: 0.0406 - val_loss: 0.1311 - val_accuracy: 0.9486 - val_mse: 0.0385
# Epoch 129/160
# 840/840 [==============================] - 7s 8ms/step - loss: 0.1384 - accuracy: 0.9454 - mse: 0.0408 - val_loss: 0.1305 - val_accuracy: 0.9491 - val_mse: 0.0384
# Epoch 130/160
# 840/840 [==============================] - 6s 8ms/step - loss: 0.1376 - accuracy: 0.9459 - mse: 0.0406 - val_loss: 0.1306 - val_accuracy: 0.9490 - val_mse: 0.0384
# Epoch 131/160
# 840/840 [==============================] - 7s 8ms/step - loss: 0.1369 - accuracy: 0.9464 - mse: 0.0403 - val_loss: 0.1302 - val_accuracy: 0.9491 - val_mse: 0.0384
# Epoch 132/160
# 840/840 [==============================] - 6s 7ms/step - loss: 0.1370 - accuracy: 0.9464 - mse: 0.0404 - val_loss: 0.1299 - val_accuracy: 0.9490 - val_mse: 0.0382
# Epoch 133/160
# 840/840 [==============================] - 7s 8ms/step - loss: 0.1366 - accuracy: 0.9458 - mse: 0.0403 - val_loss: 0.1295 - val_accuracy: 0.9493 - val_mse: 0.0381
# Epoch 134/160
# 840/840 [==============================] - 6s 7ms/step - loss: 0.1361 - accuracy: 0.9462 - mse: 0.0402 - val_loss: 0.1296 - val_accuracy: 0.9489 - val_mse: 0.0382
# Epoch 135/160
# 840/840 [==============================] - 6s 7ms/step - loss: 0.1360 - accuracy: 0.9465 - mse: 0.0400 - val_loss: 0.1291 - val_accuracy: 0.9494 - val_mse: 0.0380
# Epoch 136/160
# 840/840 [==============================] - 7s 8ms/step - loss: 0.1354 - accuracy: 0.9466 - mse: 0.0399 - val_loss: 0.1292 - val_accuracy: 0.9491 - val_mse: 0.0380
# Epoch 137/160
# 840/840 [==============================] - 6s 7ms/step - loss: 0.1356 - accuracy: 0.9466 - mse: 0.0400 - val_loss: 0.1287 - val_accuracy: 0.9495 - val_mse: 0.0379
# Epoch 138/160
# 840/840 [==============================] - 6s 8ms/step - loss: 0.1349 - accuracy: 0.9464 - mse: 0.0398 - val_loss: 0.1286 - val_accuracy: 0.9495 - val_mse: 0.0379
# Epoch 139/160
# 840/840 [==============================] - 6s 8ms/step - loss: 0.1351 - accuracy: 0.9467 - mse: 0.0398 - val_loss: 0.1284 - val_accuracy: 0.9494 - val_mse: 0.0379
# Epoch 140/160
# 840/840 [==============================] - 6s 7ms/step - loss: 0.1343 - accuracy: 0.9469 - mse: 0.0396 - val_loss: 0.1281 - val_accuracy: 0.9495 - val_mse: 0.0378
# Epoch 141/160
# 840/840 [==============================] - 6s 7ms/step - loss: 0.1346 - accuracy: 0.9472 - mse: 0.0396 - val_loss: 0.1280 - val_accuracy: 0.9496 - val_mse: 0.0378
# Epoch 142/160
# 840/840 [==============================] - 7s 8ms/step - loss: 0.1344 - accuracy: 0.9465 - mse: 0.0397 - val_loss: 0.1280 - val_accuracy: 0.9498 - val_mse: 0.0377
# Epoch 143/160
# 840/840 [==============================] - 6s 8ms/step - loss: 0.1344 - accuracy: 0.9468 - mse: 0.0396 - val_loss: 0.1274 - val_accuracy: 0.9497 - val_mse: 0.0376
# Epoch 144/160
# 840/840 [==============================] - 7s 8ms/step - loss: 0.1340 - accuracy: 0.9469 - mse: 0.0396 - val_loss: 0.1276 - val_accuracy: 0.9497 - val_mse: 0.0377
# Epoch 145/160
# 840/840 [==============================] - 6s 8ms/step - loss: 0.1331 - accuracy: 0.9471 - mse: 0.0393 - val_loss: 0.1273 - val_accuracy: 0.9495 - val_mse: 0.0375
# Epoch 146/160
# 840/840 [==============================] - 6s 8ms/step - loss: 0.1326 - accuracy: 0.9477 - mse: 0.0391 - val_loss: 0.1270 - val_accuracy: 0.9499 - val_mse: 0.0375
# Epoch 147/160
# 840/840 [==============================] - 6s 7ms/step - loss: 0.1326 - accuracy: 0.9473 - mse: 0.0392 - val_loss: 0.1269 - val_accuracy: 0.9499 - val_mse: 0.0374
# Epoch 148/160
# 840/840 [==============================] - 6s 7ms/step - loss: 0.1326 - accuracy: 0.9476 - mse: 0.0392 - val_loss: 0.1267 - val_accuracy: 0.9498 - val_mse: 0.0373
# Epoch 149/160
# 840/840 [==============================] - 6s 7ms/step - loss: 0.1322 - accuracy: 0.9474 - mse: 0.0391 - val_loss: 0.1269 - val_accuracy: 0.9499 - val_mse: 0.0375
# Epoch 150/160
# 840/840 [==============================] - 6s 7ms/step - loss: 0.1320 - accuracy: 0.9473 - mse: 0.0390 - val_loss: 0.1263 - val_accuracy: 0.9502 - val_mse: 0.0373
# Epoch 151/160
# 840/840 [==============================] - 7s 8ms/step - loss: 0.1315 - accuracy: 0.9475 - mse: 0.0389 - val_loss: 0.1264 - val_accuracy: 0.9499 - val_mse: 0.0373
# Epoch 152/160
# 840/840 [==============================] - 6s 7ms/step - loss: 0.1314 - accuracy: 0.9479 - mse: 0.0388 - val_loss: 0.1263 - val_accuracy: 0.9499 - val_mse: 0.0373
# Epoch 153/160
# 840/840 [==============================] - 6s 7ms/step - loss: 0.1313 - accuracy: 0.9481 - mse: 0.0388 - val_loss: 0.1266 - val_accuracy: 0.9497 - val_mse: 0.0374
# Epoch 154/160
# 840/840 [==============================] - 6s 7ms/step - loss: 0.1306 - accuracy: 0.9483 - mse: 0.0385 - val_loss: 0.1257 - val_accuracy: 0.9502 - val_mse: 0.0371
# Epoch 155/160
# 840/840 [==============================] - 6s 8ms/step - loss: 0.1306 - accuracy: 0.9481 - mse: 0.0386 - val_loss: 0.1254 - val_accuracy: 0.9505 - val_mse: 0.0370
# Epoch 156/160
# 840/840 [==============================] - 6s 7ms/step - loss: 0.1295 - accuracy: 0.9488 - mse: 0.0382 - val_loss: 0.1252 - val_accuracy: 0.9503 - val_mse: 0.0370
# Epoch 157/160
# 840/840 [==============================] - 6s 7ms/step - loss: 0.1300 - accuracy: 0.9482 - mse: 0.0384 - val_loss: 0.1253 - val_accuracy: 0.9503 - val_mse: 0.0370
# Epoch 158/160
# 840/840 [==============================] - 6s 8ms/step - loss: 0.1298 - accuracy: 0.9479 - mse: 0.0384 - val_loss: 0.1247 - val_accuracy: 0.9505 - val_mse: 0.0368
# Epoch 159/160
# 840/840 [==============================] - 6s 7ms/step - loss: 0.1294 - accuracy: 0.9481 - mse: 0.0383 - val_loss: 0.1246 - val_accuracy: 0.9504 - val_mse: 0.0369
# Epoch 160/160
# 840/840 [==============================] - 6s 7ms/step - loss: 0.1294 - accuracy: 0.9489 - mse: 0.0381 - val_loss: 0.1242 - val_accuracy: 0.9503 - val_mse: 0.0367

# %%
### plot learning curve

fig, ax = plt.subplots(1,1, figsize=(8,8))
plt.plot(tr_model.history["loss"], label='training data',c='blue',linewidth = 2)
plt.plot(tr_model.history["val_loss"], label='validation data',c='red',linewidth = 2)
plt.title("DNN with TDA variable", fontsize=25)
ax.set_ylabel('loss', fontsize=25,horizontalalignment='right',y=1)
ax.set_xlabel('epoch', fontsize=25,horizontalalignment='right',x=1)
# plt.yscale("log")
plt.legend(loc='best', prop={'size':20}, edgecolor = "w",fancybox=False, framealpha=0)
plt.show()

fig, ax = plt.subplots(1,1, figsize=(8,8))
plt.plot(tr_model.history["accuracy"], label='training data',c='blue',linewidth = 2)
plt.plot(tr_model.history["val_accuracy"], label='validation data',c='red',linewidth = 2)
plt.title("DNN with TDA variable", fontsize=25)
ax.set_ylabel('accuracy', fontsize=25,horizontalalignment='right',y=1)
ax.set_xlabel('epoch', fontsize=25,horizontalalignment='right',x=1)
# plt.yscale("log")
plt.legend(loc='best', prop={'size':20}, edgecolor = "w",fancybox=False, framealpha=0)
plt.show()

# %%
print("Time:{:^8.4f}(s)".format(time.time()-t1))
# Out:
# Time:1370.7848(s)

# %%
### save the model ###

model.save("/root/data/mucollider/two_boosted/10TeV/ML_model/model_mucollider_10.h5")
# Out:
# /root/miniconda3/envs/tf/lib/python3.10/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
### check which part of model is more important ###

weights, biases = model.get_layer('dense_4').get_weights()
hl_influence = np.mean(np.abs(weights[:128, :]))
ll_influence = np.mean(np.abs(weights[128:, :]))
print("high level influence: ", hl_influence)
print("low  level influence: ", ll_influence)

weights, _ = model.get_layer('dense_4').get_weights()

hl_weights = np.abs(weights[:128, :]).flatten()
ll_weights = np.abs(weights[128:, :]).flatten()

bins = np.linspace(0,max(hl_weights), 50)
plt.hist(hl_weights, bins=bins, alpha=0.5, label='HL Weights', color='blue')
plt.hist(ll_weights, bins=bins, alpha=0.5, label='LL Weights', color='green')
plt.title('Weight Magnitude Distribution at Fusion Layer')
plt.xlabel('weight')
plt.ylabel('count')
plt.legend()
plt.show()
# Out:
# high level influence:  0.05564999
# low  level influence:  0.05399284

# %%
print("Time:{:^8.4f}(s)".format(time.time()-t1))
# Out:
# Time:1371.2144(s)
