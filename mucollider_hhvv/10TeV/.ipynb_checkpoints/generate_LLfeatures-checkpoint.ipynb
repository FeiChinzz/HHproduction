# %%
########## import some useful package ##########

import time
t1 = time.time()

import uproot
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm

import ripser
import persim

# %%
########## read the data ##########

processes = ["jjBG_ptcut", "ttBG_ptcut", "bbBG_ptcut", "wwBG", "wwvvBG", "zzBG", "zzvvBG", "hzvvBG"]
event_type = [str(i)+"_200K" for i in processes]

BR_hbb = 0.5824
Xsection = [1.08143e-1, 3.539e-2, 1.86879e-2, 2.200885e+1, 7.053723e+1, 1.3355, 3.983523e+1, 7.03508147*BR_hbb]     ### unit: fb
Luminosity = 1000   ### unit: fb^-1
simulation_num = 200000

features = ["VLCjetR10N2", "VLCjetR10N2.PT", "VLCjetR10N2.Mass", "VLCjetR10N2.Constituents", "EFlowTrack.fUniqueID", "EFlowTrack.PT", "EFlowTrack.Eta", "EFlowTrack.Phi", "EFlowTrack.PID", "EFlowPhoton.fUniqueID", "EFlowPhoton.ET", "EFlowPhoton.Eta", "EFlowPhoton.Phi", "EFlowNeutralHadron.fUniqueID", "EFlowNeutralHadron.ET", "EFlowNeutralHadron.Eta", "EFlowNeutralHadron.Phi"]

##### set data path #####

event_path = []
for type in event_type:
    event_path.append("/data/mucollider/two_boosted/10TeV/testdata/" + type + "/delphes_output.root")

##### get the data file #####

data_file =[]
for path in event_path:
    data_file.append(uproot.open(path))
    
##### read data with features #####
events = []     ### total events
for process in processes:
    tmp_events = []
    for feature in features:
        tmp_events.append(data_file[processes.index(process)]["Delphes;1"][feature].array())
    tmp_events = np.expand_dims(tmp_events, axis=-1)
    tmp_events = tmp_events.transpose((1,0,2))
    tmp_events = np.squeeze(tmp_events,axis=(2,))
    events.append(tmp_events)
    print("Time:{:^8.4f}(s)".format(time.time()-t1))
del tmp_events
# Out:
# /usr/local/lib/python3.8/dist-packages/awkward/array/base.py:394: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return cls.numpy.array(value, copy=False)
# Time:18.5979 (s)
# Time:36.5895 (s)
# Time:54.8510 (s)
# Time:66.0129 (s)
# Time:79.8626 (s)
# Time:92.0859 (s)
# Time:104.7068(s)
# Time:121.3210(s)

# %%
########## define useful function ##########

##### calculate significance #####

def significance(s,b):
    return np.sqrt(2*((s+b)*np.log(1+s/b)-s))

##### count event number #####

def count(events):
    events_num = []
    for i, process in enumerate(processes):
        events_num.append(len(events[processes.index(process)]))
        print("There are", events_num[i], process, "events. Corresponding cross section:", Xsection[processes.index(process)]*events_num[i]/simulation_num, "(fb)")
        
##### select if Fat Jet >= 2 #####
        
def Fat_Jet_selection(events):
    where1 = np.where(events[:,features.index("VLCjetR10N2")]>=2)
    return events[where1]

##### select if M_jet_leading > XX GeV #####

def mass_leading_selection(events, low_mass_cut, high_mass_cut):
    where1 = []
    for i in range(len(events)):
        switch=1
        if events[i][features.index("VLCjetR10N2.Mass")][0]<low_mass_cut:
            switch=0
        if events[i][features.index("VLCjetR10N2.Mass")][0]>high_mass_cut:
            switch=0
        if switch==1:
            where1.append(i)
    return events[where1]

##### select if M_jet_subleading > XX GeV #####

def mass_subleading_selection(events, low_mass_cut, high_mass_cut):
    where1 = []
    for i in range(len(events)):
        switch=1
        if events[i][features.index("VLCjetR10N2.Mass")][1]<low_mass_cut:
            switch=0
        if events[i][features.index("VLCjetR10N2.Mass")][1]>high_mass_cut:
            switch=0
        if switch==1:
            where1.append(i)
    return events[where1]

##### select if pT_J_leading > XX GeV #####

def pT_leading_selection(events, low_pT_cut, high_pT_cut):
    where1 = []
    for i in range(len(events)):
        switch = 1
        if events[i][features.index("VLCjetR10N2.PT")][0]<low_pT_cut:
            switch=0
        if events[i][features.index("VLCjetR10N2.PT")][0]>high_pT_cut:
            switch=0
        if switch==1:
            where1.append(i)
    return events[where1]

##### select if pT_J_subleading > XX GeV #####

def pT_subleading_selection(events, low_pT_cut, high_pT_cut):
    where1 = []
    for i in range(len(events)):
        switch = 1
        if events[i][features.index("VLCjetR10N2.PT")][1]<low_pT_cut:
            switch=0
        if events[i][features.index("VLCjetR10N2.PT")][1]>high_pT_cut:
            switch=0
        if switch==1:
            where1.append(i)
    return events[where1]

# %%
def get_particle_info(event):
    ##### set jet constituents ID #####

    leadingJ_constituents = event[features.index("VLCjetR10N2.Constituents")][0][:-1]
    subleadingJ_constituents= event[features.index("VLCjetR10N2.Constituents")][1][:-1]

    ##### construct infromation for all EFlow particles in this events and sort by PT #####

    all_ID = np.concatenate((event[features.index("EFlowTrack.fUniqueID")], event[features.index("EFlowPhoton.fUniqueID")], event[features.index("EFlowNeutralHadron.fUniqueID")]))
    all_PT = np.concatenate((event[features.index("EFlowTrack.PT")], event[features.index("EFlowPhoton.ET")], event[features.index("EFlowNeutralHadron.ET")]))
    all_Eta = np.concatenate((event[features.index("EFlowTrack.Eta")], event[features.index("EFlowPhoton.Eta")], event[features.index("EFlowNeutralHadron.Eta")]))
    all_Phi = np.concatenate((event[features.index("EFlowTrack.Phi")], event[features.index("EFlowPhoton.Phi")], event[features.index("EFlowNeutralHadron.Phi")]))
    all_PID = np.concatenate((event[features.index("EFlowTrack.PID")], np.full(len(event[features.index("EFlowPhoton.fUniqueID")]), 22), np.full(len(event[features.index("EFlowNeutralHadron.fUniqueID")]), 4)))

    #####                          categorize PID                      #####
    ##### 1:electron 2:muon 3:photon 4:neutral hadron 5:charged hadron #####

    condlist = [abs(all_PID)==11, abs(all_PID)==13, abs(all_PID)==22, abs(all_PID)==4]
    choicelist = [1, 2, 3, 4]
    all_PID = np.select(condlist, choicelist, 5)

    sort_order = np.argsort(all_PT)[::-1]   ### from large PT to low PT

    all_ID = all_ID[sort_order]
    all_PT = all_PT[sort_order]
    all_Eta = all_Eta[sort_order]
    all_Phi = all_Phi[sort_order]
    all_PID = all_PID[sort_order]

    ##### find Jet particle in EFlow particle #####
    if len(leadingJ_constituents)>20: where_leading = np.where(np.isin(all_ID, leadingJ_constituents))[0][0:20]
    else: where_leading = np.where(np.isin(all_ID, leadingJ_constituents))[0]

    if len(subleadingJ_constituents)>20: where_subleading = np.where(np.isin(all_ID, subleadingJ_constituents))[0][0:20]
    else: where_subleading = np.where(np.isin(all_ID, subleadingJ_constituents))[0]

    leadingJ_PT, subleadingJ_PT = all_PT[where_leading], all_PT[where_subleading]
    leadingJ_Eta, subleadingJ_Eta = all_Eta[where_leading], all_Eta[where_subleading]
    leadingJ_Phi, subleadingJ_Phi = all_Phi[where_leading], all_Phi[where_subleading]
    leadingJ_PID, subleadingJ_PID = all_PID[where_leading], all_PID[where_subleading]

    leadingJ_info, subleadingJ_info = np.stack((leadingJ_PT, leadingJ_Eta, leadingJ_Phi, leadingJ_PID), axis=1).ravel(), np.stack((subleadingJ_PT, subleadingJ_Eta, subleadingJ_Phi, subleadingJ_PID), axis=1).ravel()

    ##### do zero padding #####

    particle_info = np.zeros(2*20*4)
    particle_info[0:len(leadingJ_info)] = leadingJ_info
    particle_info[80:80+len(subleadingJ_info)] = subleadingJ_info
    
    return particle_info

# %%
########## preselection ##########

print("Before any selection:")
count(events)

##### 2 fat jet selection #####

for process in processes:
    events[processes.index(process)] = Fat_Jet_selection(events[processes.index(process)])
print("\nAfter 2 fat jet selection:")
count(events)

##### leading jet pT selection #####

leading_low_pT_cut = 200   ### GeV
leading_high_pT_cut = 800   ### GeV
for process in processes:
    events[processes.index(process)] = pT_leading_selection(events[processes.index(process)], leading_low_pT_cut, leading_high_pT_cut)
print("\nAfter leading jet pT selection:")
count(events)

##### subleading jet pT selection #####

subleading_low_pT_cut = 200   ### GeV
subleading_high_pT_cut = 600   ### GeV
for process in processes:
    events[processes.index(process)] = pT_subleading_selection(events[processes.index(process)], subleading_low_pT_cut, subleading_high_pT_cut)
print("\nAfter subleading jet pT selection:")
count(events)

##### leading jet mass selection #####

leading_low_mass_cut = 65
leading_high_mass_cut = 150
for process in processes:
    events[processes.index(process)] = mass_leading_selection(events[processes.index(process)], leading_low_mass_cut, leading_high_mass_cut)
print("\nAfter leading jet mass selection:")
count(events)

##### subleading jet mass selection #####

subleading_low_mass_cut = 65
subleading_high_mass_cut = 150
for process in processes:
    events[processes.index(process)] = mass_subleading_selection(events[processes.index(process)], subleading_low_mass_cut, subleading_high_mass_cut)
print("\nAfter subleading jet mass selection:")
count(events)
# Out:
# Before any selection:
# There are 200000 jjBG_ptcut events. Corresponding cross section: 0.10814300000000002 (fb)
# There are 200000 ttBG_ptcut events. Corresponding cross section: 0.03539 (fb)
# There are 200000 bbBG_ptcut events. Corresponding cross section: 0.0186879 (fb)
# There are 200000 wwBG events. Corresponding cross section: 22.00885 (fb)
# There are 200000 wwvvBG events. Corresponding cross section: 70.53723 (fb)
# There are 200000 zzBG events. Corresponding cross section: 1.3355 (fb)
# There are 200000 zzvvBG events. Corresponding cross section: 39.83523 (fb)
# There are 200000 hzvvBG events. Corresponding cross section: 4.097231448128 (fb)
#
# After 2 fat jet selection:
# There are 199990 jjBG_ptcut events. Corresponding cross section: 0.10813759285 (fb)
# There are 199990 ttBG_ptcut events. Corresponding cross section: 0.0353882305 (fb)
# There are 199978 bbBG_ptcut events. Corresponding cross section: 0.018685844331000002 (fb)
# There are 120771 wwBG events. Corresponding cross section: 13.29015411675 (fb)
# There are 181902 wwvvBG events. Corresponding cross section: 64.1543160573 (fb)
# There are 126967 zzBG events. Corresponding cross section: 0.8478221424999999 (fb)
# There are 181498 zzvvBG events. Corresponding cross section: 36.1500728727 (fb)
# There are 197295 hzvvBG events. Corresponding cross section: 4.041816392792069 (fb)
#
# After leading jet pT selection:
# There are 71273 jjBG_ptcut events. Corresponding cross section: 0.038538380195 (fb)
# There are 88677 ttBG_ptcut events. Corresponding cross section: 0.01569139515 (fb)
# There are 74649 bbBG_ptcut events. Corresponding cross section: 0.0069751652355 (fb)
# There are 16466 wwBG events. Corresponding cross section: 1.8119886205 (fb)
# There are 119766 wwvvBG events. Corresponding cross section: 42.2398094409 (fb)
# There are 14636 zzBG events. Corresponding cross section: 0.09773188999999999 (fb)
# There are 122988 zzvvBG events. Corresponding cross section: 24.4962763362 (fb)
# There are 135110 hzvvBG events. Corresponding cross section: 2.7678847047828707 (fb)
#
# After subleading jet pT selection:
# There are 27927 jjBG_ptcut events. Corresponding cross section: 0.015100547805000001 (fb)
# There are 42369 ttBG_ptcut events. Corresponding cross section: 0.007497194549999999 (fb)
# There are 30205 bbBG_ptcut events. Corresponding cross section: 0.0028223400975 (fb)
# There are 8766 wwBG events. Corresponding cross section: 0.9646478955 (fb)
# There are 56165 wwvvBG events. Corresponding cross section: 19.80861761475 (fb)
# There are 8226 zzBG events. Corresponding cross section: 0.054929114999999994 (fb)
# There are 59740 zzvvBG events. Corresponding cross section: 11.898783201 (fb)
# There are 53638 hzvvBG events. Corresponding cross section: 1.0988365020734483 (fb)
#
# After leading jet mass selection:
# There are 10314 jjBG_ptcut events. Corresponding cross section: 0.00557693451 (fb)
# There are 18044 ttBG_ptcut events. Corresponding cross section: 0.0031928857999999997 (fb)
# There are 11093 bbBG_ptcut events. Corresponding cross section: 0.0010365243735 (fb)
# There are 370 wwBG events. Corresponding cross section: 0.0407163725 (fb)
# There are 36478 wwvvBG events. Corresponding cross section: 12.8652853797 (fb)
# There are 549 zzBG events. Corresponding cross section: 0.0036659475 (fb)
# There are 41903 zzvvBG events. Corresponding cross section: 8.346078213450001 (fb)
# There are 39733 hzvvBG events. Corresponding cross section: 0.8139764856423491 (fb)
#
# After subleading jet mass selection:
# There are 3808 jjBG_ptcut events. Corresponding cross section: 0.00205904272 (fb)
# There are 7352 ttBG_ptcut events. Corresponding cross section: 0.0013009363999999999 (fb)
# There are 3952 bbBG_ptcut events. Corresponding cross section: 0.00036927290400000004 (fb)
# There are 1 wwBG events. Corresponding cross section: 0.00011004425 (fb)
# There are 23346 wwvvBG events. Corresponding cross section: 8.2338108579 (fb)
# There are 8 zzBG events. Corresponding cross section: 5.341999999999999e-05 (fb)
# There are 29532 zzvvBG events. Corresponding cross section: 5.8820700618 (fb)
# There are 27527 hzvvBG events. Corresponding cross section: 0.5639224503630973 (fb)

# %%
##### generate particle information #####

particle_info = []

for process in processes:
    for event in events[processes.index(process)]:
        particle_info.append(get_particle_info(event))
    print("Time:{:^8.4f}(s)".format(time.time()-t1))
# Out:
# Time:143.4952(s)
# Time:145.1394(s)
# Time:146.0779(s)
# Time:146.0784(s)
# Time:150.7874(s)
# Time:150.8008(s)
# Time:156.8701(s)
# Time:162.5336(s)

# %%
particle_info[0]
# Out:
# array([ 8.36429214e+01,  2.41746664e+00,  3.00565028e+00,  4.00000000e+00,
#         6.88683243e+01,  2.49649453e+00,  2.96229982e+00,  5.00000000e+00,
#         3.01764717e+01,  1.69437993e+00,  2.99361825e+00,  5.00000000e+00,
#         2.11903820e+01,  1.69750702e+00,  3.09212875e+00,  5.00000000e+00,
#         2.05241184e+01,  2.49820924e+00,  2.99235153e+00,  3.00000000e+00,
#         1.55297995e+01,  1.65779507e+00,  3.03789186e+00,  5.00000000e+00,
#         1.39905272e+01,  2.49656868e+00,  3.01586127e+00,  5.00000000e+00,
#         1.39627981e+01,  2.49209857e+00,  2.93892980e+00,  5.00000000e+00,
#         1.17046165e+01,  1.72272420e+00,  3.04194665e+00,  5.00000000e+00,
#         1.09843407e+01,  2.48413205e+00,  2.98647642e+00,  3.00000000e+00,
#         9.43626118e+00,  1.67562532e+00,  3.06197739e+00,  5.00000000e+00,
#         6.49632883e+00,  1.77031982e+00,  3.00658274e+00,  5.00000000e+00,
#         5.61661434e+00,  2.49843955e+00,  2.93299937e+00,  3.00000000e+00,
#         4.79532528e+00,  1.64866388e+00,  3.00296998e+00,  5.00000000e+00,
#         4.15028858e+00,  2.47974062e+00,  2.98419952e+00,  3.00000000e+00,
#         3.99338984e+00,  2.48784709e+00,  2.90443492e+00,  3.00000000e+00,
#         3.21910334e+00,  2.41140056e+00, -3.10353589e+00,  4.00000000e+00,
#         3.07272077e+00,  1.68371332e+00,  3.04940605e+00,  5.00000000e+00,
#         2.87234616e+00,  1.82423079e+00, -3.03866720e+00,  4.00000000e+00,
#         2.58378482e+00,  2.45196557e+00,  2.91628242e+00,  3.00000000e+00,
#         1.97061066e+02, -2.46669960e+00, -1.16290264e-01,  3.00000000e+00,
#         4.64621048e+01, -2.44110823e+00, -1.15339272e-01,  3.00000000e+00,
#         9.71128368e+00, -2.49570298e+00, -1.13386475e-01,  3.00000000e+00,
#         8.07891083e+00, -2.45412159e+00, -9.75593105e-02,  3.00000000e+00,
#         7.79231834e+00, -2.47798896e+00, -1.11111514e-01,  3.00000000e+00,
#         7.31937170e+00, -2.30822062e+00, -2.60774344e-01,  3.00000000e+00,
#         4.33113480e+00, -2.31013775e+00, -2.34798416e-01,  3.00000000e+00,
#         4.30219030e+00, -2.43020749e+00, -7.73847327e-02,  3.00000000e+00,
#         3.22124052e+00, -2.26701069e+00,  1.66487947e-01,  5.00000000e+00,
#         2.20990872e+00, -2.29929924e+00, -2.63087153e-01,  3.00000000e+00,
#         1.65998006e+00, -2.37992144e+00, -7.83017725e-02,  3.00000000e+00,
#         1.48783731e+00, -1.03664458e+00,  8.90042335e-02,  4.00000000e+00,
#         1.41910815e+00, -1.16448402e+00,  2.40600258e-02,  5.00000000e+00,
#         9.68309939e-01, -9.60259676e-01, -1.05789274e-01,  3.00000000e+00,
#         6.79399610e-01, -2.24612761e+00,  2.68142223e-02,  5.00000000e+00,
#         6.65437043e-01, -1.96806979e+00,  3.25497448e-01,  5.00000000e+00,
#         5.70958257e-01, -1.91753042e+00, -2.65441686e-01,  3.00000000e+00,
#         5.62328696e-01, -8.22583199e-01,  5.60261905e-01,  3.00000000e+00,
#         5.34353375e-01, -1.60752583e+00,  6.17551506e-01,  5.00000000e+00,
#         5.20314276e-01, -1.34373379e+00,  1.28725898e+00,  5.00000000e+00])

# %%
##### output test data #####

d = {'particle_info': particle_info}
df = pd.DataFrame(data=d)
df
# Out:
#                                            particle_info
# 0      [83.6429214477539, 2.417466640472412, 3.005650...
# 1      [93.03103637695312, 2.2409629821777344, -0.734...
# 2      [77.21674346923828, -2.3784704208374023, 1.635...
# 3      [116.06806945800781, 2.425384998321533, -2.244...
# 4      [66.3756103515625, 1.5240416526794434, 1.40357...
# ...                                                  ...
# 95521  [81.55436706542969, -1.4126031398773193, 2.751...
# 95522  [48.97913360595703, 0.05121324583888054, 2.411...
# 95523  [116.95706176757812, -1.6328436136245728, -1.5...
# 95524  [90.8409194946289, -1.3846659660339355, -0.820...
# 95525  [66.3339614868164, 0.7711874842643738, -2.0219...
#
# [95526 rows x 1 columns]

# %%
import h5py
h5f = h5py.File('/data/mucollider/two_boosted/10TeV/test_LLfeature.h5', 'w')
for key, value in d.items():
    h5f.create_dataset(key, data=value)
    print(f"已寫入 Dataset: {key}")
h5f.close()
# Out:
# 已寫入 Dataset: particle_info
